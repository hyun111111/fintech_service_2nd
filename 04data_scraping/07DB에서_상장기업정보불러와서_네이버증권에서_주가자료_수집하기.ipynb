# %% [markdown]
# # DB에 저장된 상장기업 정보 불러오기

# %%
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()
import pandas as pd

# %%
engine = create_engine("mysql+pymysql://root:0308@localhost:3306/stock_info")
conn = engine.connect()

# %%
data = pd.read_sql('stock_company_info_2025_4_7', con=conn)
conn.close()

# %%
data
# Out:
#       주식종목       회사명   종목코드                        업종  \
# 0      코스닥    한국피아이엠  44890             자동차 신품 부품 제조업
# 1      코스닥    에이유브랜즈  48107     섬유, 의복, 신발 및 가죽제품 소매업
# 2      코스닥    우양에이치씨  10197  구조용 금속제품, 탱크 및 증기발생기 제조업
# 3      코스닥        더즌  46286                    전기 통신업
# 4      코스닥      심플랫폼  44453            소프트웨어 개발 및 공급업
# ...    ...       ...    ...                       ...
# 2756  유가증권      유한양행  00010                   의약품 제조업
# 2757  유가증권    CJ대한통운  00012                 도로 화물 운송업
# 2758  유가증권        경방  00005                    종합 소매업
# 2759  유가증권     유수홀딩스  00070       회사 본부 및 경영 컨설팅 서비스업
# 2760  유가증권  한진중공업홀딩스  00348         연료용 가스 제조 및 배관공급업
#
#                                                    주요제품         상장일  결산월  \
# 0     내연기관 부품(터보차저, DCT변속기), IT 부품(스마트워치/스마트링), 자율주행...  2025-04-04  12월
# 1                               레인부츠, 스니커즈, 겨울화, 패션잡화 등  2025-04-03  12월
# 2                                       화공 플랜트, 에너지 플랜트  2025-03-28  12월
# 3                                 디지털뱅킹 솔루션(B2B 금융 서비스)  2025-03-24  12월
# 4                NUBISON AIoT(산업용 데이터 수집과 산업용 AI서비스 운영)  2025-03-21  12월
# ...                                                 ...         ...  ...
# 2756  의약품(삐콤씨, 안티푸라민, 렉라자, 로수바미브, 코푸시럽 등), 생활용품(유한락스...  1962-11-01  12월
# 2757  Contract Logistics, 포워딩, 항만하역, 해운, 택배국제특송, SCM...  1956-07-02  12월
# 2758          섬유류(면사,면혼방사,면직물,면혼방직물,화섬사,화섬직물) 제조,도매,수출입  1956-03-03  12월
# 2759                                               지주사업  1956-03-03  12월
# 2760                                               지주회사  1956-03-03  12월
#
#        대표자명                          홈페이지     지역
# 0       송준호       http://www.pimkorea.com  대구광역시
# 1       김지훈  http://aubrandz.irpage.co.kr  서울특별시
# 2       김진태      http://www.wooyang.co.kr    경기도
# 3       조철한        http://www.dozn.co.kr/  서울특별시
# 4     임대근..       http://simplatform.com/  서울특별시
# ...     ...                           ...    ...
# 2756  대표이..        http://www.yuhan.co.kr  서울특별시
# 2757  신영수..    http://www.cjlogistics.com  서울특별시
# 2758  김준,..    http://www.kyungbang.co.kr  서울특별시
# 2759    송영규  http://www.eusu-holdings.com  서울특별시
# 2760    조원국  http://www.hhic-holdings.com    경기도
#
# [2761 rows x 10 columns]

# %% [markdown]
# # Npay 증권에서 종목코드로 주가 조회 후 추가하기

# %%
https://finance.naver.com/item/main.naver?code=005930

# %%
stock_code = data['종목코드'].apply(lambda x: x+"0")
stock_code
# Out:
# 0       448900
# 1       481070
# 2       101970
# 3       462860
# 4       444530
#          ...
# 2756    000100
# 2757    000120
# 2758    000050
# 2759    000700
# 2760    003480
# Name: 종목코드, Length: 2761, dtype: object

# %%
for code in stock_code:
    pass
 #   print(code)

# %% [markdown]
# # 종목코드,종목명, 현재가, 변동금액, 변화율,전일 가, 고가,상한가,저가, 하한가,거래량

# %% [markdown]
# 수집 후 DB 저장
# * table명 = stock_price_(연도)_(월)

# %%
import requests
import time
from bs4 import BeautifulSoup as bs

# %%
url = "https://finance.naver.com/item/main.naver"
payload = dict(code=448900)
r = requests.get(url, params=payload)
print( r.url, r. status_code)
data = r.content
data
# Out:
# https://finance.naver.com/item/main.naver?code=448900 200
# b'\n\n\t\n\t\n\t\n\t\n<html lang=\'ko\'>\n<head>\n\n\n\t\n\t\t<title>\xc7\xd1\xb1\xb9\xc7\xc7\xbe\xc6\xc0\xcc\xbf\xa5 : \xb3\xd7\xc0\xcc\xb9\xf6\xc6\xe4\xc0\xcc \xc1\xf5\xb1\xc7</title>\n\t\n\t\n\n\n\n\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n\n<meta http-equiv="Content-Script-Type" content="text/javascript">\n<meta http-equiv="Content-Style-Type" content="text/css">\n<meta name="apple-mobile-web-app-title" content="\xb3\xd7\xc0\xcc\xb9\xf6\xc6\xe4\xc0\xcc \xc1\xf5\xb1\xc7" />\n\n\n\n\n\n\t\n    \n        <meta property="og:url" content="https://finance.naver.com/item/main.naver?code=448900"/>\n        \n\t\t\t\n\t\t    \n\t\t    \t<meta property="og:title" content="\xc7\xd1\xb1\xb9\xc7\xc7\xbe\xc6\xc0\xcc\xbf\xa5 - \xb3\xd7\xc0\xcc\xb9\xf6\xc6\xe4\xc0\xcc \xc1\xf5\xb1\xc7 : \xb3\xd7\xc0\xcc\xb9\xf6\xc6\xe4\xc0\xcc \xc1\xf5\xb1\xc7"/>\n\t\t     \n\t\t\n\t\t\n\t\t\t\n\t\t\t   <meta property="og:description" content="\xb0\xfc\xbd\xc9\xc1\xbe\xb8\xf1\xc0\xc7 \xbd\xc7\xbd\xc3\xb0\xa3 \xc1\xd6\xb0\xa1\xb8\xa6 \xb0\xa1\xc0\xe5 \xba\xfc\xb8\xa3\xb0\xd4 \xc8\xae\xc0\xce\xc7\xcf\xb4\xc2 \xb0\xf7"/>\n\t\t    \n\t\t    \n\t\t\n\t\t \n\t\t\t\n\t\t\t    <meta property="og:image" content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png"/>\n\t\t    \n\t\t    \n\t\t\n    \n\n<meta property="og:type" content="article"/>\n<meta property="og:article:thumbnailUrl" content=""/>\n<meta property="og:article:author" content="\xb3\xd7\xc0\xcc\xb9\xf6\xc6\xe4\xc0\xcc \xc1\xf5\xb1\xc7"/>\n<meta property="og:article:author:url" content="http://FINANCE.NAVER.COM"/>\n\n\n\n\n\n\n<link rel=\'stylesheet\' type=\'text/css\' href=\'https://ssl.pstatic.net/imgstock/static.pc/20250326145749/css/finance_header.css\'>\n\n\t\n\t\n\t\n\t\n\t\t\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20250326145749/css/newstock.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20250326145749/css/common.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20250326145749/css/layout.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20250326145749/css/main.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20250326145749/css/newstock2.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20250326145749/css/newstock3.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20250326145749/css/world.css">\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20250326145749/js/jindo.min.ns.1.5.3.euckr.js"></script>\n\t\t\t\t<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20250326145749/js/release/common.js"></script>\n\t\t\t\t<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20250326145749/js/jindoComponent/jindo.Component.1.0.3.js"></script>\n\t\t\t\t<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20250326145749/js/nhn.autocomplete.stock.js"></script>\n\t\t\t\n\t\t\n\n\t\t\n\t\n\n<script>\n\tvar ieVersion = (function () {\n        var version = -1;\n        if (\n          navigator.appName == \'Microsoft Internet Explorer\' &&\n          navigator.userAgent.toLowerCase().indexOf(\'msie\') != -1 &&\n          new RegExp(\'MSIE ([0-9]{1,}[\\./0-9]{0,})\').exec(navigator.userAgent) != null\n        ) {\n          version = parseInt(RegExp.$1);\n        }\n        return version;\n      })();\n</script>\n\t\n\n\t<link rel="shortcut icon" href="https://ssl.pstatic.net/imgstock/favi/favicon.ico" type="image/x-icon">\n\t\n\t<script type="text/javascript">\n    (function(){\n\t\tdocument.write(\n\t\t\t\t[\n\t\t\t\t\t\'<link rel="apple-touch-icon-precomposed" href="https://ssl.ps ...

# %%
soup = bs(data, "lxml")
print(soup)
# Out:
# <html lang="ko">
# <head>
# <title>한국피아이엠 : 네이버페이 증권</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="네이버페이 증권" name="apple-mobile-web-app-title"/>
# <meta content="https://finance.naver.com/item/main.naver?code=448900" property="og:url"/>
# <meta content="한국피아이엠 - 네이버페이 증권 : 네이버페이 증권" property="og:title"/>
# <meta content="관심종목의 실시간 주가를 가장 빠르게 확인하는 곳" property="og:description"/>
# <meta content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png" property="og:image"/>
# <meta content="article" property="og:type"/>
# <meta content="" property="og:article:thumbnailUrl"/>
# <meta content="네이버페이 증권" property="og:article:author"/>
# <meta content="http://FINANCE.NAVER.COM" property="og:article:author:url"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20250326145749/css/finance_header.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20250326145749/css/newstock.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20250326145749/css/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20250326145749/css/layout.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20250326145749/css/main.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20250326145749/css/newstock2.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20250326145749/css/newstock3.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20250326145749/css/world.css" rel="stylesheet" type="text/css"/>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20250326145749/js/jindo.min.ns.1.5.3.euckr.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20250326145749/js/release/common.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20250326145749/js/jindoComponent/jindo.Component.1.0.3.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20250326145749/js/nhn.autocomplete.stock.js" type="text/javascript"></script>
# <script>
# 	var ieVersion = (function () {
#         var version = -1;
#         if (
#           navigator.appName == 'Microsoft Internet Explorer' &&
#           navigator.userAgent.toLowerCase().indexOf('msie') != -1 &&
#           new RegExp('MSIE ([0-9]{1,}[\./0-9]{0,})').exec(navigator.userAgent) != null
#         ) {
#           version = parseInt(RegExp.$1);
#         }
#         return version;
#       })();
# </script>
# <link href="https://ssl.pstatic.net/imgstock/favi/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <script type="text/javascript">
#     (function(){
# 		document.write(
# 				[
# 					'<link rel="apple-touch-icon-precomposed" href="https://ssl.pstatic.net/imgstock/favi/favicon-96x96.png"/>',
# 					'<link rel="apple-touch-icon-precomposed" sizes="180x180" href="https://ssl.pstatic.net/imgstock/favi/favicon-180x180.png"/>',
# 					'<link rel="apple-touch-icon-precomposed" sizes="192x192" href="https://ssl.pstatic.net/imgstock/favi/favicon-192x192.png"/>',
# 					'<link rel="icon" type="image/png" sizes="16x16" href="https://ssl.pstatic.net/imgstock/favi/favicon-16x16.png"/>',
# 					'<link rel="icon" type="image/png" sizes="32x32" href="https://ssl.pstatic.net/imgstock/favi/favicon-32x32.png"/>',
# 					'<link rel="icon" type="image/png" sizes="96x96" href="https://ssl.pstatic.net/imgstock/favi/favicon-96x96.png"/>',
# 					'<link rel="icon" type="image/png" sizes="192x192" href="https://ssl.pstatic.net/imgstock/favi/favicon-192x192.png"/>'
# 				]
# 			.join('\n')
# 		);
#     })();
#     </script>
# </head>
# <body onload="getGNB();">
# <script type="text/javascript">
#
#
#
#
#
#
#
# var nsc="finance.stockend";
#
#
# var ccsrv="cc.naver.com";
#
#
#
#
# 	var gnb_service='finance';
#
#
#
# var gnb_logout=document.URL; //GNB에서 로그아웃 후 redirect 될 URL
# var gnb_searchbox='off'; //미니 검색창을 on 할지 off 할지. default는 off
# var gnb_shortnick='off'; //닉네임 말줄임(10자)을 on할지 off 할지. default는 off.
#
#
# var gnb_naverme_layer_open_callback = function(){
# 	   var naverLayerSize = gnbNaverMeLayer.getLayerSize();
#
# 		var me_layers = document.getElementById("me_layers");
# 		me_layers.width=naverLayerSize.width;
# 		me_layers.height=naverLayerSize.height;};
#
# var gnb_naverme_layer_close_callback = function(){
#
# 			var me_layers = document.getElementById("me_layers");
# 			me_layers.width="0";
# 			me_layers.height="0";};
# </script>
# <div id="u_skip">
# <a href="#menu" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#middle" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div id="header">
# <div class="header_area">
# <div class="header_inner">
# <div class="logo_area">
# <h1 class="service">
# <a class="logo_link" href="https://www.naver.com/" onclick="clickcr(this, 'STA.naver', '', '', event);">
# <svg fill="none" height="22" viewbox="0 0 22 22" width="22" xmlns="http://www.w3.org/2000/svg">
# <path d="M22 11C22 13.1756 21.3549 15.3023 20.1462 17.1113C18.9375 18.9202 17.2195 20.3301 15.2095 21.1627C13.1995 21.9952 10.9878 22.2131 8.85401 21.7886C6.72022 21.3642 4.76021 20.3166 3.22183 18.7782C1.68345 17.2398 0.635805 15.2798 0.211368 13.146C-0.213069 11.0122 0.00476298 8.80047 0.837327 6.79048C1.66989 4.78049 3.07979 3.06253 4.88873 1.85383C6.69768 0.645137 8.82441 0 11 0C13.9174 0 16.7153 1.15893 18.7782 3.22183C20.8411 5.28473 22 8.08262 22 11ZM12.8398 5.83V11.3602L8.98976 5.83H5.83V16.1838H9.1575V10.637L13.0075 16.17H16.1783V5.83H12.8398Z" fill="#000"></path>
# </svg>
# <span class="blind">네이버</span>
# </a>
# <a class="logo_link" href="https://new-m.pay.naver.com/" onclick="clickcr(this, 'STA.pay', '', '', event);">
# <svg fill="none" height="22" viewbox="0 0 37 22" width="37" xmlns="http://www.w3.org/2000/svg">
# <path d="M34.4319 5.21944L31.3913 12.1478L27.9518 5.21944H25.3072L30.1783 14.8317L28.1703 19.3358H30.7384L37 5.2331L34.4319 5.21944ZM23.6171 15.9331H21.1037V14.9328C20.1894 15.7342 19.0108 16.1685 17.7953 16.1518C14.7901 16.1518 12.4379 13.692 12.4379 10.5763C12.4379 7.46057 14.7874 5.00079 17.7953 5.00079C19.0104 4.9833 20.189 5.41657 21.1037 6.21701V5.21944H23.6171V15.9331ZM21.3987 10.5899C21.3987 8.57019 19.9891 7.03694 18.1204 7.03694C16.2517 7.03694 14.842 8.57019 14.842 10.5899C14.842 12.6097 16.249 14.1429 18.1204 14.1429C19.9918 14.1429 21.3987 12.596 21.3987 10.5899ZM0.00819554 19.3358H2.63088V15.023C3.52823 15.7695 4.66309 16.1699 5.83001 16.1518C8.83516 16.1518 11.1901 13.692 11.1901 10.5763C11.1901 7.46057 8.83789 5.00079 5.83001 5.00079C4.61166 4.9789 3.42899 5.4126 2.51341 6.21701V5.21944H0L0.00819554 19.3358ZM5.51856 7.03694C7.38722 7.03694 8.79691 8.57019 8.79691 10.5899C8.79691 12.6097 7.38722 14.1429 5.51856 14.1429C3.6499 14.1429 2.24021 12.6097 2.24021 10.5899C2.24021 8.57019 3.63351 7.03694 5.51856 7.03694Z" fill="#000"></path>
# </svg>
# <span class="blind">페이</span>
# </a>
# <a class="logo_link" href="/" onclick="clickcr(this, 'STA.finance', '', '', event);">
# <svg fill="none" height="22" viewbox="0 0 34 22" width="34" xmlns="http://www.w3.org/2000/svg">
# <path d="M2.43006 8.88998L1.85406 6.99998C5.29206 6.31598 7.00206 5.34398 7.45206 4.31798H2.71806V2.35598H14.3641V4.31798H9.75606C9.70206 4.65998 9.61206 4.98398 9.46806 5.28998L15.2101 6.98198L14.4901 8.88998L8.02806 6.92798C6.84006 7.75598 5.00406 8.40398 2.43006 8.88998ZM0.612061 11.5V9.53798H16.4521V11.5H0.612061ZM6.53406 12.796H10.5301C13.2301 12.796 14.7961 14.128 14.7961 15.91C14.7961 17.71 13.2301 19.024 10.5301 19.024H6.53406C3.85206 19.024 2.28606 17.71 2.28606 15.91C2.28606 14.128 3.85206 12.796 6.53406 12.796ZM6.96606 17.044H10.1161C11.7901 17.044 12.4921 16.594 12.4921 15.892C12.4921 15.19 11.7901 14.776 10.1161 14.776H6.96606C5.29206 14.776 4.57206 15.19 4.57206 15.892C4.57206 16.594 5.29206 17.044 6.96606 17.044Z" fill="#000"></path>
# <path d="M25.1904 13.354V11.536H29.4564V2.03198H31.7604V15.334H29.4564V13.354H25.1904ZM21.3384 10.564C20.9244 10.582 20.5464 10.582 20.1684 10.582H17.4504L17.3604 8.61998H20.3844C21.5004 8.61998 22.9584 8.56598 24.4884 8.45798C24.7224 6.99998 24.8484 5.63198 24.8664 4.62398H18.4404V2.66198H27.0984V3.56198C27.0984 5.16398 26.9724 6.76598 26.7564 8.25998L28.2684 8.09798L28.5024 10.006C26.9724 10.222 25.2264 10.384 23.5704 10.474C23.4984 11.5 23.3904 12.562 23.2644 13.714L21.0684 13.588C21.1764 12.508 21.2664 11.536 21.3384 10.564ZM22.4724 14.254V16.756H32.3724V18.844H20.1684V14.254H22.4724Z" fill="#000"></path>
# </svg>
# <span class="blind">증권</span>
# </a>
# </h1>
# </div>
# <div class="right_area">
# <div class="search_area">
# <form action="/search/search.naver" method="get" name="search" onsubmit="return delayed_submit(this)" style="margin:0; padding:0;">
# <label class="blind" for="stock_items">증권 종목명·지수명 검색</label>
# <input accesskey="s" autocomplete="off" class="search_input" id="stock_items" name="query" placeholder="종목명·지수명 입력" title="종목명·지수명 검색" type="text"/>
# <input id="_endUrl" name="endUrl" type="hidden" value=""/>
# <button class="search_button" onclick="clickcr(this, 'STA.search', '', '', event);" type="button">
# <svg fill="none" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M6.9999 2.59996C4.56985 2.59996 2.5999 4.56991 2.5999 6.99996C2.5999 9.43002 4.56985 11.4 6.9999 11.4C9.42996 11.4 11.3999 9.43002 11.3999 6.99996C11.3999 4.56991 9.42996 2.59996 6.9999 2.59996ZM1.3999 6.99996C1.3999 3.90717 3.90711 1.39996 6.9999 1.39996C10.0927 1.39996 12.5999 3.90717 12.5999 6.99996C12.5999 10.0928 10.0927 12.6 6.9999 12.6C3.90711 12.6 1.3999 10.0928 1.3999 6.99996Z" fill="#404048" fill-rule="evenodd"></path>
# <path clip-rule="evenodd" d="M10.2421 10.2424C10.4765 10.0081 10.8564 10.0081 11.0907 10.2424L14.424 13.5758C14.6583 13.8101 14.6583 14.19 14.424 14.4243C14.1897 14.6586 13.8098 14.6586 13.5755 14.4243L10.2421 11.091C10.0078 10.8567 10.0078 10.4768 10.2421 10.2424Z" fill="#404048" fill-rule="evenodd"></path>
# </svg>
# <span class="blind">검색</span>
# </button>
# <div class="auto_area">
# <span class="blind">자동완성</span>
# <div id="autoFrame" style="display: none;">
# <div class="wrap" id="atcmp" style="display:none;">
# <div class="wrap_in">
# <div class="words">
# <ul class="_resultBox">
# <li>
# <a class="_au_real_list" href="#" onclick="clickcr(this, 'AUT.list', '', '', event); return false;">
# <span class="num _au_real_list">@code@</span>
# <span class="_au_real_list">@txt@</span>
# <span class="type _au_real_list">@market@</span>
# </a>
# <div class="_au_full" style="display:none">@full_txt@</div>
# <div class="_au_code" style="display:none">@in_code@</div>
# <div class="_au_name" style="display:none">@in_name@</div>
# <div class="_au_link" style="display:none">@in_link@</div>
# <div class="_au_market" style="display:none">@in_market@</div>
# </li>
# </ul>
# <div class="search_notice">
# <p class="text">
# 												공모주와 해외 종목은 모바일 페이지로 이동합니다.
# 											</p>
# </div>
# </div>
# </div>
# <!-- 현재 자동완성 기능을 사용하고 계십니다 -->
# <div class="wrap" id="atcmpIng" style="display:none;">
# <div class="wrap_in">
# <div class="words">
# <p class="msg">
# 												현재 자동완성 기능을 사용하고 계십니다.
# 											</p>
# </div>
# </div>
# </div>
# <!--// 현재 자동완성 기능을 사용하고 계십니다 -->
# <!-- 자동완성 기능이 활성화 -->
# <div class="wrap" id="atcmpStart" style="display:none;">
# <div class="wrap_in">
# <div class="words">
# <p class="msg">
# 												자동완성 기능이 활성화되었습니다.
# 											</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </form>
# </div>
# <div class="gnb_area">
# <div id="gnb">
# <script charset="EUC-KR" type="text/javascript">
# 							var gnb_service = "finance";
# 							var gnb_template = location.protocol === "http:" ? "gnb_quirks_euckr" : "gnb_utf8" ;
# 							var gnb_logout=encodeURIComponent(location.href);
# 							var gnb_brightness = 1;
# 							var gnb_one_naver = 0;
# 						</script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn?20250407" type="text/javascript">
# </script>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div id="menu">
# <ul class="menu">
# <li class="m1 first"><a href="/" onclick="clickcr(this, 'LNB.home', '', '', event);"><span class="tx">증권 홈</span></a></li>
# <li class="m2 on"><a href="/sise/" onclick="clickcr(this, 'LNB.sise', '', '', event);"><span class="tx">국내증시</span><span class="blind">선택됨</span></a></li>
# <li class="m3"><a href="/world/" onclick="clickcr(this, 'LNB.world', '', '', event);"><span class="tx">해외증시</span></a></li>
# <li class="m4"><a href="/marketindex/" onclick="clickcr(this, 'LNB.market', '', '', event);"><span class="tx">시장지표</span></a></li>
# <li class="m6"><a href="/research/" onclick="clickcr(this, 'LNB.research', '', '', event);"><span class="tx">리서치</span></a></li>
# <li class="m7"><a href="/news/"><span class="tx">뉴스</span></a></li>
# <li class="m8"><a href="/mystock/" onclick="clickcr(this, 'LNB.mystock', '', '', event);"><span class="tx">MY</span></a></li>
# </ul>
# </div>
# </div>
# </div>
# <script type="text/JavaScript">
# 		/* lcs 집계 */
#         ;(function(){
#             var eventType = "onpageshow" in window ? "pageshow" : "load";
#             jindo.$Fn(function(){
#                 lcs_do();
#             }).attach(window, eventType);
#         })();
#
# 		/* 검색 자동완성 [ 인자1 : 검색input의 ID, 인자2 : iframe 태그 ID ]   */
# 		// AutoComplete 생성
# 		var acDomain = "ac.stock.naver.com";
# 		if (location.hostname.indexOf("staging-") > -1) {
# 			acDomain = "staging-" + acDomain;
# 		} else if (location.hostname.indexOf("test-") > -1) {
# 			acDomain = "test-" + acDomain;
# 		} else if (location.hostname.indexOf("dev-") > -1 || location.hostname.indexOf("localhost") > -1 || location.hostname.indexOf("local-") > -1) {
# 			acDomain = "dev-" + acDomain;
# 		}
#
#         var acUrl = "https://" + acDomain + "/ac";
#
# 		smartSearch = new nhn.Autocomplete(
# 			// InputManager 생성
# 			new nhn.AcInputManager(jindo.$("stock_items")),
# 			// DataManager 생성
# 			new nhn.AcDataManager(acUrl, "xhr", "get", {}),
# 			// ViewManager 생성
# 			new nhn.AcStockViewManager(jindo.$("autoFrame"), jindo.$("nautocomplete"), {
#                                         strMax: 200,
#                                         listMax: [7, 2, 2],
#                                         aRedirectUrl: [
# 										"https://" + window.location.hostname,
#                             			"https://finance.naver.com",
#                             			"https://finance.naver.com"],
# 										mobileUrl: "https://m.stock.naver.com"}),
# 			// Autocomplete Option
#             {formId:"search", cookieDomain:location.hostname, cookieName:"NaverCommonStock_disable"});
#
# 			smartSearch.attach({
# 	            onFocus: function () {
# 	                var weInput = jindo.$Element('stock_items');
# 	                if (weInput && weInput.hasClass("snb_default")) {
# 	                        weInput.text("");
# 	                        weInput.removeClass('snb_default');
# 	                }
# 	            }
# 	        });
#
# 		/* 통합검색  start ----->  */
# 		var sSearchHintText = '종목명·지수명·환율명·원자재명 입력';
# 		function itegrationSearch() {
# 			var query = jindo.$('stock_items').value;
#
# 			if ( query == ''  || encodeURIComponent(query) == encodeURIComponent(sSearchHintText))
# 			{
# 				alert ( '검색어를 입력해 주세요.' );
# 				return;
# 			}
#
#             var url = "https://search.naver.com/search.naver?sm=sta_hty.finance&where=nexearch&ie=UTF8&query=" + encodeURIComponent(query);
#             window.open(url, "_blank");
#
# 			return false;
# 		}
#
# 		function delayed_submit(object) {
# 			if (navigator.userAgent.indexOf('MSIE') == -1) {
# 				window.setTimeout(function() {stock_search(object)}, 300);
# 			} else {
# 				stock_search(object);
# 			}
# 			return false;
# 		}
#
# 		function stock_search (object) {
# 			// endUrl check
# 			if (object.endUrl.value) {
# 				if (object.endUrl.value.startsWith("https://m.stock.naver.com")) {
# 					// 검색정보 초기화
# 					var _endUrl = object.endUrl.value;
# 					object.query.value = "";
# 					object.endUrl.value = "";
# 					document.getElementById("atcmp").style.display="none";
# 					window.open(_endUrl, "_blank");
# 				} else {
# 					location.href = object.endUrl.value;
# 				}
#
# 				return;
# 			}
#
# 			// query check
# 			query = object.query.value.replace(/^\s*/,'').replace(/\s*$/,'');	// trim
# 			object.query.value=query;
#
# 			if ( query == '' || query == sSearchHintText.replace(/^\s*/,'').replace(/\s*$/,''))
# 			{
# 				alert ( '검색어를 입력해 주세요.' );
# 				return;
# 			}
# 			else {
# 				object.submit();
# 			}
# 		}
# 		/* <---------- 통합검색  end */
#
# 		function popup()
# 		{
# 			win = window.open('/template/group_limit_pop.jsp','finan_popup','width=569 height=278 scrollbars=no status=no');
# 			win.focus();
# 		}
# 	</script>
# <iframe frameborder="0" height="0" id="me_layers" name="test" scrolling="no" style="display:block;top: 22px; right: 209px; position: absolute; z-index: 15;" title="네이버미 영역" width="0"></iframe>
# </div>
# <div id="wrap">
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20250326145749/js/ellipse.js"></script>
# <script type="text/javascript">
# 	function financialInfoCommentToggle() {
# 		if(jindo.$Element(jindo.$$.getSingle("div.ly_moreifrs")).visible()) {
# 			jindo.$Element(jindo.$$.getSingle("a.more_ifrs")).html("항목별 상세기준 보기");
# 			jindo.$Element(jindo.$$.getSingle("a.more_ifrs")).removeClass("fd");
# 		} else {
# 			jindo.$Element(jindo.$$.getSingle("a.more_ifrs")).html("항목별 상세기준 닫기");
# 			jindo.$Element(jindo.$$.getSingle("a.more_ifrs")).addClass("fd");
# 		}
# 		jindo.$Element(jindo.$$.getSingle("div.ly_moreifrs")).toggle();
# 	}
#
# </script>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20250326145749/js/recent_code.js"></script>
# <script language="javascript">addCode('448900');</script>
# <script language="JavaScript" src="https://ssl.pstatic.net/imgstock/static.pc/20250326145749/js/summary.js"></script>
# <script language="JavaScript">fchartStatus.setChartStatus('on');</script>
# <style>
#
#     .hide_chart {
#         position: absolute;
#         top: 0;
#         left: -9999px;
#     }
# </style>
# <div class="new_totalinfo" id="middle">
# <dl class="blind">
# <dt>종목 시세 정보</dt>
# <dd>2025년 04월
#         07일 13시
#         43분 기준 장중</dd>
# <dd>종목명 한국피아이엠</dd>
# <dd>종목코드 448900 코스닥</dd>
# <dd>현재가 15,400 전일대비 하락 700
#             마이너스
#             4.35 퍼센트
#         </dd>
# <dd>전일가 16,100</dd>
# <dd>시가 17,040</dd>
# <dd>고가 17,720</dd>
# <dd>상한가 20,900</dd>
# <dd>저가 15,350</dd>
# <dd>하한가 11,270</dd>
# <dd>거래량 6,315,335</dd>
# <dd>거래대금 105,866백만</dd>
# </dl>
# <div class="h_company">
# <div class="wrap_company">
# <h2><a href="#" onclick="clickcr(this, 'sop.title', '', '', event);window.location.reload();">한국피아이엠</a>
# </h2>
# <div class="description">
# <span class="code">448900</span>
# <img alt="코스닥" class="kosdaq" height="16" src="https://ssl.pstatic.net/imgstock/item_renewal/btn_kosdaq.gif" width="33"/>
# <span class="blind">날짜</span>
# <span id="time">
# <em class="date">2025.04.07  13:43 <span>기준(KRX 장중)</span></em>
# </span>
# <em class="realtime">
# <span class="blind">실시간</span>
# </em>
# <em class="summary">
# <a href="#" onclick="togglePannel('summary_lyr'); return false;"></a>
# <span class="blind">기업개요</span>
# <div class="summary_lyr" id="summary_lyr" style="display:none;top:22px;left:0">
# <iframe frameborder="0" height="" id="summary_ifr" name="summary_ifr" scrolling="no" src="" style="position:absolute;left:0;top:-2;z-index:20" width="410"></iframe>
# <div class="summary_info" id="summary_info">
# <h4>기업개요</h4>
# <p>동사는 금속분말사출성형 기술을 바탕으로 소형, 정밀, 복잡한 형상의 금속부품을 제조하여 판매하고 있음.</p>
# <p>첨단 신소재를 MIM 제품에 적용하기 위한 방향으로 연구개발 역량을 집중하고 있으며 기존 MIM에 적용되지 않았던 신소재를 활용한 제품을 개발함으로써 임플란트, 로봇 등 다양한 첨단 분야로 사업을 확대하고 있음.</p>
# <p>2024년 11월 중 기업가치 제고 및 원활한 자금조달과 주식의 유동성 확보를 위해 코스닥시장에 이전상장을 결정함.</p>
# <div class="txt_notice">출처 : 에프앤가이드</div>
# <div class="btn_area_top">
# <a href="#" onclick="hidePannel('summary_lyr'); return false;"><img alt="닫기" height="11" src="https://ssl.pstatic.net/static/nfinance/img/btn_close.gif" width="11"/></a>
# </div>
# <div class="bg_btm"></div>
# </div>
# <span class="bg_lt"></span>
# <span class="bg_rt"></span>
# <div class="bu_arrow"></div>
# </div>
# </em>
# </div>
# </div>
# <div class="quick">
# <p>
# <a class="snb_top1" href="#" onclick="clickcr(this,'sop.2','','',event);"><span class="blind">MY STOCK 추가</span></a>
# <a class="snb_top3" href="javascript:quickorder('on')" onclick="clickcr(this,'sop.3','','',event);"><span class="blind">빠른주문</span></a>
# </p>
# <div class="ly_lstmove blind NE=a:sop*m">
# <span class="bg"></span>
# <div class="txt _ly_group">
# <div class="bx_sel scr_white2 _ly_group_list">
# <ul></ul>
# </div>
# <div class="bx_sel _ly_group_blank" style="display:none;">
# <p class="txt_inner type7">추가할 그룹이 없습니다.<br/>그룹을 추가해주세요.</p>
# </div>
# <p class="rgt">
# <button class="btn_spr btn_groupadd2 NPI=a:add" type="button"><span class="blind">그룹추가</span>
# </button>
# </p>
# <p>
# <button class="btn_spr btn_cfm2 _btn_ok NPI=a:confirm" type="button"><span class="blind">확인</span></button>
# <button class="btn_spr btn_clse2 _btn_cancel NPI=a:close" type="button"><span class="blind">닫기</span></button>
# </p>
# </div>
# <div class="txt _ly_message" style="display:none;">
# </div>
# </div>
# <div class="layer_quick_order" id="quickOrderArea" style="display:none">
# <div class="content">
# <h5>네이버 주식거래연결<br/>빠른 주문을 도와드립니다!</h5>
# <ul>
# <li>본 서비스는 고객님의 빠른 주문을 돕기 위해<br/><span>증권사의 로그인을 연결</span>해드리고 있습니다.</li>
# <li>고객님이 보유하고 계신 증권사를 클릭한 후<br/><span>증권사의 아이디, 비밀번호, 공인인증서로 주문</span>을<br/>하실 수 있습니다.</li>
# <li>증권사 로그인 이후 시스템 문제가 발생하면,<br/><span>증권사 고객센터로 직접 문의</span> 하시기 바랍니다.</li>
# <li>네이버는 증권사 서비스의 시스템 장애에 따른<br/>법적 책임을 지지 않습니다.</li>
# </ul>
# <div class="ci_area">
# <div id="quickOrderCiBanner0"></div>
# <div id="quickOrderCiBanner1"></div>
# <div id="quickOrderCiBanner2"></div>
# <div id="quickOrderCiBanner3"></div>
# </div>
# <div class="btn_area_btm"><a href="javascript:quickorder('off')"><img alt="닫기" height="20" src="https://ssl.pstatic.net/imgstock/item_renewal/btn_close.gif" width="38"/></a></div>
# <div class="btn_area_top"><a href="javascript:quickorder('off')"><img alt="닫기" height="19" src="https://ssl.pstatic.net/imgstock/item_renewal/btn_close_x.gif" width="19"/></a></div>
# </div>
# </div>
# </div>
# </div>
# <div class="content_wrap">
# <div id="content">
# <!-- chart가 사라질때  <div class="spot spot_short">-->
# <!-- KRX, NXT 거래 미대상 일 때 <div class="default spot spot_short"> -->
# <div class="default spot" id="chart_area">
# <div class="rate_info" id="rate_info_krx" style="display: block;">
# <dl class="blind">
# <dt><strong>한국피아이엠</strong></dt>
# <dd>오늘의시세 15,400 포인트</dd>
# <dd>700 포인트 하락</dd>
# <dd>4.35% 마이너스</dd>
# </dl>
# <div class="today">
# <p class="no_today">
# <em class="no_down">
# <span class="blind">15,400</span>
# <span class="no1">1</span><span class="no5">5</span><span class="shim">,</span><span class="no4">4</span><span class="no0">0</span><span class="no0">0</span>
# </em>
# </p>
# <p class="no_exday">
# <span class="sptxt sp_txt1">전일대비</span>
# <em class="no_down">
# <span class="ico down">하락</span>
# <span class="blind">700</span>
# <span class="no7">7</span><span class="no0">0</span><span class="no0">0</span>
# </em>
# <span class="bar">l</span>
# <em class="no_down">
# <span class="ico minus">-</span>
# <span class="blind">4.35</span>
# <span class="no4">4</span><span class="jum">.</span><span class="no3">3</span><span class="no5">5</span>
# <span class="per">%</span>
# </em>
# </p>
# </div>
# <table class="no_info" summary="주요 시세(전일종가, 시고저가, 거래량, 거래대금)을 제공합니다.">
# <caption>주요 시세</caption>
# <colgroup>
# <col/>
# <col width="214"/>
# <col width="157"/>
# </colgroup>
# <tr>
# <td class="first">
# <span class="sptxt sp_txt2">전일</span>
# <em>
# <span class="blind">16,100</span>
# <span class="no1">1</span><span class="no6">6</span><span class="shim">,</span><span class="no1">1</span><span class="no0">0</span><span class="no0">0</span>
# </em>
# </td>
# <td>
# <span class="sptxt sp_txt4">고가</span>
# <em class="no_up">
# <span class="blind">17,720</span><span class="no1">1</span><span class="no7">7</span><span class="shim">,</span><span class="no7">7</span><span class="no2">2</span><span class="no0">0</span>
# </em>
# <span class="sptxt sp_txt6">(상한가</span>
# <em class="no_cha">
# <span class="blind">20,900</span><span class="no2">2</span><span class="no0">0</span><span class="shim">,</span><span class="no9">9</span><span class="no0">0</span><span class="no0">0</span>
# </em>
# <span class="sptxt sp_txt8">)</span>
# </td>
# <td>
# <span class="sptxt sp_txt9">거래량</span>
# <em>
# <span class="blind">6,315,335</span>
# <span class="no6">6</span><span class="shim">,</span><span class="no3">3</span><span class="no1">1</span><span class="no5">5</span><span class="shim">,</span><span class="no3">3</span><span class="no3">3</span><span class="no5">5</span>
# </em>
# </td>
# </tr>
# <tr>
# <td class="first">
# <span class="sptxt sp_txt3">시가</span>
# <em class="no_up">
# <span class="blind">17,040</span><span class="no1">1</span><span class="no7">7</span><span class="shim">,</span><span class="no0">0</span><span class="no4">4</span><span class="no0">0</span>
# </em>
# </td>
# <td>
# <span class="sptxt sp_txt5">저가</span>
# <em class="no_down">
# <span class="blind">15,350</span><span class="no1">1</span><span class="no5">5</span><span class="shim">,</span><span class="no3">3</span><span class="no5">5</span><span class="no0">0</span>
# </em>
# <span class="sptxt sp_txt7">(하한가</span>
# <em class="no_cha">
# <span class="no1">1</span><span class="no1">1</span><span class="shim">,</span><span class="no2">2</span><span class="no7">7</span><span class="no0">0</span>
# </em>
# <span class="sptxt sp_txt8">)</span>
# </td>
# <td>
# <span class="sptxt sp_txt10">거래대금</span>
# <em>
# <span class="blind">105,866</span>
# <span class="no1">1</span><span class="no0">0</span><span class="no5">5</span><span class="shim">,</span><span class="no8">8</span><span class="no6">6</span><span class="no6">6</span>
# </em>
# <span class="sptxt sp_txt11">백만</span>
# </td>
# </tr>
# </table>
# </div>
# <div class="chart">
# <p class="blind">종목 시세 차트</p>
# <div class="chart_control_area">
# <dl class="line">
# <dt>선차트</dt>
# <dd>
# <ul>
# <li class="day"><a class="on" href="#" onclick="showChart('day')">1일</a></li>
# <li class="week"><a href="#" onclick="showChart('week')">1주일</a></li>
# <li class="month3"><a href="#" onclick="showChart('month3');">3개월</a></li>
# <li class="year"><a href="#" onclick="showChart('year');">1년</a></li>
# <li class="year3"><a href="#" onclick="showChart('year3');">3년</a></li>
# <li class="year5"><a href="#" onclick="showChart('year5');">5년</a></li>
# <li class="year10"><a href="#" onclick="showChart('year10');">10년</a></li>
# </ul>
# </dd>
# </dl>
# <dl class="bar">
# <dt>봉차트</dt>
# <dd>
# <ul>
# <li class="day"><a href="#" onclick="showBarChart('day');">일봉</a></li>
# <li class="week"><a href="#" onclick="showBarChart('week');">주봉</a></li>
# <li class="month"><a href="#" onclick="showBarChart('month');">월봉</a></li>
# </ul>
# </dd>
# </dl>
# </div>
# <p class="source">한국거래소(KRX)</p>
# <h5 class="blind">이미지 차트</h5>
# <img alt="이미지 차트" height="289" id="img_chart_area" onerror="this.src='https://ssl.pstatic.net/imgstock/chart3/world2008/error_700x289.png'" src="https://ssl.pstatic.net/imgfinance/chart/item/area/day/448900.png?sidcode=1744001034739" width="700"/>
# </div>
# <a class="btn_close" href="javascript:fchartStatus.showChartArea('448900', '%C7%D1%B1%B9%C7%C7%BE%C6%C0%CC%BF%A5', 'false',false)" onclick="clickcr(this,'sop.toggle','','',event);">
# <div id="btn_close">
# <img alt="차트닫기" height="11" src="https://ssl.pstatic.net/imgstock/item_renewal/btn_lay_close.gif" width="45"/>
# </div>
# </a>
# </div>
# <script id="summaryTpl" type="text/template">
#                     <div class="today">
#                         <p class="no_today">
#                             {if rf == 1 || rf == 2}
#                             <em class="no_up">
#                                 {elseif rf == 4 || rf == 5}
#                                 <em class="no_down">
#                                     {else}
#                                     <em class="X">
#                                         {/if}
#                                         {js numberFont(changeNumberFormat(=nv))}
#                                     </em>
#                         </p>
#                         <p class="no_exday">
#                             <span class="sptxt sp_txt1">전일대비</span>
#                             {if rf == 1}
#                             <em class="no_up">
#                                 <span class="ico up_price">상한가</span>
#                                 {elseif rf == 2}
#                                 <em class="no_up">
#                                     <span class="ico up">상승</span>
#                                     {elseif rf == 4}
#                                     <em class="no_down">
#                                         <span class="ico down_price">하한가</span>
#                                         {elseif rf == 5}
#                                         <em class="no_down">
#                                             <span class="ico down">하락</span>
#                                             {else}
#                                             <em class="X">
#                                                 <span class="ico sam">보합</span>
#                                                 {/if}
#                                                 {js numberFont(changeNumberFormat(=cv))}
#                                             </em>
#
#                                             <span class="bar">l</span>
#                                             {if rf == 1 || rf == 2}
#                                             <em class="no_up">
#                                                 <span class="ico plus">+</span>
#                                                 {elseif rf == 4 || rf == 5}
#                                                 <em class="no_down">
#                                                     <span class="ico minus">-</span>
#                                                     {else}
#                                                     <em class="X">
#                                                         {/if}
#                                                         {if cr != null}
#                                                         {js numberFont(changeNumberFormat(=cr.toFixed(2)))}
#                                                         {/if}
#                                                         <span class="per">%</span>
#                                                     </em>
#                         </p>
#                     </div>
#                     <table summary="주요 시세(전일종가, 시고저가, 거래량, 거래대금)을 제공합니다." class="no_info">
#                         <caption>주요 시세</caption>
#                         <colgroup>
#                             <col>
#                             <col width="214">
#                             <col width="157">
#                         </colgroup>
#                         <tr>
#                             <td class="first">
#                                 <span class="sptxt sp_txt2">전일</span>
#                                 <em>
#                                     {if sv == 0}
#                                     {js numberFont(changeNumberFormat(=pcv))}
#                                     {else}
#                                     {js numberFont(changeNumberFormat(=sv))}
#                                     {/if}
#                                 </em>
#                             </td>
#                             <td>
#                                 <span class="sptxt sp_txt4">고가</span>
#                                 {if tyn == "Y"}
#                                 <em>
#                                     {else}
#                                     {if hv == 0}
#                                     <em>
#                                         {elseif pcv < hv}
#                                         <em class="no_up">
#                                             {elseif pcv > hv}
#                                             <em class="no_down">
#                                                 {else}
#                                                 <em>
#                                                     {/if}
#                                                     {/if}
#                                                     {if ms == "PREOPEN"}
#                                                     {js numberFont(0)}
#                                                     {else}
#                                                     {js numberFont(changeNumberFormat(=hv))}
#                                                     {/if}
#                                                 </em>
#                                                 <span class="sptxt sp_txt6">(상한가</span>
#                                                 <em class="no_cha">
#                                                     {if ms == "PREOPEN"}
#                                                     {js numberFont(0)}
#                                                     {else}
#                                                     {js numberFont(changeNumberFormat(=ul))}
#                                                     {/if}
#                                                 </em>
#                                                 <span class="sptxt sp_txt8">)</span>
#                             </td>
#                             <td>
#                                 <span class="sptxt sp_txt9">거래량</span>
#                                 <em>
#                                     {js numberFont(changeNumberFormat(=aq))}
#                                 </em>
#                             </td>
#                         </tr>
#                         <tr>
#                             <td class="first">
#                                 <span class="sptxt sp_txt3">시가</span>
#                                 {if tyn == "Y"}
#                                 <em>
#                                     {else}
#                                     {if ov == 0}
#                                     <em>
#                                         {elseif pcv < ov}
#                                         <em class="no_up">
#                                             {elseif pcv > ov}
#                                             <em class="no_down">
#                                                 {else}
#                                                 <em>
#                                                     {/if}
#                                                     {/if}
#                                                     {if ms == "PREOPEN"}
#                                                     {js numberFont(0)}
#                                                     {else}
#                                                     {js numberFont(changeNumberFormat(=ov))}
#                                                     {/if}
#                                                 </em>
#                             </td>
#                             <td>
#                                 <span class="sptxt sp_txt5">저가</span>
#                                 {if tyn == "Y"}
#                                 <em>
#                                     {else}
#                                     {if lv == 0}
#                                     <em>
#                                         {elseif pcv < lv}
#                                         <em class="no_up">
#                                             {elseif pcv > lv}
#                                             <em class="no_down">
#                                                 {else}
#                                                 <em>
#                                                     {/if}
#                                                     {/if}
#                                                     {if ms == "PREOPEN"}
#                                                     {js numberFont(0)}
#                                                     {else}
#                                                     {js numberFont(changeNumberFormat(=lv))}
#                                                     {/if}
#                                                 </em>
#                                                 <span class="sptxt sp_txt7">(하한가</span>
#                                                 <em class="no_cha">
#                                                     {if ms == "PREOPEN"}
#                                                     {js numberFont(0)}
#                                                     {else}
#                                                     {js numberFont(changeNumberFormat(=ll))}
#                                                     {/if}
#                                                 </em>
#                                                 <span class="sptxt sp_txt8">)</span>
#                             </td>
#                             <td>
#                                 <span class="sptxt sp_txt10">거래대금</span>
#                                 <em>
#                                     {js numberFont(changeNumberFormat((=aa/1000000).toFixed(0)))}
#                                 </em>
#                                 <span class="sptxt sp_txt11">백만</span>
#                             </td>
#                         </tr>
#                     </table>
#                 </script>
# <script type="text/javascript">
#                   var pollingInterval = 2000;
#                   var timer = null;
#                   var pollingAjax = null;
#                   var itemcodes = '';
#
#                   var startTimer = function () {
#                     clearTimer();
#                     timer = setInterval('doPolling()', pollingInterval);
#                   }
#
#                   var clearTimer = function () {
#                     if (pollingAjax) {
#                       pollingAjax.abort();
#                       pollingAjax = null;
#                     }
#
#                     timer = window.clearInterval(timer);
#                   }
#
#                   var doPolling = function () {
#                     var pollingApiUrl = "https://polling.finance.naver.com/api/realtime?query=SERVICE_ITEM:" + "448900"
#
#                     if (requestType == 'recent' && itemcodes != "") {
#                       pollingApiUrl += "|" + "SERVICE_RECENT_ITEM:" + itemcodes;
#                     } else if (requestType == 'mystock' && itemcodes != "") {
#                       pollingApiUrl += "|" + "SERVICE_MYSTOCK_ITEM:" + itemcodes;
#                     }
#
#                     pollingAjax = jindo.$Ajax(pollingApiUrl, {
#                       type: 'jsonp',
#                       jsonp_charset: "euc-kr",
#                       onload: function (response) {
#                         if (response != null && response.readyState() == 4) {
#                           refreshQuote(response.json());
#                           startTimer();
#                         }
#                       },
#                       timeout: 2,
#                       ontimeout: function () {
#                         startTimer();
#                       },
#                       async: true
#                     });
#                     pollingAjax.request();
#                   }
#
#                   function displayTime (ms, time) {
#                     var result;
#
#                     var utcDate = new Date(time);
#                     utcDate.setMinutes(utcDate.getMinutes() + utcDate.getTimezoneOffset());
#                     utcDate.setHours(utcDate.getHours() + 9);
#
#                     var oDate = jindo.$Date(utcDate);
#
#                     if (ms == "PREOPEN") {
#                       closeDate = oDate.format('Y.m.d')
#                       result = '<em class="date">' + oDate.format('Y.m.d') + ' <span>기준(KRX 개장전)</span></em> ';
#                     } else if (ms == "CLOSE") {
#                       result = '<em class="date">' + closeDate + ' <span>기준(KRX 장마감)</span></em> ';
#                     } else {
#                       closeDate = oDate.format('Y.m.d')
#                       result = '<em class="date">' + oDate.format('Y.m.d H:i') + ' <span>기준(KRX 장중)</span></em> ';
#                     }
#
#                     return result;
#                   }
#
#                   /**
#                    * 우측상단 투자정보 영역 중, NAV 값 갱신
#                    */
#                   function refreshEtfNav (etfNav) {
#                     var elEtfNav = jindo.$Element(jindo.$$.getSingle("#on_board_last_nav"));
#                     if (elEtfNav != null) {
#                       if (etfNav != null) {
#                         elEtfNav.html("<em><strong>" + changeNumberFormat(etfNav.toFixed(0)) + "</strong></em>");
#                       } else {
#                         elEtfNav.html("<em><strong>N/A</strong></em>");
#                       }
#                     }
#                   }
#
#                   function refreshInvestmentSummary (nv) {
#                     if (!(false && false && false))
#                     {
#                       return;
#                     }
#
#                     var averageBuyingPrice = 0;
#                     var holdingShares = 0;
#
#                     var elEvaluationProfitAmount = jindo.$Element(jindo.$$.getSingle("#evaluation_profit_amount"));
#                     // 평가손익 = (nv - 평균매입가) * 보유수량
#                     var evaluationProfitAmount = (nv - 0) * 0;
#                     // 평가수익률 = 평가손익 / (평균매입가 * 보유수량) * 100
#                     var evaluationProfitRate = evaluationProfitAmount / (0 *
#                     0) *
#                     100;
#
#                     var sPointClass = "";
#                     var sSign = "";
#                     if (evaluationProfitAmount > 0) {
#                       sPointClass = "f_up";
#                       sSign = "+";
#                     } else {
#                       sPointClass = "f_down";
#                       sSign = "";
#                     }
#
#                     var evaluationProfitAmoutText = ""
#                     if (evaluationProfitAmount > 10000000000) {
#                       var evaluationProfitAmountDivideBillion = evaluationProfitAmount / 100000000;
#                       evaluationProfitAmountText = "<em>" + sSign + changeNumberFormat(evaluationProfitAmountDivideBillion.toFixed(0)) + "억</em>";
#                     } else {
#                       evaluationProfitAmountText = "<em>" + sSign + changeNumberFormat(evaluationProfitAmount) + "</em>";
#                     }
#
#                     if (elEvaluationProfitAmount != null) {
#                       elEvaluationProfitAmount.removeClass("f_up");
#                       elEvaluationProfitAmount.removeClass("f_down");
#                       elEvaluationProfitAmount.addClass(sPointClass);
#                       elEvaluationProfitAmount.html(evaluationProfitAmountText);
#                     }
#
#                     var elEvaluationProfitRate = jindo.$Element(jindo.$$.getSingle("#evaluation_profit_rate"));
#                     if (elEvaluationProfitRate != null) {
#
#                       elEvaluationProfitRate.removeClass("f_up");
#                       elEvaluationProfitRate.removeClass("f_down");
#                       elEvaluationProfitRate.addClass(sPointClass);
#
#                       elEvaluationProfitRate.html("<em>" + sSign + changeNumberFormat(evaluationProfitRate.toFixed(2)) + "%</em>");
#                     }
#                   }
#
#
#
#                   function refreshCompanyValue (json) {
#                     var sPer = "N/A";
#                     var sKrxPer = "N/A";
#                     /* if ((json.per !== undefined) && (json.per !== null)) {
#                         sPer = converToFixedPointNotation(json.per, 2);
#                     }
#
#                     jindo.$A(jindo.$$("#_per")).forEach(function(v) {
#                         jindo.$Element(v).text(sPer);
#                     }, this); */
#
#                     if ((json.eps !== undefined) && (json.eps !== null)) {
#                       sPer = converToFixedPointNotation(json.nv / json.eps, 2);
#                     }
#
#                     jindo.$A(jindo.$$("#_per")).forEach(function (v) {
#                       jindo.$Element(v).text(sPer);
#                     }, this);
#
#                     if ((json.keps !== undefined) && (json.keps !== null)) {
#                       sKrxPer = converToFixedPointNotation(json.nv / json.keps, 2);
#                     }
#
#                     jindo.$A(jindo.$$("#krx_per")).forEach(function (v) {
#                       jindo.$Element(v).text(sKrxPer);
#                     }, this);
#
#                     var sCnsPer = "N/A";
#                     if ((json.cnsEps !== undefined) && (json.cnsEps !== null)) {
#                       sCnsPer = converToFixedPointNotation(json.nv / json.cnsEps, 2);
#                     }
#
#                     jindo.$A(jindo.$$("#_cns_per")).forEach(function (v) {
#                       jindo.$Element(v).text(sCnsPer);
#                     }, this);
#
#                     var sPbr = "N/A";
#                     if ((json.bps !== undefined) && (json.bps !== null)) {
#                       var bps = converToFixedPointNotation(json.bps, 0)
#                       sPbr = converToFixedPointNotation(json.nv / bps, 2);
#                     }
#
#                     jindo.$A(jindo.$$("#_pbr")).forEach(function (v) {
#                       jindo.$Element(v).text(sPbr);
#                     }, this);
#
#                     var sDvr = "N/A";
#                     if ((json.dv !== undefined) && (json.dv !== null)) {
#                       var dv = converToFixedPointNotation(json.dv, 0)
#                       sDvr = converToFixedPointNotation((dv * 100) / json.nv, 2);
#                     }
#
#                     jindo.$A(jindo.$$("#_dvr")).forEach(function (v) {
#                       jindo.$Element(v).text(sDvr);
#                     }, this);
#                   }
#
#                   function refreshQuote (res) {
#                     if (res != null && res.resultCode == 'success') {
#                       pollingInterval = res.result.pollingInterval;
#
#                       for (var index = 0; index < res.result.areas.length; index++) {
#                         if (res.result.areas[index].name == "SERVICE_ITEM" && res.result.areas[index].datas[0]) {
#                           var ms = "NOT DEFINED";
#                           ms = res.result.areas[index].datas[0].ms;
#                           document.getElementById("time").innerHTML = displayTime(ms, res.result.time);
#
#                           jindo.$Element(jindo.$$.getSingle("#chart_area .rate_info")).html(jindo.$Template("summaryTpl").process(res.result.areas[index].datas[0]));
#
#                           refreshInvestmentSummary(res.result.areas[index].datas[0].nv);
#                           refreshEtfNav(res.result.areas[index].datas[0].nav);
#                           refreshCompanyValue(res.result.areas[index].datas[0]);
#                         } else if (res.result.areas[index].name == "SERVICE_RECENT_ITEM") {
#                           renderRecentAreaRealtime("recent", res.result.areas[index]);
#                         } else if (res.result.areas[index].name == "SERVICE_MYSTOCK_ITEM") {
#                           renderRecentAreaRealtime("mystock", res.result.areas[index]);
#                         }
#                       }
#                     }
#                   }
#
#                   function numberFont (value) {
#                     value = value + "";
#                     var result = "";
#
#                     for (i = 0; i < value.length; i++) {
#                       var tmpChar = value.charAt(i);
#
#                       result += '<span class="';
#                       if (tmpChar == ".") {
#                         result += "jum";
#                       } else if (tmpChar == ",") {
#                         result += "shim";
#                       } else {
#                         result += "no" + tmpChar;
#                       }
#                       result += '">' + tmpChar + '</span>';
#                     }
#
#                     return result;
#                   }
#
#                   function changeNumberFormat (vNumber) {
#                     var sUnderNumber = "";
#                     var sNumberString = vNumber || 0;
#                     sNumberString = (typeof sNumberString != "String") ? String(sNumberString) : sNumberString;
#
#                     if (sNumberString.indexOf(".") > -1) {
#                       var aNumber = sNumberString.split(".");
#                       sNumberString = aNumber[0];
#                       sUnderNumber = "." + aNumber[1];
# ...
# <a href="javascript:showArea('tab_fav', 'tab tab_fav2', 'fav_kosdaq', 'fav_kospi')" onclick="clickcr(this, 'pss.3', '', '', event);"><span>코스닥</span></a>
# <!-- [D] 활성화된 탭메뉴에 따라 blind text 변경해주세요 -->
# <h3 class="blind" id="blind_text_tab_fav">코스피</h3>
# </div>
# <div id="fav_kospi" style="display:block">
# <table class="rank" summary="코스피 인기검색종목 리스트">
# <caption>코스피 인기검색종목</caption>
# <colgroup><col/><col width="60"/><col width="86"/></colgroup>
# <thead>
# <tr>
# <th>업체명</th>
# <th scope="col">거래량</th>
# <th scope="col">전일비</th>
# </tr>
# </thead>
# <tr>
# <th class="no1" scope="row"><a href="/item/main.naver?code=005930" onclick="clickcr(this, 'pss.2', '', '1', event);" target="_top">삼성전자</a></th>
# <td>53,400</td>
# <td>
# <em class="f_down down"><span>하향</span>
# 				2,700
# 				</em>
# </td>
# </tr>
# <tr>
# <th class="no2" scope="row"><a href="/item/main.naver?code=000660" onclick="clickcr(this, 'pss.2', '', '2', event);" target="_top">SK하이닉스</a></th>
# <td>166,900</td>
# <td>
# <em class="f_down down"><span>하향</span>
# 				15,300
# 				</em>
# </td>
# </tr>
# <tr>
# <th class="no3" scope="row"><a href="/item/main.naver?code=042660" onclick="clickcr(this, 'pss.2', '', '3', event);" target="_top">한화오션</a></th>
# <td>62,900</td>
# <td>
# <em class="f_down down"><span>하향</span>
# 				6,400
# 				</em>
# </td>
# </tr>
# <tr>
# <th class="no4" scope="row"><a href="/item/main.naver?code=005380" onclick="clickcr(this, 'pss.2', '', '4', event);" target="_top">현대차</a></th>
# <td>180,800</td>
# <td>
# <em class="f_down down"><span>하향</span>
# 				11,000
# 				</em>
# </td>
# </tr>
# <tr>
# <th class="no5" scope="row"><a href="/item/main.naver?code=012450" onclick="clickcr(this, 'pss.2', '', '5', event);" target="_top">한화에어로스..</a></th>
# <td>639,000</td>
# <td>
# <em class="f_down down"><span>하향</span>
# 				63,000
# 				</em>
# </td>
# </tr>
# <tr><td class="line" colspan="3"></td></tr>
# <tr>
# <th class="no6" scope="row"><a href="/item/main.naver?code=084690" onclick="clickcr(this, 'pss.2', '', '6', event);" target="_top">대상홀딩스</a></th>
# <td>16,830</td>
# <td>
# <em class="f_up up"><span>상향</span>
# 				2,820
# 				</em>
# </td>
# </tr>
# <tr>
# <th class="no7" scope="row"><a href="/item/main.naver?code=034020" onclick="clickcr(this, 'pss.2', '', '7', event);" target="_top">두산에너빌리..</a></th>
# <td>21,050</td>
# <td>
# <em class="f_down down"><span>하향</span>
# 				2,000
# 				</em>
# </td>
# </tr>
# <tr>
# <th class="no8" scope="row"><a href="/item/main.naver?code=066570" onclick="clickcr(this, 'pss.2', '', '8', event);" target="_top">LG전자</a></th>
# <td>68,500</td>
# <td>
# <em class="f_down down"><span>하향</span>
# 				4,300
# 				</em>
# </td>
# </tr>
# <tr>
# <th class="no9" scope="row"><a href="/item/main.naver?code=005490" onclick="clickcr(this, 'pss.2', '', '9', event);" target="_top">POSCO홀딩스</a></th>
# <td>256,000</td>
# <td>
# <em class="f_down down"><span>하향</span>
# 				17,000
# 				</em>
# </td>
# </tr>
# <tr>
# <th class="no10" scope="row"><a href="/item/main.naver?code=004770" onclick="clickcr(this, 'pss.2', '', '10', event);" target="_top">써니전자</a></th>
# <td>3,425</td>
# <td>
# <em class="f_up up"><span>상향</span>
# 				370
# 				</em>
# </td>
# </tr>
# </table>
# </div>
# <div id="fav_kosdaq" style="display:none">
# <table class="rank" summary="코스닥 인기검색종목 리스트">
# <caption>코스피 인기검색종목</caption>
# <colgroup><col/><col width="50"/><col width="86"/></colgroup>
# <thead>
# <tr>
# <th>업체명</th>
# <th scope="col">거래량</th>
# <th scope="col">전일비</th>
# </tr>
# </thead>
# <tr>
# <th class="no1" scope="row"><a href="/item/main.naver?code=053800" onclick="clickcr(this, 'pss.4', '', '1', event);" target="_top">안랩</a></th>
# <td>108,800</td>
# <td>
# <em class="f_up up"><span>상향</span>
# 				14,900
# 				</em>
# </td>
# </tr>
# <tr>
# <th class="no2" scope="row"><a href="/item/main.naver?code=065500" onclick="clickcr(this, 'pss.4', '', '2', event);" target="_top">오리엔트정공</a></th>
# <td>14,575</td>
# <td>
# <em class="f_up up"><span>상향</span>
# 				1,405
# 				</em>
# </td>
# </tr>
# <tr>
# <th class="no3" scope="row"><a href="/item/main.naver?code=298380" onclick="clickcr(this, 'pss.4', '', '3', event);" target="_top">에이비엘바이..</a></th>
# <td>44,250</td>
# <td>
# <em class="f_up up_arrow"><span>상한가</span>
# 				10,200
# 				</em>
# </td>
# </tr>
# <tr>
# <th class="no4" scope="row"><a href="/item/main.naver?code=304100" onclick="clickcr(this, 'pss.4', '', '4', event);" target="_top">솔트룩스</a></th>
# <td>28,600</td>
# <td>
# <em class="f_up up"><span>상향</span>
# 				4,350
# 				</em>
# </td>
# </tr>
# <tr>
# <th class="no5" scope="row"><a href="/item/main.naver?code=052400" onclick="clickcr(this, 'pss.4', '', '5', event);" target="_top">코나아이</a></th>
# <td>42,650</td>
# <td>
# <em class="f_up up"><span>상향</span>
# 				7,550
# 				</em>
# </td>
# </tr>
# <tr><td class="line" colspan="3"></td></tr>
# <tr>
# <th class="no6" scope="row"><a href="/item/main.naver?code=388720" onclick="clickcr(this, 'pss.4', '', '6', event);" target="_top">유일로보틱스</a></th>
# <td>82,200</td>
# <td>
# <em class="f_down down"><span>하향</span>
# 				900
# 				</em>
# </td>
# </tr>
# <tr>
# <th class="no7" scope="row"><a href="/item/main.naver?code=196170" onclick="clickcr(this, 'pss.4', '', '7', event);" target="_top">알테오젠</a></th>
# <td>336,500</td>
# <td>
# <em class="f_down down"><span>하향</span>
# 				26,500
# 				</em>
# </td>
# </tr>
# <tr>
# <th class="no8" scope="row"><a href="/item/main.naver?code=028300" onclick="clickcr(this, 'pss.4', '', '8', event);" target="_top">HLB</a></th>
# <td>55,700</td>
# <td>
# <em class="f_down down"><span>하향</span>
# 				1,900
# 				</em>
# </td>
# </tr>
# <tr>
# <th class="no9" scope="row"><a href="/item/main.naver?code=039240" onclick="clickcr(this, 'pss.4', '', '9', event);" target="_top">경남스틸</a></th>
# <td>8,110</td>
# <td>
# <em class="f_up up_arrow"><span>상한가</span>
# 				1,870
# 				</em>
# </td>
# </tr>
# <tr>
# <th class="no10" scope="row"><a href="/item/main.naver?code=043910" onclick="clickcr(this, 'pss.4', '', '10', event);" target="_top">자연과환경</a></th>
# <td>890</td>
# <td>
# <em class="f_up up"><span>상향</span>
# 				19
# 				</em>
# </td>
# </tr>
# </table>
# </div>
# </div>
# <div class="aside_section rate">
# <h2 class="h_sub sub_tit8"><span>시세정보바로가기</span></h2>
# <h3 class="h3_title">KRX 주요시세</h3>
# <p>
# <a href="/sise/sise_index.naver?code=KOSPI" onclick="clickcr(this, 'quk.2', '', '', event);">코스피</a>
# <a href="/sise/sise_index.naver?code=KOSDAQ" onclick="clickcr(this, 'quk.3', '', '', event);">코스닥</a>
# <a href="/sise/sise_index.naver?code=FUT" onclick="clickcr(this, 'quk.4', '', '', event);">선물</a>
# <a class="end" href="/sise/konex.naver" onclick="clickcr(this, 'quk.konex', '', '', event);">코넥스</a><br/>
# <a href="/sise/sise_index.naver?code=KPI100" onclick="clickcr(this, 'quk.32', '', '', event);">코스피100</a>
# <a href="/sise/sise_index.naver?code=KPI200" onclick="clickcr(this, 'quk.30', '', '', event);">코스피200</a>
# <a class="end" href="/sise/etf.naver" onclick="clickcr(this, 'quk.31', '', '', event);">ETF</a><br/>
# <a href="/sise/sise_index.naver?code=KVALUE" onclick="clickcr(this, 'quk.33', '', '', event);"><strong>코리아밸류업</strong></a>
# <a href="/sise/sise_group.naver?type=upjong" onclick="clickcr(this, 'quk.5', '', '', event);"><strong>업종별</strong></a>
# <a class="end" href="/sise/theme.naver" onclick="clickcr(this, 'quk.6', '', '', event);">테마별</a><br/>
# <a href="/sise/sise_upper.naver" onclick="clickcr(this, 'quk.7', '', '', event);"><strong>상한가</strong></a>
# <a href="/sise/sise_lower.naver" onclick="clickcr(this, 'quk.8', '', '', event);">하한가</a>
# <a href="/sise/sise_rise.naver" onclick="clickcr(this, 'quk.9', '', '', event);">상승</a>
# <a href="/sise/sise_steady.naver" onclick="clickcr(this, 'quk.10', '', '', event);">보합</a>
# <a class="end" href="/sise/sise_fall.naver" onclick="clickcr(this, 'quk.11', '', '', event);">하락</a><br/>
# <a href="/sise/sise_quant.naver" onclick="clickcr(this, 'quk.12', '', '', event);">거래상위</a>
# <a href="/sise/sise_quant_high.naver" onclick="clickcr(this, 'quk.13', '', '', event);"><strong>급증</strong></a>
# <a class="end" href="/sise/sise_quant_low.naver" onclick="clickcr(this, 'quk.14', '', '', event);">급감</a><br/>
# <a href="/sise/sise_high_down.naver" onclick="clickcr(this, 'quk.15', '', '', event);">고가대비급락</a>
# <a class="end" href="/sise/sise_low_up.naver" onclick="clickcr(this, 'quk.16', '', '', event);">저가대비급등</a>
# </p>
# <p>
# <a href="/sise/sise_market_sum.naver" onclick="clickcr(this, 'quk.17', '', '', event);"><strong>시가총액상위</strong></a>
# <a class="end" href="/sise/sise_foreign_hold.naver" onclick="clickcr(this, 'quk.18', '', '', event);">외국인보유현황</a><br/>
# <a href="/sise/sise_deal_rank.naver" onclick="clickcr(this, 'quk.19', '', '', event);">외국인매매</a>
# <a href="/sise/sise_deal_rank.naver?investor_gubun=1000" onclick="clickcr(this, 'quk.19-1', '', '', event);">기관매매</a>
# <a class="end" href="/sise/sise_program.naver" onclick="clickcr(this, 'quk.20', '', '', event);">프로그램매매</a><br/>
# <a href="/sise/management.naver" onclick="clickcr(this, 'quk.21', '', '', event);">관리·감리종목</a>
# <a class="end" href="/sise/sise_new_stock.naver" onclick="clickcr(this, 'quk.22', '', '', event);">신규상장종목</a><br/>
# <a href="/sise/sise_deposit.naver" onclick="clickcr(this, 'quk.23', '', '', event);">증시자금동향</a>
# <a class="end" href="/sise/sise_trans_style.naver" onclick="clickcr(this, 'quk.24', '', '', event);">투자자별매매동향</a>
# </p>
# <p>
# <a href="/sise/item_gap.naver" onclick="clickcr(this, 'quk.25', '', '', event);">갭상승 종목</a>
# <a class="end" href="/sise/item_gold.naver" onclick="clickcr(this, 'quk.26', '', '', event);">골든크로스 종목</a><br/>
# <a href="/sise/item_igyuk.naver" onclick="clickcr(this, 'quk.27', '', '', event);">이격도과열종목</a>
# <a class="end" href="/sise/item_overheating_1.naver" onclick="clickcr(this, 'quk.28', '', '', event);">투자심리과열종목</a><br/>
# <a class="end" href="/sise/item_overheating_2.naver" onclick="clickcr(this, 'quk.29', '', '', event);">상대강도과열종목</a>
# </p>
# <h3 class="h3_title">NXT 주요시세</h3>
# <p class="end">
# <a href="/sise/nxt_sise_market_sum.naver" onclick="clickcr(this, 'direct.cap_nxt', '', '', event);">시가총액</a>
# <a href="/sise/nxt_sise_quant.naver" onclick="clickcr(this, 'direct.toplist_nxt', '', '', event);">거래상위</a>
# <a href="/sise/nxt_sise_rise.naver" onclick="clickcr(this, 'direct.rise_nxt', '', '', event);">상승</a>
# <a class="end" href="/sise/nxt_sise_fall.naver" onclick="clickcr(this, 'direct.fall_nxt', '', '', event);">하락</a>
# </p>
# <a class="more" href="/sise/" onclick="clickcr(this, 'quk.1', '', '', event);">더보기</a>
# <div class="hidden_line"></div>
# </div>
# <div class="aside_section notice">
# <h2 class="h_sub sub_tit10"><span>공지사항</span></h2>
# <ul>
# <li><a href="https://finance.naver.com/notice.naver?noticeId=19675" onclick="clickcr(this, 'ice.2', 'https://finance.naver.com/notice.naver?noticeId=19675', '1', event)">국내 첫 대체거래소(NXT) 시세...</a></li>
# <li><a href="https://finance.naver.com/notice.naver?noticeId=17105" onclick="clickcr(this, 'ice.2', 'https://finance.naver.com/notice.naver?noticeId=17105', '2', event)">PC 증권 해외 종목 검색 도입 ...</a></li>
# <li><a href="" onclick="clickcr(this, 'ice.2', '', '3', event)"></a></li>
# <li><a href="" onclick="clickcr(this, 'ice.2', '', '4', event)"></a></li>
# <li><a href="" onclick="clickcr(this, 'ice.2', '', '5', event)"></a></li>
# </ul>
# <a class="more" href="/notice.naver" onclick="clickcr(this, 'ice.1', '', '', event);">더보기</a>
# </div>
# </div>
# </div>
# </div>
# <div id="footer">
# <ul>
# <li class="first">
# <a href="https://new-m.pay.naver.com/member/terms-policy/naver-financial-service" onclick="clickcr(this, 'fot.service', '', '', event);" target="_blank">이용약관</a>
# </li>
# <li>
# <a href="https://new-m.pay.naver.com/member/terms-policy/privacy" onclick="clickcr(this, 'fot.privacy', '', '', event);" target="_blank"><strong>개인정보처리방침</strong></a>
# </li>
# <li>
# <a href="/rules.naver" onclick="clickcr(this, 'fot.policy', '', '', event);" target="_blank">게시판 운영원칙</a>
# </li>
# <li>
# <a href="https://help.naver.com/alias/contents2/finance/finance_1.naver" onclick="clickcr(this, 'fot.help', '', '', event);" target="_blank">증권 고객센터</a>
# </li>
# </ul>
# <p class="desc">
# 			네이버파이낸셜(주)이 제공하는 금융 정보는 <a class="desc_help" href="javascript:;" onclick="togglePanelFooter('footerPanel0');">콘텐츠 제공업체</a>로부터 받는 투자 참고사항이며, 오류가 발생하거나 지연될 수 있습니다.<br/>
# 			네이버파이낸셜(주)과 콘텐츠 제공업체는 제공된 정보에 의한 투자 결과에 법적인 책임을 지지 않습니다. 게시된 정보는 무단으로 배포할 수 없습니다.
# 		</p>
# <p class="info">국내 증시 기본 데이터는 한국거래소(KRX)에서 제공합니다.</p>
# <address>
# <a class="logo" href="https://www.naverfincorp.com/" onclick="clickcr(this, 'fot.nhn', '', '', event);" target="_blank"><img alt="NAVER FINANCIAL" height="12" src="https://ssl.pstatic.net/static/nfinance/img/logo_financial.png" width="160"/></a>
# </address>
# <div class="provider_layer" id="footerPanel0" onblur="hidePannel('footerPanel0')" style="display:none" tabindex="0">
# <strong class="provider_layer__tit">네이버파이낸셜에 콘텐츠 제공</strong>
# <div class="provider_layer__txt">
# <strong>에프앤가이드</strong> 기업 및 재무정보<br/>
# <strong>KG제로인</strong> 해외 시세, 시장지표 정보<br/>
# <strong>한국예탁결제원</strong> 주주총회일, 전자투표 정보<br/>
# <strong>인포스탁</strong> 국내 테마 정보
# 			</div>
# <div class="provider_layer__info">
# <strong class="provider_layer__tit">네이버에 콘텐츠 제공</strong>
# <div class="provider_layer__txt">
# <strong>코스콤</strong> 국내 시세 정보
# 				</div>
# </div>
# <button class="button_close" onclick="hidePannel('footerPanel0')" type="button">
# <img alt="닫기" height="20" src="https://ssl.pstatic.net/static/nfinance/2022/footer_close.png" width="20"/>
# </button>
# </div>
# </div>
# <script type="text/javascript">
# function isVisible(obj) {
#     if (obj == document) return true
#
#     if (!obj) return false
#     if (!obj.parentNode) return false
#     if (obj.style) {
#         if (obj.style.display == 'none') return false
#         if (obj.style.visibility == 'hidden') return false
#     }
#
#     if (window.getComputedStyle) {
#         var style = window.getComputedStyle(obj, "")
#         if (style.display == 'none') return false
#         if (style.visibility == 'hidden') return false
#     }
#
#     var style = obj.currentStyle
#     if (style) {
#         if (style['display'] == 'none') return false
#         if (style['visibility'] == 'hidden') return false
#     }
#
#     return isVisible(obj.parentNode)
# }
#
# function isChildOf(myobj, containerObj) {
# 	while(myobj != undefined) {
# 		if (myobj == document.body) {
# 			break;
# 		}
# 		if (myobj == containerObj) {
# 			return true;
# 		}
# 		myobj = myobj.parentElement;
# 	}
# 	return false;
# }
#
# function gnbLayerClose(e){
# 	var target = e.target ? e.target : e.srcElement;
# 	if (isVisible(document.getElementById('gnb_service_lyr')) || isVisible(document.getElementById('gnb_notice_lyr')) ||isVisible(document.getElementById('gnb_my_lyr')) ) {
# 		if (!isChildOf(target, document.getElementById('gnb'))) {
# 			gnbAllLayerClose();
# 		}
# 	}
# }
#
# var isIE = (navigator.userAgent.toLowerCase().indexOf("msie")!=-1 && window.document.all) ? true:false;
# if (isIE) {
# 	document.attachEvent('onmousedown', gnbLayerClose);
# } else {
# 	window.addEventListener('mousedown', gnbLayerClose);
# }
#
# function showPannel(layerId){
#     var layer = jindo.$(layerId);
#     layer.style.display='block';
#
#     if (layerId == "summary_lyr") {
#         var layerHeight = jindo.$Element(layer).height();
#         jindo.$Element("summary_ifr").height(layerHeight);
#     }
# }
#
# function hidePannel(layerId){
#     var layer = jindo.$(layerId);
#     layer.style.display='none';
# }
#
# function togglePanelFooter(layerId) {
#     var elTargetLayer = jindo.$Element(jindo.$$.getSingle("#" + layerId));
#
#     if (elTargetLayer != null) {
#         if (elTargetLayer.visible()) {
#             hidePannel(layerId);
#         } else {
#             showPannel(layerId);
#         }
#     }
# }
#
# // add data-useragent
# document.documentElement.setAttribute('data-useragent',navigator.userAgent);
#
# // _replaceNewsLink class 하위의 a 태그 조회 후 redirect
# jindo.$Fn(function () {
# 	jindo.$$("._replaceNewsLink a").forEach(function(ele){
# 		var urls = ele.href.split("?");
# 		if (urls[0].indexOf("/news_read.naver") > 0 || urls[0].indexOf("/newsRead.naver") > 0) {
# 			var param = jindo.$S(urls[1]).parseString();
# 			var oid = param.office_id ? param.office_id : param.officeId;
# 			var aid = param.article_id ? param.article_id : param.articleId;
#
# 			ele.target = "_blank";
# 			ele.href = jindo.$S("https://n.news.naver.com/mnews/article/%s/%s").format(oid, aid);
# 		}
# 	});
# }).attach(document, "domready");
# </script>
# </div>
# </body>
# </html>

# %%
# 종목코드
soup.select_one("dl dd:nth-child(4)").text.split(" ")[1]
# Out:
# '448900'

# %%
# 종목명
soup.select_one("dl dd:nth-child(3)").text.split(" ")[1]
# Out:
# '한국피아이엠'

# %%
soup.select("dl dd")
# Out:
# [<dd>2025년 04월
#          07일 13시
#          43분 기준 장중</dd>,
#  <dd>종목명 한국피아이엠</dd>,
#  <dd>종목코드 448900 코스닥</dd>,
#  <dd>현재가 15,400 전일대비 하락 700
#              마이너스
#              4.35 퍼센트
#          </dd>,
#  <dd>전일가 16,100</dd>,
#  <dd>시가 17,040</dd>,
#  <dd>고가 17,720</dd>,
#  <dd>상한가 20,900</dd>,
#  <dd>저가 15,350</dd>,
#  <dd>하한가 11,270</dd>,
#  <dd>거래량 6,315,335</dd>,
#  <dd>거래대금 105,866백만</dd>,
#  <dd>오늘의시세 15,400 포인트</dd>,
#  <dd>700 포인트 하락</dd>,
#  <dd>4.35% 마이너스</dd>,
#  <dd>
#  <ul>
#  <li class="day"><a class="on" href="#" onclick="showChart('day')">1일</a></li>
#  <li class="week"><a href="#" onclick="showChart('week')">1주일</a></li>
#  <li class="month3"><a href="#" onclick="showChart('month3');">3개월</a></li>
#  <li class="year"><a href="#" onclick="showChart('year');">1년</a></li>
#  <li class="year3"><a href="#" onclick="showChart('year3');">3년</a></li>
#  <li class="year5"><a href="#" onclick="showChart('year5');">5년</a></li>
#  <li class="year10"><a href="#" onclick="showChart('year10');">10년</a></li>
#  </ul>
#  </dd>,
#  <dd>
#  <ul>
#  <li class="day"><a href="#" onclick="showBarChart('day');">일봉</a></li>
#  <li class="week"><a href="#" onclick="showBarChart('week');">주봉</a></li>
#  <li class="month"><a href="#" onclick="showBarChart('month');">월봉</a></li>
#  </ul>
#  </dd>,
#  <dd>매출액-매출원가-판관비</dd>,
#  <dd>지배회상의 지분에 귀속되는 당기순이익</dd>,
#  <dd>종속회사의 지분에 귀속되는 당기순이익</dd>,
#  <dd>조정영업이익/매출액</dd>,
#  <dd>지배주주지분 당기순이익 / (자본총계 - 비지배주주지분)</dd>,
#  <dd>지배주주지분 당기순이익/지배주주 평균발행주식수(우선주+보통주)</dd>,
#  <dd>지배주주지분 귀속 순자산/지배주주 기말발행주식(우선주+보통주)</dd>]

# %%
soup.select_one('div.today span.blind').text.replace(",","")
# Out:
# '15400'

# %%
# 현재가
print(int(soup.select_one("dl dd:nth-child(5)").text.split(" ")[1]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[318], line 2
#       1 # 현재가
# ----> 2 print(int(soup.select_one("dl dd:nth-child(5)").text.split(" ")[1]))
#
# ValueError: invalid literal for int() with base 10: '8,120'

# %%
stcok_info = soup.select_one("dl")

# %%
stock_info[3].split(" ")
# Out:
# ['5']

# %%
# 변동금액 상하락 여부 
soup.select_one("dl dd:nth-child()").text.split(" ")[16]
# Out:
# '마이너스\n'

# %%
# 변동금액
gap = int(soup.select_one("dl dd:nth-child(5)").text.split(" ")[4].replace("\n",""))
if soup.select("dl dd")[3].text.split(" ")[16] == '마이너스\n':
    gap = -gap
else :
    pass
print(gap)
# Out:
# -700

# %%
# 변화율
print(soup.select_one("dl dd:nth-child(5)").text.split(" ")[-10])
# Out:
# 4.35

# %%
pp = float(soup.select("dl dd")[3].text.split(" ")[-10])
if soup.select("dl dd")[3].text.split(" ")[16] == '마이너스\n':
    pp = -pp
else :
    pass
print(pp)
# Out:
# -4.35

# %%
# 전일 가
soup.select("dl dd:nth-child(6)")[0].text.split(" ")[1].replace(",","")
# Out:
# '16,100'

# %%
# 고가
soup.select("dl dd:nth-child(8)")[0].text.split(" ")[1].replace(",","")
# Out:
# '17,720'

# %%
# 상한가
soup.select("dl dd:nth-child(9)")[0].text.split(" ")[1].replace(",","")
# Out:
# '20,900'

# %%
# 저가
soup.select("dl dd:nth-child(10)")[0].text.split(" ")[1].replace(",","")
# Out:
# '15,350'

# %%
# 하한가
soup.select("dl dd:nth-child(11)")[0].text.split(" ")[1].replace(",","")
# Out:
# '11270'

# %%
# 거래량
soup.select("dl dd:nth-child(12)")[0].text.split(" ")[1].replace(",","")
# Out:
# '6315335'

# %%
soup.select("dl dd")
# Out:
# [<dd>2025년 04월
#          07일 13시
#          43분 기준 장중</dd>,
#  <dd>종목명 한국피아이엠</dd>,
#  <dd>종목코드 448900 코스닥</dd>,
#  <dd>현재가 15,400 전일대비 하락 700
#              마이너스
#              4.35 퍼센트
#          </dd>,
#  <dd>전일가 16,100</dd>,
#  <dd>시가 17,040</dd>,
#  <dd>고가 17,720</dd>,
#  <dd>상한가 20,900</dd>,
#  <dd>저가 15,350</dd>,
#  <dd>하한가 11,270</dd>,
#  <dd>거래량 6,315,335</dd>,
#  <dd>거래대금 105,866백만</dd>,
#  <dd>오늘의시세 15,400 포인트</dd>,
#  <dd>700 포인트 하락</dd>,
#  <dd>4.35% 마이너스</dd>,
#  <dd>
#  <ul>
#  <li class="day"><a class="on" href="#" onclick="showChart('day')">1일</a></li>
#  <li class="week"><a href="#" onclick="showChart('week')">1주일</a></li>
#  <li class="month3"><a href="#" onclick="showChart('month3');">3개월</a></li>
#  <li class="year"><a href="#" onclick="showChart('year');">1년</a></li>
#  <li class="year3"><a href="#" onclick="showChart('year3');">3년</a></li>
#  <li class="year5"><a href="#" onclick="showChart('year5');">5년</a></li>
#  <li class="year10"><a href="#" onclick="showChart('year10');">10년</a></li>
#  </ul>
#  </dd>,
#  <dd>
#  <ul>
#  <li class="day"><a href="#" onclick="showBarChart('day');">일봉</a></li>
#  <li class="week"><a href="#" onclick="showBarChart('week');">주봉</a></li>
#  <li class="month"><a href="#" onclick="showBarChart('month');">월봉</a></li>
#  </ul>
#  </dd>,
#  <dd>매출액-매출원가-판관비</dd>,
#  <dd>지배회상의 지분에 귀속되는 당기순이익</dd>,
#  <dd>종속회사의 지분에 귀속되는 당기순이익</dd>,
#  <dd>조정영업이익/매출액</dd>,
#  <dd>지배주주지분 당기순이익 / (자본총계 - 비지배주주지분)</dd>,
#  <dd>지배주주지분 당기순이익/지배주주 평균발행주식수(우선주+보통주)</dd>,
#  <dd>지배주주지분 귀속 순자산/지배주주 기말발행주식(우선주+보통주)</dd>]

# %%
stock_list = []
for stock_info in soup:
    # 종목코드
    code = int(stock_info.select("dl dd:nth-child(4)").text.split(" ")[1])
    # 종목명
    company = stock_info.select("dl dd")[1].text.split(" ")[1]
    # 현재가
    now = int(stock_info.select("dl dd")[3].text.split(" ")[1].replace(",",""))
    # 변동금액
    gap = int(stock_info.select("dl dd")[3].text.split(" ")[4].replace("\n",""))
    if stock_info.select("dl dd")[3].text.split(" ")[16] == '마이너스\n':
        gap = -gap
    else :
        pass
    # 변화율
    pp = float(stock_info.select("dl dd")[3].text.split(" ")[-10])
    if stock_info.select("dl dd")[3].text.split(" ")[16] == '마이너스\n':
        pp = -pp
    else :
        pass
    # 전일 가
    eve_price = int(stock_info.select("dl dd")[4].text.split(" ")[1].replace(",",""))
    # 고가
    high = int(stock_info.select("dl dd")[6].text.split(" ")[1].replace(",",""))
    # 상한가
    mn = int(stock_info.select("dl dd")[7].text.split(" ")[1].replace(",",""))
    # 저가
    nn = int(stock_info.select("dl dd")[8].text.split(" ")[1].replace(",",""))
    # 하한가
    lower = int(stock_info.select("dl dd")[9].text.split(" ")[1].replace(",",""))
    # 거래량
    volume = int(stock_info.select("dl dd")[10].text.split(" ")[1].replace(",",""))
    stock_list.append((code, company, now, gap, pp, eve_price, high, mn, nn,lower, volume ))
    
print(stock_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[250], line 4
#       1 stock_list = []
#       2 for stock_info in soup:
#       3     # 종목코드
# ----> 4     code = int(stock_info.select("dl dd:nth-child(4)").text.split(" ")[1])
#       5     # 종목명
#       6     company = stock_info.select("dl dd")[1].text.split(" ")[1]
#
# File ~\miniforge3\envs\fintech\lib\site-packages\bs4\element.py:2877, in ResultSet.__getattr__(self, key)
#    2875 def __getattr__(self, key: str) -> None:
#    2876     """Raise a helpful exception to explain a common code fix."""
# -> 2877     raise AttributeError(
#    2878         f"""ResultSet object has no attribute "{key}". You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?"""
#    2879     )
#
# AttributeError: ResultSet object has no attribute "text". You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
for stock_info in soup:
    # 종목코드
    print(int(stock_info.select("dl.blind > dd")[2].text.split(" ")[1]))
# Out:
# 448900
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[216], line 3
#       1 for stock_info in soup:
#       2     # 종목코드
# ----> 3     print(int(stock_info.select("dl dd")[2].text.split(" ")[1]))
#
# AttributeError: 'NavigableString' object has no attribute 'select'

# %%
final_result =[]

import time


for idx, code in enumerate(stock_code[1000:]):
    print( f"{idx+1}/{len(stock_code[1000:])} 작성중")
    
    url = "https://finance.naver.com/item/main.naver"
    payload = dict(code=code)
    r = requests.get(url, params=payload)
    data = r.content
    data
    soup = bs(data, "lxml")
    
    # 종목명
    stock_name = soup.select_one("dl dd:nth-child(3)").text[4:]
    # 현재가
    today_price = int(soup.select_one("dl dd:nth-child(5)").text.split(" ")[1].replace(",",""))
    # 변동금액
    gap = int(soup.select_one("dl dd:nth-child(5)").text.split(" ")[4].replace("\n","").replace(",",""))
    if soup.select("dl dd")[3].text.split(" ")[16] == '마이너스\n':
        gap = -gap
    else :
        pass
    # 변화율
    pp = float(soup.select("dl dd")[3].text.split(" ")[-10])
    if soup.select("dl dd")[3].text.split(" ")[16] == '마이너스\n':
        pp = -pp
    else :
        pass
    # 전일 가
    eve_price = int(soup.select_one("dl dd:nth-child(6)").text.split(" ")[1].replace(",",""))
    # 고가
    int(soup.select_one("dl dd:nth-child(8)").text.split(" ")[1].replace(",",""))
    # 고가
    high = int(soup.select_one("dl dd:nth-child(9)").text.split(" ")[1].replace(",",""))
    # 상한가
    top = int(soup.select_one("dl dd:nth-child(10)").text.split(" ")[1].replace(",",""))
    # 저가
    low = int(soup.select_one("dl dd:nth-child(11)").text.split(" ")[1].replace(",",""))
    # 하한가
    bottom = int(soup.select_one("dl dd:nth-child(12)").text.split(" ")[1].replace(",",""))
    # 거래량
    volume = int(soup.select("dl dd:nth-child(12)")[0].text.split(" ")[1].replace(",",""))
    
    value = (code, stock_name, today_price, gap, pp, eve_price, high, top, low,bottom, volume )
    final_result.append(value)

    culumn = ('종목코드','종목명', '현재가', '변동금액', '변화율','전일가', '고가','상한가','저가', '하한가','거래량')
    df = pd.DataFrame(final_result, columns = column)
    time.sleep(5)
df
# Out:
# 1/1761 작성중
# 2/1761 작성중
# 3/1761 작성중
# 4/1761 작성중
# 5/1761 작성중
# 6/1761 작성중
# 7/1761 작성중
# 8/1761 작성중
# 9/1761 작성중
# 10/1761 작성중
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[329], line 17
#      14 soup = bs(data, "lxml")
#      16 # 종목명
# ---> 17 stock_name = soup.select_one("dl dd:nth-child(3)").text[4:]
#      18 # 현재가
#      19 today_price = int(soup.select_one("dl dd:nth-child(5)").text.split(" ")[1].replace(",",""))
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
stock_list= []


# 종목명
stock_name = soup.select_one("dl dd:nth-child(3)").text.split(" ")[1]
# 현재가
today_price = int(soup.select_one("dl dd:nth-child(5)").text.split(" ")[1].replace(",",""))
# 변동금액
gap = int(soup.select_one("dl dd:nth-child(5)").text.split(" ")[4].replace("\n",""))
if soup.select("dl dd")[3].text.split(" ")[16] == '마이너스\n':
    gap = -gap
else :
    pass
# 변화율
pp = float(soup.select("dl dd")[3].text.split(" ")[-10])
if soup.select("dl dd")[3].text.split(" ")[16] == '마이너스\n':
    pp = -pp
else :
    pass
# 전일 가
eve_price = int(soup.select_one("dl dd:nth-child(6)").text.split(" ")[1].replace(",",""))
# 고가
high = int(soup.select_one("dl dd:nth-child(8)").text.split(" ")[1].replace(",",""))
# 상한가
top = int(soup.select_one("dl dd:nth-child(9)").text.split(" ")[1].replace(",",""))
# 저가
low = int(soup.select_one("dl dd:nth-child(10)").text.split(" ")[1].replace(",",""))
# 하한가
bottom = int(soup.select_one("dl dd:nth-child(11)").text.split(" ")[1].replace(",",""))
# 거래량
volume = int(soup.select_one("dl dd:nth-child(12)").text.split(" ")[1].replace(",",""))
stock_list.append((stock_code[0], stock_name, today_price, gap, pp, eve_price, high, top, low,bottom, volume ))
print(stock_list)
# Out:
# [('448900', '한국피아이엠', 15400, -700, -4.35, 16100, 17720, 20900, 15350, 11270, 6315335)]

# %% [markdown]
# # 데이터 수집과 동시에 DB에 저장하기

# %%
from datetime import datetime
today = datetime.today()
date = f"{today.year}_{today.month:02d}"
print(date)
# Out:
# 2025_04

# %%
engine = create_engine("mysql+pymysql://root:0308@localhost:3306/stock_info")
conn = engine.connect()
df.to_sql(f"stock_price_{date}", com=conn, if_exists="append")
conn_close
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 engine = create_engine("mysql+pymysql://root:0308@localhost:3306/stock_info")
#       2 conn = engine.connect()
# ----> 3 df.to_sql(f"stock_price_{date}", com=conn, if_exists="append")
#       4 conn_close
#
# NameError: name 'df' is not defined

# %%
for idx, code in enumerate(stock_code):
    
    url = "https://finance.naver.com/item/main.naver"
    payload = dict(code=code)
    r = requests.get(url, params=payload)
    print(r.status_code, f"{idx}/{len(stock_code)-1} 작업중", end="\r")
    data = r.content
    data
    soup = bs(data, "lxml")
    
    # 종목명
    stock_name = soup.select_one("dl dd:nth-child(3)").text.split(" ")[1]
    # 현재가
    today_price = int(soup.select_one("dl dd:nth-child(5)").text.split(" ")[1].replace(",",""))
    # 변동금액
    gap = int(soup.select_one("dl dd:nth-child(5)").text.split(" ")[4].replace("\n","").replace(",",""))
    if soup.select("dl dd")[3].text.split(" ")[16] == '마이너스\n':
        gap = -gap
    else :
        pass
    # 변화율
    pp = float(soup.select("dl dd")[3].text.split(" ")[-10])
    if soup.select("dl dd")[3].text.split(" ")[16] == '마이너스\n':
        pp = -pp
    else :
        pass
    # 전일 가
    eve_price = int(soup.select_one("dl dd:nth-child(6)").text.split(" ")[1].replace(",",""))
    # 고가
    int(soup.select_one("dl dd:nth-child(8)").text.split(" ")[1].replace(",",""))
    # 고가
    high = int(soup.select_one("dl dd:nth-child(9)").text.split(" ")[1].replace(",",""))
    # 상한가
    top = int(soup.select_one("dl dd:nth-child(10)").text.split(" ")[1].replace(",",""))
    # 저가
    low = int(soup.select_one("dl dd:nth-child(11)").text.split(" ")[1].replace(",",""))
    # 하한가
    bottom = int(soup.select_one("dl dd:nth-child(12)").text.split(" ")[1].replace(",",""))
    # 거래량
    volume = int(soup.select("dl dd:nth-child(12)")[0].text.split(" ")[1].replace(",",""))
    
    value = (code, stock_name, today_price, gap, pp, eve_price, high, top, low,bottom, volume )
    column = ['종목코드','종목명', '현재가', '변동금액', '변화율','전일가', '고가','상한가','저가', '하한가','거래량']
    df = pd.DataFrame([value], columns=column)
    #오늘 기준 연도, 달 출력
    year, month = year_month()
    # data data 쿼리창 오픈
    conn = dbconnect()
    df.to_sql(f'stock_price_{year}_{month:02d}', con=conn,  if_exists="append", index=False)
    conn.close()
    print(f"{idx+1}/{len(stock_code)}{stock_name}db저장완료 ", end="\r")
    time.sleep(5)
# Out:
# 83/2761셀비온db저장완료  Љdb저장완료 료
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[343], line 52
#      50 conn.close()
#      51 print(f"{idx+1}/{len(stock_code)}{stock_name}db저장완료 ", end="\r")
# ---> 52 time.sleep(5)
#
# KeyboardInterrupt:

# %%
def year_month():
    from datetime import datetime
    today = datetime.today()
    return today.year, today.month

# %%
year_month()
# Out:
# (2025, 4)

# %%
def dbconnect():
    engine = create_engine("mysql+pymysql://root:0308@localhost:3306/stock_info")
    conn = engine.connect()
    return conn

# %% [markdown]
# # 함수형 프로그래밍으로 코드 변경하기

# %%
def dbconnect():
    engine = create_engine("mysql+pymysql://root:0308@localhost:3306/stock_info")
    conn = engine.connect()
    return conn

# %%
def year_month():
    from datetime import datetime
    today = datetime.today()
    return today.year, today.month

# %%
def stock_info_get(code):
    
    url = "https://finance.naver.com/item/main.naver"
    print( f"{idx+1}/{len(stock_code-1)} 작성중")
    payload = dict(code=code)
    r = requests.get(url, params=payload)
    data = r.content
    data
    soup = bs(data, "lxml")
    
    # 종목명
    stock_name = soup.select_one("dl dd:nth-child(3)").text.split(" ")[1]
    # 현재가
    today_price = int(soup.select_one("dl dd:nth-child(5)").text.split(" ")[1].replace(",",""))
    # 변동금액
    gap = int(soup.select_one("dl dd:nth-child(5)").text.split(" ")[4].replace("\n","").replace(",",""))
    if soup.select("dl dd")[3].text.split(" ")[16] == '마이너스\n':
        gap = -gap
    else :
        pass
    # 변화율
    pp = float(soup.select("dl dd")[3].text.split(" ")[-10])
    if soup.select("dl dd")[3].text.split(" ")[16] == '마이너스\n':
        pp = -pp
    else :
        pass
    # 전일 가
    eve_price = int(soup.select_one("dl dd:nth-child(6)").text.split(" ")[1].replace(",",""))
    # 고가
    int(soup.select_one("dl dd:nth-child(8)").text.split(" ")[1].replace(",",""))
    # 고가
    high = int(soup.select_one("dl dd:nth-child(9)").text.split(" ")[1].replace(",",""))
    # 상한가
    top = int(soup.select_one("dl dd:nth-child(10)").text.split(" ")[1].replace(",",""))
    # 저가
    low = int(soup.select_one("dl dd:nth-child(11)").text.split(" ")[1].replace(",",""))
    # 하한가
    bottom = int(soup.select_one("dl dd:nth-child(12)").text.split(" ")[1].replace(",",""))
    # 거래량
    volume = int(soup.select("dl dd:nth-child(12)")[0].text.split(" ")[1].replace(",",""))
    
    value = (code, stock_name, today_price, gap, pp, eve_price, high, top, low,bottom, volume )
    column = ['종목코드','종목명', '현재가', '변동금액', '변화율','전일가', '고가','상한가','저가', '하한가','거래량']
    df = pd.DataFrame([value], columns=column)
    time.sleep(5)
    return df, stock_name

# %%
from dbio import *

# %%
stock_code = stock_codes()
for idx, code in enumerate(stock_code):
    print( f"{idx}/{len(stock_code)-1} {code} 작성중", end="\r")
    df, stock_name = stock_info_get(code)
    to_stock_db(idx, code , df, stock_name)
# Out:
# 0/2760 448900 작성중
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\ops\array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\computation\expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\computation\expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       2 for idx, code in enumerate(stock_code):
#       3     print( f"{idx}/{len(stock_code)-1} {code} 작성중", end="\r")
# ----> 4     df, stock_name = stock_info_get(code)
#       5     to_stock_db(idx, code , df, stock_name)
#
# Cell In[7], line 4, in stock_info_get(code)
#       1 def stock_info_get(code):
#       3     url = "https://finance.naver.com/item/main.naver"
# ----> 4     print( f"{idx+1}/{len(stock_code-1)} 작성중")
#       5     payload = dict(code=code)
#       6     r = requests.get(url, params=payload)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\arraylike.py:194, in OpsMixin.__sub__(self, other)
#     192 @unpack_zerodim_and_defer("__sub__")
#     193 def __sub__(self, other):
# --> 194     return self._arith_method(other, operator.sub)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\series.py:6135, in Series._arith_method(self, other, op)
#    6133 def _arith_method(self, other, op):
#    6134     self, other = self._align_for_op(other)
# -> 6135     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\base.py:1382, in IndexOpsMixin._arith_method(self, other, op)
#    1379     rvalues = np.arange(rvalues.start, rvalues.stop, rvalues.step)
#    1381 with np.errstate(all="ignore"):
# -> 1382     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1384 return self._construct_result(result, name=res_name)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\ops\array_ops.py:283, in arithmetic_op(left, right, op)
#     279     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     281     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     282     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 283     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     285 return res_values
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\ops\array_ops.py:227, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 except TypeError:
#     220     if not is_cmp and (
#     221         left.dtype == object or getattr(right, "dtype", None) == object
#     222     ):
#    (...)
#     225         # Don't do this for comparisons, as that will handle complex numbers
#     226         #  incorrectly, see GH#32047
# --> 227         result = _masked_arith_op(left, right, op)
#     228     else:
#     229         raise
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\ops\array_ops.py:182, in _masked_arith_op(x, y, op)
#     179         mask = np.where(y == 1, False, mask)
#     181     if mask.any():
# --> 182         result[mask] = op(xrav[mask], y)
#     184 np.putmask(result, ~mask, np.nan)
#     185 result = result.reshape(x.shape)  # 2D compat
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'
