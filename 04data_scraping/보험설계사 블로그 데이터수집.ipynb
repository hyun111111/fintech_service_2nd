# %%
import pandas as pd
import numpy as np
import os

# %%
data = pd.read_csv("C:/Users/Admin/Documents/카카오톡 받은 파일/cleaned_text_all.csv")
data
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 data = pd.read_csv("C:/Users/Admin/Documents/카카오톡 받은 파일/cleaned_text_all.csv")
#       2 data
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\io\parsers\readers.py:1898, in TextFileReader._make_engine(self, f, engine)
#    1895     raise ValueError(msg)
#    1897 try:
# -> 1898     return mapping[engine](f, **self.options)
#    1899 except Exception:
#    1900     if self.handles is not None:
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File parsers.pyx:574, in pandas._libs.parsers.TextReader.__cinit__()
#
# File parsers.pyx:663, in pandas._libs.parsers.TextReader._get_header()
#
# File parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2053, in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc0 in position 61: invalid start byte

# %%
pd.set_option('display.max_colwidth', None)

# %%
data['content']
# Out:
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ​\n요즘 부업이나 자격증에 대한 관심이 높아지면서, 보다 안정적이면서도 전문성을 가진 부업을 찾는 분들이 많습니다. \n​\n그중에서도 보험설계사 자격증은 높은 수입을 만들어 낼 수 있는 상방이 열려있고, 시간을 자유롭게 활용할 수 있어 주목받고 있죠. 저 역시 새로운 도전이자 부업으로서의 가능성을 살펴보다가 도전하게 되었는데요. \n​\n이번 포스팅에서는 제가 보험설계사를 선택하게 된 이유와 공부 방법, 그리고 실제 시험에 합격한 경험까지 자세히 공유해 보려고 합니다.  부업을 고려 중이거나 해당 자격증에 관심이 있는 분들이라면 우선 가볍게 읽어보세요.\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n보험설계사에 도전한 이유\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n우선, 제가 보험설계사를 취득하는데 도전하리라고는 상상조차 안했는데, 결국은 얼마전 손해보험 설계사 자격증에 합격했습니다.\n​\n기회는 우연하게 다가왔는데요. 아버지가 임파선암이 의심된다는 병원측 교수님의 말씀에,  현실적인 부분들이 있다보니 엄마께서 치료 비용 때문에 걱정을 많이 하셨어요. \n​\n그 모습을 보면서 경제적인 부분에 대한 걱정이 없다면, 환자를 우선순위로 둘텐데 어쩔 수 없구나~라고 현실을 자각하면서 한편으로는 아버지가 가입하신 보험들에 대해 모두 찾아봐야겠다고 생각했죠.\n​\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n​\n체크해 보니 다행히도 암보험에 가입해두셨더라구요. 하지만, 만기가 2개월만 남은 상태라는것! 2개월안에 확실히 진단이 떨어져야하는데, 마음이 급했어요. 그래서 최대한 병원의 진료 일정을 빠르게 잡고 진단이 나올 수 있게 도와드려서 결과적으로는 진단금으로 3,000만원을 지급받게 됐습니다.\n​\n물론, 첫 암환자로 분류되어 산정특례 대상자로 본인부담금의 치료비가 적게 청구되어 엄마가 그정도까지 걱정하실 정도는 아니었는데 3,000만원이 나온다는 소식을 전해드리니 두분다 심리적으로 안도하셔서 다행이었죠.\n​\n해당 비용으로 치료를 잘 받으시고 현재는 정기적으로 검진을 받고 있는 상황인데요. 불현듯 아 나는 암보험이 없는데  ...
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     한국기독교연합회관\n\n\n서울특별시 종로구 김상옥로 30\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n2024년 7월 합격증\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n손보 87점\n제3보 87점\n​\n60점 커트라인 인데\n공부 넘 열심히 했나요?\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n2021년 3월 합격증\n​\n안녕하세요.\n나는 2026년에 매월 천만원 벌고\n경제적 자유 이루었다.\n진인사w 입니다.\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n​\n손해보험설계사 시험을\n보았습니다.\n​\n1차에\n 합격을 했어요.\n​\n2021년도에 합격한 적이 있어요.\n부수입을 얻기 위해\n시험을 치뤘죠.\n​\n그때도\n생명보험\n손해보험\n제3보험\n모두 합격했어요~\n​\n불과 3년전에 시험을 쳤고\n어느 정도 자신이 있었어요...\n근데 왠걸!\n시험이 쉽지 않았습니다.\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n​\n시험 합격 세가지 말씀\n드릴께요.\n​\n1. 모의고사 문제 풀기\n2. 유튜브 기출문제 강의 듣기\n3. 요약집 보기\n​\n제가 선택한 세가지 방법입니다.\n​\n공부기간은 7일 입니다.\n​\n하루에는\n2시간 이상해야 함니다.\n​\n시험 3일전에는\n8시간 이상 하는게 좋을 것 같아요.\n​\n물론\n외우는데 자신 있다고\n생각하신 분들은\n더 짧게 하시면 되고\n​\n만약 느긋하게 하나씩\n알아가신다고 한다면\n2주~3주는 해야겠네요!\n​\n​\n​\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n손해보험설계사 시험\n결코 만만하지 않다!\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n요즘 모든 자격증 시험이 점점\n난이도가 높아지는 것 같아요!\n​\n2014년도에\n생명보험을 합격했고\n문제가 그렇게 어렵진 않았던 것 같아요\n​\n2021년도에\n생명보험\n손해보험\n제3보험\n요것도 그냥 풀었던 것 같아요.\n​\n근데\n2024년\n모의고사 보자마자\n머 이래?\n​\n진짜 거의 모르겠다\n수준이였습니다.\n​\n나름 보험을 잘 안다고\n생각했는데...\n​\n공인중개사도 10월 26일이라\n얼마 안 남았고\n​\n육아에\n살림에\n시간을 쪼개서\n시험공부를 했어요.\n​\n예전에 획득한 유경험자니\n하루 이틀 집중해서\n보자고 생각했는데\n아니었습니다.\n​\n​\n​\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n1. 모의고사 문제 풀기\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n진인사w는 \n한화손해보험설계사가 되기 위해\n시험을 보았어요.\n​\n지점장님\n교육팀장님\n소개해준 분이(20년차 보험설계사)\n있었어요.\n​\n메리츠파트너스를 지원했는데\n지인과 소통하다가\n지인이 자기가 일하는 회사로\n오라고 해서 가게 되었어요.\n​\n제가 시험 보는 방법은\n요약집을 먼저 보지 않아요.\n​\n모의고사 시험을 보고\n풀었어요.\n​\n문제 보고 답 보고 \n그렇게 풀었습니다.\n​\n모의고사 문제집이에\n모의고사가 20회 정도 있었어요.\n​\n​\n​\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n1일차는\n모의고사 1회를 \n문제 보고\n해설지를 보았어요.\n​\n문제를 푼 것이 아니라\n답을 외웠죠.\n​\n​\n​\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n2일차는\n2회 3회를\n했어요.\n​\n3일차는 사정이 있어 못했어요\n​\n​\n​\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n4일차는\n해밀도서관에서\n4회를 풀었어요\n​\n​\n​\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n5일차는\n근처 무인카페가서\n새벽 4시~7시까지\n5회 ~ 6회\n10회를 보았고\n​\n​\n​\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n6일차는\n11회 ~ 14회를 풀었던 \n것 같아요.\n​\n아침 7~12시까지\n원미도서관에서 공부했고\n원래 더 하려고 했는데\n집안일로 인해 못했어요\ ...
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          보험설계사 자격증, 직장인 부업으로 도전한 현실 후기\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n​\n안녕하세요! 수댕입니다 :)\n요즘 부업에 관심 가지는 분들 많으시죠?\n저도 그중 한 명으로, \n직장인 부업\n으로 \n보험설계사 자격증\n에 도전했고 \n시험에 합격\n했습니다.\n오늘은 저처럼 부업이나 투잡을 고민 중인 분들을 위해\n보험설계사 시험 준비부터 합격까지의 과정\n을 솔직하게 \n공유드릴게요.\n​\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n보험설계사 부업 도전한 이유\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n저는 20대 중반에 부모님께서 들어놨던 제 보험을 처음 살펴보게 되었고, 그때 당시 보험에 대해 공부한 후 기존보험 \n일부 정리 후 제 선택으로 특약을 구성해 가입을 했었어요. \n( 부모님도 보험내용에 관해 잘 모르셨고 지인 계약이라 제대로 설명못들은 채로 가입하심) \n​\n그리고 시간이 흘러 결혼을 하게되고 보험료 체크를 위해 제 보험과 남편 보험을 살펴보게 됩니다. \n남편또한 보험내용은 잘 몰랐고 부모님이 들어준 그대로 \n결혼 후 넘겨 받았습니다. \n보험료가 적지 않아지만 그만큼 보장이 든든하면 남은 금액만 잘 내면 된다고 생각했었습니다.\n자세히 알아보기위해 보험료 분석을 의뢰 했고 20대 후반의 나이에 종합보험,암보험 등 3가지 보험이 특약 포함해 모두\n 갱신형\n으로 가입되어 있었습니다.\n( 갱신형이 무조건 나쁜건 아닙니다!) \n​\n병력 없는 건강체인 2\n0대인 남편에게는 적합하지 않은\n보험\n이였어요. 어느정도 보험에 관심이 있었기\n때문에  ...
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ​\n​\n안녕하세요 하루쌤입니다! \n​\n따끈따끈한\n손해보험 설게사 자격시험\n합격후기 가져왔어요 \n​\n좋은 건 바로 자랑해야지 ~~~~ \n​\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n​\n​\n​\n​\n저는 목포 TC 지점 / 센터 소속이구요!\n​\n​\n목포 포함 전남권은 전부 다 \n'광주'\n 에서 시험을 보게 됩니다\n​\n​\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n​\n​\n​\n혹시 \n시험 준비 과정이 궁금하시다면\n하단 블로그 내용 확인해주세요 :) \n​\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n손해보험설계사 준비한다면? 자격시험 준비방법 (목포DB손해보험 / BTC 과정)\n\n\n안녕하세요 하루쌤입니다! 이번에 보험스쿨 후기를 적었는데 꽤나 많은분들이 관심을 보이시더라구요? 🫢...\n\n\nblog.naver.com\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n​\n​\n​\n두근 두근 시험 당일\n🙏🏻\n​\n2025년 3월 26일 \n(이 글을 쓰는 오늘..) \n시험 봤습니다! \n​\n​\n​\n목포지점에서 대략 2주간 \nBTC 과정으로 시험 준비를 했어요! \n​\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nPrevious image\n\n\nNext image\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n​\n하루도 안빠지고 열심히 출석했다는 기록 \n​\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n​\n​\n시험에 대해 궁금해하실 것 같은 부분들\n정리해서 올려보도록 하겠습니다! \n​\n​\n​\n​\n​\n​\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n시험 장소는 어디인가요?\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n오션빌딩3\n\n\n광주광역시 서구 상무중앙로 44\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n​\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n​\n​\n▪️ 시험장소 \n광주광역시 서구 상무중앙로 44\n(오션빌딩3 / 4층) \n​\n​\n▪️ 주차 \n시험 당일 건물 주차 불가능 \n주변에 있는 유료 주차장 이용 추천 \n(전 \n근처 스마일주차빌딩 주차장\n 이용했어요) \n​\n갓길 주차는 단속을 한다고하니 주의하시길 바랍니다! \n​\n​\n​\n​\n​\n​\n​\n ...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   1. 셀프로 준비하는 보험설계사 시험\n5월부터 쉬면서 보험설계사를 따야겠다고 생각했다\n주 목적은 내 보험과 가족 보험을 들어주기 위함\n시간도 많고 언젠가 활용도가 있을까 하는 기대가 있어서 했다\n어렵지 않고 부업으로 돈도 벌 수 있다\n​\n예전에는 보험회사를 통해서만 시험을 볼 수 있어서 귀찮았다\n대리점 가서 시험자료 받고 시험접수 하는거면 안했을거같다 \n이제는 모든 걸 어플로 할 수 있다\n​\n나는 롯데손해보험 원더 어플을 통해서 보험설계사를 준비했다\n시험자료도 어플에서 다운받고, 모의고사도 어플에서 풀고, 시험접수도 어플에서 한다\n비대면으로 방구석에서 모든걸 할 수 있다 물론 시험은 시험장 가서 본다\n​\n현재 이런 서비스를 하는건 롯데와 메리츠 두 곳으로 알고 있다\n메리츠는 안해봐서 정확히 모르지만 유사한 시스템일 듯하다\n​\n​\n2. 롯데손해보험 원더 vs 메리츠 파트너스, 혜택 및 지원금 비교\n롯데 원더는 합격시 25만원 / 월2만원계약시 25만원 / 월7만원계약시 25만원을 준다\n최대 75만원이고 상품권이 아니라 현금이다\n셀프 가입 목적으로 하면 월2만원은 할 만해도 월7만원은 어려울 수 있다\n기존에 아예 보험이 없던 사람은 7만원 채울만 한거 같은데, 나 같은 경우는 기존 보험이 있어서 3만원 정도만 추가가입했다\n가족까지 가입시킬거면 월7만원해서 75만원 받을 수 있을 듯하다\n​\n메리 ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...                                                                                                                                                                                                                                     ...
# 65                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 66                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 67    https://m.blog.naver.com/eunha523/223881061943\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n셤합격후기(feat.손보/흥미)\n\n\n주말께 맹구랑 손보설계셤 공부했었음. 요셤이랑 나중에 행정사자격증 따는 게 목표. 4일 바짝했나?.. 근데...\n\n\nm.blog.naver.com\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n \nhttps://m.blog.naver.com/eunha523/223899544519\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n손보시험에 관심많으신 분들.(feat.레드오션TC 각오하시고 도전하시는건지.)\n\n\n오늘 오전에도 이 시험문의가 많으셨고, 메일로도 꽤 문의글이 있었는데 일단, 알바ㅁ, 잡코리x 등.. 이력...\n\n\nm.blog.naver.com\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n​\n오\n랜만에 보는 시험이었다.\n#손해보험설계사시험\n​\n부\n동산 오픈하려고하는 자리가 \n아무래도 여름장사까지하고 정리할 듯 해서 \n3~4개월 텀으로 좀 걸릴 듯 하다.\n​\n어\n차피 올해 오픈해도 빠르면 가을이겠구나.\n그래서 단기느낌으로 일이나 해볼까..\n하다가, 이력서 올리고 쏙쏙 넣어봤음.\n​\n중\n개업관련업은 물론이고,\n(*하.. 중개업은 대표로 일하고싶어서.)\n설계사쪽 TC들도 연락들을 많이 해왔다.\n이것도 수당이니 열심히들이다.\n목소리들이 다 짜증(?)스러워서 패스하다가,\n​\n지\n금 팀장님 목소리가 맘에들어 ㅎㅎ\n손보사 중 규모있고, 집에서도 가까워서\n면접이나 봐볼까.. 하고 담 날 보러갔음.\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n​\n🌿\n미팅\n​\n동글동글하고 선해보이는 팀장님이시길래\n이것저것 설명듣고 커피도 마시고.\n​\n고\n로 보험회사들도 진화하여\n옛날처럼 보험아줌마스럽게 '보험설계사모집'\n이런식의 공고를 부담스럽게 올리는 게 아닌,\n(물론 TC의 개념이 나름 진화하긴 했다.)\n공고도 아쥬 그.럴.듯.하.게. '간단알바식'\n시간단축으로 올리고 경력단절 주부들이나 \n일자리 구하기 힘든 아줌마~할줌마들도 \n열정적으로 일할 수 있단 아주 매.력.적.으.로 \n보이는 직업처럼 보이게꼬롬:)\n​\n결\n혼한 친구나 지인들의 예후(?)를 보면\n그닥 좋은 꼬라지들을 보고사는 건 아닌지라ㅎ\n금수저가 아닌이상, 이런 복지zero나라에 \n결혼하고 애낳고 잘사는 환상자체가 없었어서 \n경력단절여성, 육아부담스트레스의 아픔과 \n고단함을 굳이 나까지 겪고싶지는 않았음. \n​\n이\n로인한 같은 고민 공동체 아줌마집단을\n이런 손보사나 생보사에서 많이 볼 수 있음.\n​\n세\n상에 공짜는 없다고..\n보기좋은 공고뒤엔 또 다른 부담*100배 \n직장각으로 하지 않으면 🥕벌이가 쉽지 않다.\n​\n난 \n애초부터 큰 기대도 없었고,\n짧은시간 근무 메리트는 아예 트릭으로 생각해서\n(남은시간 어차피 지식은 내가 쌓는거임) \n적성에 맞으면 하고 아니면 때려친다. \n요런 느낌 & 평생 살면서 보험은 알아두면 \n뭐, 나쁘지 않고 후에 중개업 겸업에도 \n도움이 될 것 같아 맞으면 생각보다 쭈욱~ \n아니어도 경험치는 남는다. 항상, 최악고려.\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n​\n🌿\n교육\n미팅 다음날, 개인적인 어느사건으로 인해\n늦어서 좀 듣고 그 담날은 교육 다 듣고\n주말 건너뛰고, 월요일 다른분들 손보시험일정으로 코치님 교육없고. 화요일 다른 교육듣고 \n그 다음날(5.28) 시험 보기로. 그러니까 난 \n교육을 거의 못듣고 자습해서 시험을 봐야했다. \n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n아.. c ㅋㅋ중개사겅부 시절이 오버랩되는.ㅎ\n​\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n시험보는 주말은 맹맹구도 거의 잠을 몬자고\n좀 자다가 무릎위로 올라오고 애교떨고갔다가 올라오고×2 귀여운 관종맹구. ㅎㅎ\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n​\n이 \n시험이 \n손해보험+제3보험 or 생명보험+제3보험 \n요로케 보는 게 셤 할인된다고 알고있음.\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n1~33 손해보험 60점 \n15~50 제3보험 60점을 각각 넘어야.\n(*18번 문제는 각각 +1점)\n>> 나중에 손보에서 생보넘어갈 때는\n     제3보험 패스하고 생보만 보면 됨.\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n​\n*시\n험공부 어떻게?\n- 난 4일 공부했음. 겁나 빡쎄게.\n- 단기에 방대한 양을 집어넣어야.\n- 남들의 2~3배를 해야 안도감이 있어서 \n  모의고사가 80점 목표.\n- 항상 말하지만, 이런 자격증 시험은 \n  사무직.공무원.머리 팽팽~ 젊은친구들이\n  유리하긴 하더라.(현업은 완전다른얘기.)\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n​\n🌿\n시험점검\n주말께 코치님과 문자로 모의고사풀고\n피드백받고, 시험전날 코치님이 준 모의고사 \n3~4장 풀고. 근데 다 필요없고 모의고사 마이\n푸는 게 답. 80~90점정도 나와야 속편함.\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n난\n 스스로 하는 자습생이라 \n세상편한 수당 +1  훌륭한 교육생이었음 ㅎㅎ\n코치님들도 합격률이 그들에겐 \n곧 돈이고 성과라 나름 케어는 해주려고 \n노오력 해주심.\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n​\n🌿\n시험당일\n새벽까지 공부하고 늦잠.\n오후 3:30셤이고 각자이동인지라 버스타고ㄱㄱ. 서울이 아니어서 어찌나 땡큐인지. \n코치님이 셤현장에 오셨네. \n같이 시험보는 아줌마분하고 얘기하는 게 \n요게 시험에 3개나 나왔음ㅋㅋ\n​\n🌿\n시험보는데..\n핸드폰 끄고보기. \n비행기모드,무음 다 안된다.\n재수없음 재난문자가.. 재난을 만든다.\n불안하면 감독관 앞에 맡기고.\n울리면 바로퇴장! 지난번에 그랬다네.😱\n​\n감\n독관의 당연한 시험관련 유의사항듣고,\n마킹하라할 때 같이 하는 게 좋고\n시험지유형은 앞,뒷사람하고 다름.\n​\n- '시험 자체가' 개스트레스라서 긴장된다.\n- 모의고사 맨날 나오고 봤던 문제들, \n  요 근래는 그리 쉽게 안 나온다. \n  (*시험이 늘 그렇듯 점점 난이도 UP)\n  블로그 후기들보면 대충해도 쉬울 것 같지? ...
# 68                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            보험설계사 자격증 취득 후 수당받은 후기\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n내가 이 부업을 선택한 이유\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n안녕하세요, 본업 외에 부수입을 만들고 있는 엔잡러 부꾸미입니다.\n​\n요즘은 본업 수입만으로 생활을 꾸려가기 쉽지 않은 분들이 많죠. 저 역시 여러 가지 이유로 부수입이 필요했고, 다양한 부업을 시도해보았습니다. 그중에서도 가장 중요하게 여긴 기준은 바로 ‘수익성’ 이었어요.\n​\n‘내가 관심 있는 일이 과연 수익으로 이어질까?’ 이 질문에 답할 수 있어야 본격적으로 시작할 수 있겠더라고요. 오랜 시간을 투자하거나 별도의 자본금이 드는 건 부담스러웠기에, 시간과 자본 부담이 적은 부업을 찾고 있었는데요.\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n그렇게 고민 끝에 선택한 일이 바로 보험설계사입니다. \n나이, 성별, 학력에 제한 없이 누구나 도전할 수 있고, 짧은 준비 기간으로 자격증을 취득할 수 있으며, 초기 투자금도 들지 않는다는 점에서 큰 매력을 느꼈죠.\n​\n그전에는 온라인 판매, 위탁판매, 구매대행 등 다양한 부업을 해봤지만, 아이템 선정의 어려움, 고객 응대 스트레스, 상표권 문제, 투자 손실 등으로 번번이 실패를 겪었어요. 그래서 자본 없이 시작할 수 있으면서도 스트레스가 덜한 부업을 찾게 됐고, 지금의 보험설계사로 자리잡게 되었습니다.\n​\n본업을 하며 남는 시간에 공부하고, 온라인과 오프라인을 병행하며 활 ...
# 69                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ​\n우선 시험을 준비하게 된 이유는\n정말 어쩌다보니!\n​\n세미나 참석 알바 갔다가 의도치 않게 교육도 듣고\n그 과정에서 유익한 팁들을 듣다 보니 재밌어서\n결국 자격증까지 따게 됐다\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n물론 팁들이 재밌었지\n공부가 재밌던 건 아니었다ㅠ\n​\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n접수 방법\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n접수 방법은 개인은 안되고\n대리점이나 보험 회사 통해서 접수가 가능하다\n​\n접수하게 되면\n나중에 회사측에서 시험 일정 알려주심\n​\n​\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n시험 과목\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n​\n뭐를 배우는가 보면\n손해보험과 보험이론.윤리+법규 그리고 제3보험\n에 대해서 배운다\n​\n​\n시험 과목은 크게 보면 두 가지가 있다\n​\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n손해보험설계사 과목\n1. 손해보험\n2. 제3보험\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n총 50문제 중\n손해보험 : 1번-33번\n제3보험 : 18번-50번\n​\n18번-33번\n겹치는 부분은 \n공통부분\n이다\n( \n보험이론.윤리+법규)\n점수도 중복으로 들어감!\n​\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n​\n손해보험\n제3보험\n​\n시험은 두 과목으로 나뉘며\n각각 100점 만점에\n각 과목마다 60점 이상 맞아야 합격이다\n과락이 있어서 주의!\n​\n점수는\n ...
# Name: content, Length: 70, dtype: object

# %%
import pandas as pd
import re, glob, os, math, html
from pathlib import Path


# ---------- 1. 파일 로드 & 병합 ---------- #
file_paths = [
    "./data/naver_blog_보험설계사 2주 합격.csv",
    "./data/naver_blog_보험설계사 준비 이유.csv",
    "./data/naver_blog_보험설계사 합격 후기.csv",
    "./data/보험설계사 불합격 후기.csv",
    "./data/보험설계사 시험 꿀팁.csv",
    "./data/보험설계사 자격증.csv"
]

frames = []
for path in file_paths:
    try:
        df = pd.read_csv(path, encoding="utf-8")
    except UnicodeDecodeError:
        df = pd.read_csv(path, encoding="cp949")
    df["source_file"] = Path(path).name
    frames.append(df)

df = pd.concat(frames, ignore_index=True)


# ---------- 2. 콘텐츠 컬럼 식별 & 정제 ---------- #
# 'content', '본문', '내용' 중 존재하는 컬럼 선택
content_col = None
for cand in ["content", "본문", "내용", "텍스트", "text"]:
    if cand in df.columns:
        content_col = cand
        break

if content_col is None:
    raise ValueError("본문/내용 컬럼을 찾지 못했습니다.")

def clean_text(t):
    if pd.isna(t):
        return ""
    t = html.unescape(str(t))
    # HTML 태그 제거
    t = re.sub(r"<[^>]+>", " ", t)
    # 공백 정리
    t = re.sub(r"\s+", " ", t)
    return t.strip()

df["clean_text"] = df[content_col].apply(clean_text)


# ---------- 3. 부업 여부(business) ---------- #

# 부업이면 1 아니면 0
business_pattern = re.compile(r"(부업|투잡|n[ -]?잡|side[\s-]?job|사이드잡)", re.I)
df["business"] = df["clean_text"].str.contains(business_pattern).astype(int)


# ---------- 4. 준비 기간 추출 & 빠른 준비(quick) ---------- #
# (\d+)\s*(주|개월|일) 패턴 → 일수 환산
def extract_days(text):
    matches = re.findall(r"(\d+)\s*(주|개월|일)", text)
    days_list = []
    for num, unit in matches:
        n = int(num)
        if unit == "일":
            days_list.append(n)
        elif unit == "주":
            days_list.append(n * 7)
        elif unit == "개월":
            days_list.append(n * 30)
    return min(days_list) if days_list else math.nan

df["prep_days"] = df["clean_text"].apply(extract_days)
df["quick"] = df["prep_days"].apply(lambda x: 1 if not math.isnan(x) and x <= 14 else 0)   # 2주 이하면 1 아니면 0


# ---------- 5. 기본 통계 & 교차표 ---------- #
summary_counts = df[["business", "quick"]].agg(['sum', 'mean']).T
summary_counts.rename(columns={'sum': '합계(건)', 'mean': '비율'}, inplace=True)

crosstab_bq = pd.crosstab(df["business"], df["quick"], margins=True)
crosstab_bq.index = ['일반', '부업', '총합']
crosstab_bq.columns = ['일반 준비', '단기 준비', '총합']

# ---------- 6. 결과 출력 / 시각화 ---------- #
print("=== 핵심 통계 ===")
print(summary_counts)

print("\n=== 부업 여부 × 단기 준비 교차표 ===")
print(crosstab_bq)

new_df = df[['author_id','title','link','clean_text','business','prep_days','quick']]
new_df.to_csv('cleaned_text_all.csv', index=False, encoding='utf-8-sig')
print("통합본 저장 완료")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 19
#      17 for path in file_paths:
#      18     try:
# ---> 19         df = pd.read_csv(path, encoding="utf-8")
#      20     except UnicodeDecodeError:
#      21         df = pd.read_csv(path, encoding="cp949")
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/naver_blog_보험설계사 2주 합격.csv'
