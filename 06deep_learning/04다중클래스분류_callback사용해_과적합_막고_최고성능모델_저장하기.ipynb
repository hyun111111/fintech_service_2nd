# %% [markdown]
# # 다중클래스분류_callback사용해_과적합_막고_최고성능모델_저장하기

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_metplotlib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[68], line 5
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
# ----> 5 import koreanize_metplotlib
#
# ModuleNotFoundError: No module named 'koreanize_metplotlib'

# %%
data = pd.read_csv("./data/winequality-white.csv", sep=";")

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
sns.boxplot(data)
# Out:
# <Axes: >

# %%
data['quality'].value_counts()
# Out:
# quality
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler

# %%
X = data.drop('quality', axis=1)
y = data['quality']

# %% [markdown]
# 수치가 안나오는 것은 데이터가 너무 불균등해서

# %% [markdown]
# # 데이터 증폭 후 분석
# * 데이터 증폭 + 스케일러 사용시
# * 데이터 증폭을 먼저 하고 스케일러로 스케일링

# %%
from imblearn.over_sampling import SMOTE

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X ,y, test_size=0.4, stratify=y, random_state=42)
X_valid, X_test, y_valid, y_test =  train_test_split(X_valid ,y_valid, test_size=0.4, stratify=y_valid, random_state=42)

# %%
smt = SMOTE(k_neighbors=2, random_state=42)
smt_X_train, smt_y_train = smt.fit_resample(X_train, y_train)
smt_X_train = pd.DataFrame(smt_X_train, columns=X_train.columns)
smt_y_train = pd.Series(smt_y_train)
# Out:
# /home/jihyun/miniforge3/envs/tf/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(

# %%
smt_X_train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          6.800000          0.210000     0.270000        2.100000   0.030000
# 1          6.700000          0.240000     0.320000       10.300000   0.079000
# 2          7.600000          0.270000     0.420000        2.600000   0.044000
# 3          7.000000          0.150000     0.280000       14.700000   0.051000
# 4          7.500000          0.170000     0.340000        1.400000   0.035000
# ...             ...               ...          ...             ...        ...
# 9221       7.390043          0.240664     0.364315        2.006638   0.031033
# 9222       6.751973          0.329605     0.350789        1.782368   0.024343
# 9223       6.773419          0.325316     0.359367        1.808102   0.024815
# 9224       6.630848          0.353830     0.302339        1.637017   0.021679
# 9225       7.035602          0.272880     0.464241        2.122723   0.030583
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 0               26.000000            139.000000  0.990000  3.160000
# 1               37.000000            122.000000  0.996620  3.020000
# 2               29.000000            110.000000  0.991200  3.310000
# 3               29.000000            149.000000  0.997920  2.960000
# 4               13.000000            102.000000  0.991800  3.050000
# ...                   ...                   ...       ...       ...
# 9221            27.132757            138.137077  0.990542  3.282987
# 9222            26.127625             93.510499  0.989848  3.397842
# 9223            26.427860             94.711442  0.989875  3.396127
# 9224            24.431866             86.727465  0.989690  3.407532
# 9225            30.098431            109.393726  0.990216  3.375152
#
#       sulphates    alcohol
# 0      0.610000  12.600000
# 1      0.450000   8.800000
# 2      0.510000  12.700000
# 3      0.390000   9.000000
# 4      0.740000  11.000000
# ...         ...        ...
# 9221   0.478009  12.513276
# 9222   0.552250  12.551973
# 9223   0.544101  12.573419
# 9224   0.598278  12.430848
# 9225   0.444471  12.835602
#
# [9226 rows x 11 columns]

# %%
smt_y_train.value_counts()
# Out:
# quality
# 7    1318
# 5    1318
# 6    1318
# 4    1318
# 8    1318
# 3    1318
# 9    1318
# Name: count, dtype: int64

# %%
smt_y_train = pd.get_dummies(smt_y_train)
smt_y_train
# Out:
#           3      4      5      6      7      8      9
# 0     False  False  False  False   True  False  False
# 1     False  False   True  False  False  False  False
# 2     False  False  False   True  False  False  False
# 3     False  False  False  False   True  False  False
# 4     False  False   True  False  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...
# 9221  False  False  False  False  False  False   True
# 9222  False  False  False  False  False  False   True
# 9223  False  False  False  False  False  False   True
# 9224  False  False  False  False  False  False   True
# 9225  False  False  False  False  False  False   True
#
# [9226 rows x 7 columns]

# %%
rs = RobustScaler()
train_temp = rs.fit_transform(smt_X_train)
valid_temp = rs.fit_transform(X_valid)
test_temp =  rs.fit_transform(X_test)
rs_X_train = pd.DataFrame(train_temp, columns= smt_X_train.columns, index= smt_X_train.index)
rs_X_valid = pd.DataFrame(X_valid, columns= X_valid.columns, index= X_valid.index)
rs_X_test = pd.DataFrame(X_test, columns= X_test.columns, index= X_test.index)

# %%
ot_smt_y_train = pd.get_dummies(smt_y_train)
ot_smt_y_train
# Out:
#           3      4      5      6      7      8      9
# 0     False  False  False  False   True  False  False
# 1     False  False   True  False  False  False  False
# 2     False  False  False   True  False  False  False
# 3     False  False  False  False   True  False  False
# 4     False  False   True  False  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...
# 9221  False  False  False  False  False  False   True
# 9222  False  False  False  False  False  False   True
# 9223  False  False  False  False  False  False   True
# 9224  False  False  False  False  False  False   True
# 9225  False  False  False  False  False  False   True
#
# [9226 rows x 7 columns]

# %%
y_valid = pd.get_dummies(y_valid)
y_valid
# Out:
#           3      4      5      6      7      8      9
# 4081  False  False  False   True  False  False  False
# 3891  False  False   True  False  False  False  False
# 3885  False  False  False   True  False  False  False
# 330   False  False  False  False  False   True  False
# 3325  False  False  False  False   True  False  False
# ...     ...    ...    ...    ...    ...    ...    ...
# 28    False  False  False   True  False  False  False
# 1100  False  False  False   True  False  False  False
# 3769  False  False   True  False  False  False  False
# 3319  False  False   True  False  False  False  False
# 1910  False  False   True  False  False  False  False
#
# [1176 rows x 7 columns]

# %%
y_test = pd.get_dummies(y_test)
y_test
# Out:
#           3      4      5      6      7      8      9
# 2084  False  False  False   True  False  False  False
# 3795  False  False  False   True  False  False  False
# 2736  False  False  False   True  False  False  False
# 2320  False  False  False   True  False  False  False
# 4637  False  False  False   True  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...
# 2402  False  False  False   True  False  False  False
# 2134  False  False  False   True  False  False  False
# 3569  False  False  False   True  False  False  False
# 4714  False  False  False  False   True  False  False
# 3385  False  False  False   True  False  False  False
#
# [784 rows x 7 columns]

# %%
smt_y_train.shape[1]
# Out:
# 7

# %%
from keras.models import Sequential
from keras.layers import Dense, Input
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
model = Sequential()
model.add(Input(shape=(smt_X_train.shape[1], )))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(smt_y_train.shape[1], activation='softmax'))
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                │ (None, 64)             │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 7)              │           119 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,495 (13.65 KB)
#  Trainable params: 3,495 (13.65 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # 모델을 최고 성능에서 저장하고 중지하기

# %%
import os

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import os
import matplotlib.pyplot as plt

# 모델 컴파일
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=['accuracy'])

# 콜백 설정
early_stop = EarlyStopping(patience=100)

# 모델 저장 디렉토리 생성
os.makedirs("./model", exist_ok=True)

# 파일 저장 포맷
filepath = "./model/whitewine_loss:{val_loss:.4f}__{epoch:04d}.keras"  

# 체크포인트 콜백
model_save = ModelCheckpoint(filepath=filepath, save_best_only=True)

# 모델 학습
history = model.fit(
    rs_X_train,ot_smt_y_train,
    epochs=1000,
    batch_size=32,
    validation_data=(rs_X_valid , y_valid),  # 올바른 인자명
    callbacks=[early_stop, model_save]
)

# 학습 결과 시각화
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel("epochs")
plt.ylabel("loss")
plt.legend(["train", "valid"])  # 오타 수정
plt.show()
# Out:
# Epoch 1/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8757 - loss: 0.3146 - val_accuracy: 0.4490 - val_loss: 235.4640
# Epoch 2/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8773 - loss: 0.3069 - val_accuracy: 0.4490 - val_loss: 244.5489
# Epoch 3/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8784 - loss: 0.3057 - val_accuracy: 0.4490 - val_loss: 237.8775
# Epoch 4/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8802 - loss: 0.2978 - val_accuracy: 0.4490 - val_loss: 239.6840
# Epoch 5/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8822 - loss: 0.2973 - val_accuracy: 0.4490 - val_loss: 241.8387
# Epoch 6/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8806 - loss: 0.2983 - val_accuracy: 0.4490 - val_loss: 256.2463
# Epoch 7/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8844 - loss: 0.2912 - val_accuracy: 0.4490 - val_loss: 240.8285
# Epoch 8/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8814 - loss: 0.2936 - val_accuracy: 0.4490 - val_loss: 258.2403
# Epoch 9/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8869 - loss: 0.2954 - val_accuracy: 0.4490 - val_loss: 257.4547
# Epoch 10/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8778 - loss: 0.3038 - val_accuracy: 0.4490 - val_loss: 247.6215
# Epoch 11/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8843 - loss: 0.2940 - val_accuracy: 0.4490 - val_loss: 270.8261
# Epoch 12/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8843 - loss: 0.2835 - val_accuracy: 0.4490 - val_loss: 251.0552
# Epoch 13/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8904 - loss: 0.2805 - val_accuracy: 0.4490 - val_loss: 272.3367
# Epoch 14/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8809 - loss: 0.2861 - val_accuracy: 0.4490 - val_loss: 280.7421
# Epoch 15/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8966 - loss: 0.2708 - val_accuracy: 0.4490 - val_loss: 279.8581
# Epoch 16/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8876 - loss: 0.2805 - val_accuracy: 0.4490 - val_loss: 268.1549
# Epoch 17/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8870 - loss: 0.2812 - val_accuracy: 0.4490 - val_loss: 281.2438
# Epoch 18/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8948 - loss: 0.2728 - val_accuracy: 0.4490 - val_loss: 288.3011
# Epoch 19/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8844 - loss: 0.2819 - val_accuracy: 0.4490 - val_loss: 281.5382
# Epoch 20/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8884 - loss: 0.2786 - val_accuracy: 0.4490 - val_loss: 289.7895
# Epoch 21/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8878 - loss: 0.2837 - val_accuracy: 0.4490 - val_loss: 288.0591
# Epoch 22/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8913 - loss: 0.2712 - val_accuracy: 0.4490 - val_loss: 265.0436
# Epoch 23/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8955 - loss: 0.2636 - val_accuracy: 0.4490 - val_loss: 294.1353
# Epoch 24/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8927 - loss: 0.2739 - val_accuracy: 0.4490 - val_loss: 298.0175
# Epoch 25/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8915 - loss: 0.2726 - val_accuracy: 0.4490 - val_loss: 302.1689
# Epoch 26/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8882 - loss: 0.2701 - val_accuracy: 0.4490 - val_loss: 307.7672
# Epoch 27/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8971 - loss: 0.2616 - val_accuracy: 0.4490 - val_loss: 296.8917
# Epoch 28/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8876 - loss: 0.2831 - val_accuracy: 0.4490 - val_loss: 320.8533
# Epoch 29/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8824 - loss: 0.2799 - val_accuracy: 0.4498 - val_loss: 270.2053
# Epoch 30/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8897 - loss: 0.2747 - val_accuracy: 0.4490 - val_loss: 288.3449
# Epoch 31/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9006 - loss: 0.2540 - val_accuracy: 0.4490 - val_loss: 305.3187
# Epoch 32/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8937 - loss: 0.2604 - val_accuracy: 0.4490 - val_loss: 316.7299
# Epoch 33/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8982 - loss: 0.2560 - val_accuracy: 0.4490 - val_loss: 313.6295
# Epoch 34/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8965 - loss: 0.2562 - val_accuracy: 0.4490 - val_loss: 311.7992
# Epoch 35/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8960 - loss: 0.2536 - val_accuracy: 0.4490 - val_loss: 314.7540
# Epoch 36/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8965 - loss: 0.2535 - val_accuracy: 0.4490 - val_loss: 305.0690
# Epoch 37/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9005 - loss: 0.2493 - val_accuracy: 0.4549 - val_loss: 293.1833
# Epoch 38/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8997 - loss: 0.2509 - val_accuracy: 0.4490 - val_loss: 334.5013
# Epoch 39/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8944 - loss: 0.2521 - val_accuracy: 0.4490 - val_loss: 302.9836
# Epoch 40/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9009 - loss: 0.2496 - val_accuracy: 0.4490 - val_loss: 309.2809
# Epoch 41/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9080 - loss: 0.2435 - val_accuracy: 0.4490 - val_loss: 349.1109
# Epoch 42/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9039 - loss: 0.2485 - val_accuracy: 0.4490 - val_loss: 339.4082
# Epoch 43/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9007 - loss: 0.2462 - val_accuracy: 0.4490 - val_loss: 331.3359
# Epoch 44/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9067 - loss: 0.2400 - val_accuracy: 0.4549 - val_loss: 321.6843
# Epoch 45/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9060 - loss: 0.2430 - val_accuracy: 0.4507 - val_loss: 315.1612
# Epoch 46/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9032 - loss: 0.2428 - val_accuracy: 0.4524 - val_loss: 306.6298
# Epoch 47/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9033 - loss: 0.2554 - val_accuracy: 0.4473 - val_loss: 307.9550
# Epoch 48/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9016 - loss: 0.2503 - val_accuracy: 0.4490 - val_loss: 333.8194
# Epoch 49/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9058 - loss: 0.2365 - val_accuracy: 0.4490 - val_loss: 331.2427
# Epoch 50/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9094 - loss: 0.2363 - val_accuracy: 0.4490 - val_loss: 336.0749
# Epoch 51/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9083 - loss: 0.2354 - val_accuracy: 0.4490 - val_loss: 323.7982
# Epoch 52/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8984 - loss: 0.2458 - val_accuracy: 0.4490 - val_loss: 330.7843
# Epoch 53/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9041 - loss: 0.2417 - val_accuracy: 0.4413 - val_loss: 318.2917
# Epoch 54/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9104 - loss: 0.2345 - val_accuracy: 0.4490 - val_loss: 339.1868
# Epoch 55/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9125 - loss: 0.2263 - val_accuracy: 0.4490 - val_loss: 346.2056
# Epoch 56/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9059 - loss: 0.2230 - val_accuracy: 0.4490 - val_loss: 319.7628
# Epoch 57/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9045 - loss: 0.2363 - val_accuracy: 0.4388 - val_loss: 318.9362
# Epoch 58/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9110 - loss: 0.2294 - val_accuracy: 0.4507 - val_loss: 320.4602
# Epoch 59/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9135 - loss: 0.2302 - val_accuracy: 0.4498 - val_loss: 341.5352
# Epoch 60/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9137 - loss: 0.2250 - val_accuracy: 0.4515 - val_loss: 338.0753
# Epoch 61/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9131 - loss: 0.2224 - val_accuracy: 0.4541 - val_loss: 348.4694
# Epoch 62/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9159 - loss: 0.2174 - val_accuracy: 0.4337 - val_loss: 324.4283
# Epoch 63/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9082 - loss: 0.2256 - val_accuracy: 0.4490 - val_loss: 338.5788
# Epoch 64/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9098 - loss: 0.2358 - val_accuracy: 0.4473 - val_loss: 334.4072
# Epoch 65/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9169 - loss: 0.2217 - val_accuracy: 0.4507 - val_loss: 339.1552
# Epoch 66/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9160 - loss: 0.2154 - val_accuracy: 0.4456 - val_loss: 351.5839
# Epoch 67/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9134 - loss: 0.2332 - val_accuracy: 0.4541 - val_loss: 359.1913
# Epoch 68/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9177 - loss: 0.2160 - val_accuracy: 0.4541 - val_loss: 337.9999
# Epoch 69/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9133 - loss: 0.2244 - val_accuracy: 0.4515 - val_loss: 356.7043
# Epoch 70/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9127 - loss: 0.2147 - val_accuracy: 0.4362 - val_loss: 351.4551
# Epoch 71/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9140 - loss: 0.2189 - val_accuracy: 0.4490 - val_loss: 384.4048
# Epoch 72/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9088 - loss: 0.2303 - val_accuracy: 0.4549 - val_loss: 368.2273
# Epoch 73/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9203 - loss: 0.2104 - val_accuracy: 0.4481 - val_loss: 365.0813
# Epoch 74/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9145 - loss: 0.2163 - val_accuracy: 0.4532 - val_loss: 366.7209
# Epoch 75/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9169 - loss: 0.2105 - val_accuracy: 0.3997 - val_loss: 369.3121
# Epoch 76/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9155 - loss: 0.2149 - val_accuracy: 0.3665 - val_loss: 374.1654
# Epoch 77/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9202 - loss: 0.2044 - val_accuracy: 0.4396 - val_loss: 348.2851
# Epoch 78/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9197 - loss: 0.2131 - val_accuracy: 0.4524 - val_loss: 365.2441
# Epoch 79/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9210 - loss: 0.1979 - val_accuracy: 0.4549 - val_loss: 339.0688
# Epoch 80/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9132 - loss: 0.2129 - val_accuracy: 0.4524 - val_loss: 350.5128
# Epoch 81/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9153 - loss: 0.2213 - val_accuracy: 0.4167 - val_loss: 368.8606
# Epoch 82/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9191 - loss: 0.2019 - val_accuracy: 0.4481 - val_loss: 342.7928
# Epoch 83/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9194 - loss: 0.2128 - val_accuracy: 0.4337 - val_loss: 349.9026
# Epoch 84/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9201 - loss: 0.2045 - val_accuracy: 0.4464 - val_loss: 353.2985
# Epoch 85/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9103 - loss: 0.2195 - val_accuracy: 0.4116 - val_loss: 357.0899
# Epoch 86/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9203 - loss: 0.2044 - val_accuracy: 0.4099 - val_loss: 369.3130
# Epoch 87/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9225 - loss: 0.1961 - val_accuracy: 0.3869 - val_loss: 376.9520
# Epoch 88/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9203 - loss: 0.1998 - val_accuracy: 0.3852 - val_loss: 358.7257
# Epoch 89/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9184 - loss: 0.2006 - val_accuracy: 0.4473 - val_loss: 345.1142
# Epoch 90/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9218 - loss: 0.2134 - val_accuracy: 0.4056 - val_loss: 379.5842
# Epoch 91/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9231 - loss: 0.2022 - val_accuracy: 0.4447 - val_loss: 365.8932
# Epoch 92/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9205 - loss: 0.2000 - val_accuracy: 0.4490 - val_loss: 370.1667
# Epoch 93/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9239 - loss: 0.2001 - val_accuracy: 0.3954 - val_loss: 375.3861
# Epoch 94/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9277 - loss: 0.1913 - val_accuracy: 0.3869 - val_loss: 383.0811
# Epoch 95/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9218 - loss: 0.2021 - val_accuracy: 0.3724 - val_loss: 397.0296
# Epoch 96/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9256 - loss: 0.1933 - val_accuracy: 0.4583 - val_loss: 372.4558
# Epoch 97/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9231 - loss: 0.1953 - val_accuracy: 0.3588 - val_loss: 386.9501
# Epoch 98/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9248 - loss: 0.1938 - val_accuracy: 0.4515 - val_loss: 360.9264
# Epoch 99/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9218 - loss: 0.1987 - val_accuracy: 0.4090 - val_loss: 381.5598
# Epoch 100/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9175 - loss: 0.1980 - val_accuracy: 0.3920 - val_loss: 376.6473
# Epoch 101/1000
# 289/289 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9246 - loss: 0.1967 - val_accuracy: 0.4549 - val_loss: 356.2053

# %% [markdown]
# # 저장된 best 모델 불러와서 사용하기

# %%
rs_X_test
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2084            7.9              0.17         0.32            1.60      0.053
# 3795            6.5              0.25         0.27           17.40      0.064
# 2736            6.5              0.17         0.31            1.50      0.041
# 2320            8.0              0.20         0.30            8.10      0.037
# 4637            6.0              0.24         0.41            1.30      0.036
# ...             ...               ...          ...             ...        ...
# 2402            8.0              0.26         0.28            8.20      0.038
# 2134            6.8              0.26         0.32            7.00      0.041
# 3569            8.0              0.25         0.27            9.70      0.036
# 4714            6.1              0.22         0.40            1.85      0.031
# 3385            6.4              0.32         0.31            1.90      0.037
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2084                 47.0                 150.0  0.99480  3.29       0.76
# 3795                 29.0                 140.0  0.99776  3.20       0.49
# 2736                 34.0                 121.0  0.99092  3.06       0.46
# 2320                 42.0                 130.0  0.99379  3.10       0.67
# 4637                 42.0                 118.0  0.99018  3.04       0.64
# ...                   ...                   ...      ...   ...        ...
# 2402                 72.0                 202.0  0.99566  3.12       0.56
# 2134                 38.0                 118.0  0.99390  3.25       0.52
# 3569                 15.0                  85.0  0.99406  2.99       0.36
# 4714                 25.0                 111.0  0.98966  3.03       0.30
# 3385                 34.0                 126.0  0.99000  3.06       0.45
#
#         alcohol
# 2084   9.600000
# 3795  10.100000
# 2736  10.500000
# 2320  11.800000
# 4637  11.733333
# ...         ...
# 2402  10.000000
# 2134  10.800000
# 3569  11.200000
# 4714  11.800000
# 3385  11.800000
#
# [784 rows x 11 columns]

# %%
from keras.models import load_model

# %%
best_model =  load_model("./model/whitewine_0009__1.2062.keras")
wine_pred = best_model.predict(rs_X_test)
wine_pred = pd.DataFrame(wine_pred, columns=y_test.columns)
wine_pred
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step
#             3         4         5         6         7         8             9
# 0    0.001433  0.014570  0.268538  0.550442  0.145531  0.019487  3.258240e-07
# 1    0.000712  0.015506  0.235883  0.486540  0.248973  0.012386  2.180353e-07
# 2    0.002149  0.022699  0.156890  0.521922  0.268135  0.028200  5.954149e-06
# 3    0.001044  0.010664  0.141350  0.586855  0.235082  0.025004  8.099473e-07
# 4    0.001049  0.012141  0.089228  0.446089  0.415225  0.036265  2.876812e-06
# ..        ...       ...       ...       ...       ...       ...           ...
# 779  0.000479  0.004887  0.445558  0.466494  0.071652  0.010930  1.262528e-09
# 780  0.001668  0.014251  0.143993  0.531799  0.274434  0.033852  2.925697e-06
# 781  0.004342  0.063860  0.304512  0.441736  0.160047  0.025473  3.014933e-05
# 782  0.002890  0.033053  0.169721  0.452358  0.310428  0.031533  1.812314e-05
# 783  0.001573  0.019992  0.134347  0.510358  0.308233  0.025493  4.121224e-06
#
# [784 rows x 7 columns]

# %%
best_model.evaluate(rs_X_test, y_test)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.4847 - loss: 1.2037
# [1.20912504196167, 0.4770408272743225]
