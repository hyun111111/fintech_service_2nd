# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib

# %%
train_df = pd.read_csv("./data/bank_app_reviews_train.csv")

# %%
test_df = pd.read_csv("./data/bank_app_reviews_test.csv")

# %%
train_df
# Out:
#               리뷰일  평점                                              사용자리뷰  \
# 0      2023-12-21   5        엄빠 폰에 설치해드렸는데 두분 다 쓰기 편하다고 하시네요 ㅎㅎ 저도 쓰고있음!
# 1      2025-02-17   1  Cd기 축소 연장하려면 이 어플 깔라는데 왜 30퍼에서 안깔리는지 아니 애초에 슈퍼...
# 2      2024-07-26   5                      서비스가 통합되어 있어서 점점 사용빈도가 높아지네요.
# 3      2024-09-01   1                                          카드 충천이 안됌
# 4      2023-11-13   1                                   알뜰폰 인증이 안돼요.....
# ...           ...  ..                                                ...
# 22241  2025-03-12   3                                   어플 시작오류가 가끔 나네요.
# 22242  2025-01-09   1                            업데이트 후에 계좌이체하는 게 자주 튕겨요
# 22243  2023-07-07   5                                                굳굳굳
# 22244  2024-10-10   5                               오래시간 같이한 나의은행 든든합니다.
# 22245  2023-08-09   1  라이브 광고 전보다 더 안좋네 아무리 주기 싫어도 겨우 3원줄거면서 너무 쪼잔하게 ...
#
#                                                     업체답변 은행명
# 0                                                    NaN  하나
# 1      안녕하세요. 신한은행입니다.\n먼저 SOL사용에 불편을 드려 죄송합니다.\n어플의 ...  신한
# 2      고객님 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. KB스타뱅킹...  국민
# 3      안녕하세요. 전민구 님, 토스팀입니다. 남겨주신 내용만으로는 겪고계신 불편사항의 자...  토스
# 4      안녕하세요 헤이모두들안녕님, 우리은행입니다. 먼저 이용에 불편을 드려 매우 죄송합니...  우리
# ...                                                  ...  ..
# 22241  안녕하세요 푸딩 고객님. 우리은행 우리WON뱅킹 이용에 불편을 드려 죄송합니다. 2...  우리
# 22242  안녕하세요 일월구일 고객님. 먼저 우리WON뱅킹 이용에 불편을 드려 죄송합니다. 보...  우리
# 22243  Seung Woo Kim 고객님, 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로...  국민
# 22244  안녕하세요 lee jeong seon (isate) 고객님. 칭찬 진심으로 감사드리...  우리
# 22245  안녕하세요. 송재영님, 토스 고객센터입니다. 토스를 이용하시면서 느끼신 소중한 의견...  토스
#
# [22246 rows x 5 columns]

# %%
test_df
# Out:
#              리뷰일  평점                                              사용자리뷰  \
# 0     2024-02-08   5                                         고경민계장님감사해요
# 1     2023-07-24   5  저축목표피드 새로 생긴거 너무좋은데 분명 카테고리를 저축으로 했는데 왜 인식이 안되...
# 2     2023-09-25   1  아니 이딴걸 편리하게 사용하는앱이라고 쳐만들엇나 이렇게 불편하게만든건 일부러그런거에...
# 3     2024-02-15   3  몇 년째 만족하며 사용중이라 조금식 개선되어거는 모습에 만족하며 사용중입니다. 하지...
# 4     2023-06-19   5                           스타뱅킹을 사용 하고나서부터 편안해서 좋아요
# ...          ...  ..                                                ...
# 9529  2025-04-05   1  만보기 이벤트는 실망스러워요. 후기 말투 다 똑같고 사기 맞죠? 양심이 참... 정...
# 9530  2023-05-17   5                 기능이 많아 다 사용해보진 못 했지만 대체적으로 편한거 같아요
# 9531  2023-07-05   5                                             편리하네요.
# 9532  2024-12-20   5                                          사용하기 편리해요
# 9533  2024-03-06   1  너무 후져서 오랜만에 어플이용하다가 욕했답니다 인증방식이 2010년대에 머물러계심 ...
#
#                                                    업체답변    은행명
# 0     안녕하세요 최순녀 고객님. 칭찬 진심으로 감사드리며, 더욱 편리하고 안정적인 서비스...     우리
# 1     신아​ 님, 안녕하세요? 뱅크샐러드 고객감동팀​입니다. 소중한 시간내어 고객센터에 ...  뱅크샐러드
# 2     안녕하세요. 우리은행입니다. 먼저 우리WON뱅킹 이용에 불편을 드려 죄송합니다. 보...     우리
# 3     안녕하세요? 뱅크샐러드 고객감동팀입니다. 뱅크샐러드에 KB pay를 연결해 모든 자...  뱅크샐러드
# 4     한송림 고객님, 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. 앞...     국민
# ...                                                 ...    ...
# 9529  안녕하세요. 송송님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 노력하였으나,...     토스
# 9530  이강욱 고객님 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. 고객...     국민
# 9531  농사꾼 고객님, 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. 앞...     국민
# 9532  고객님 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. KB스타뱅킹...     국민
# 9533  안녕하세요 신한은행입니다.\n먼저 SOL사용에 불편을 드려 정말 죄송합니다.\n고객...     신한
#
# [9534 rows x 5 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22246 entries, 0 to 22245
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   리뷰일     22246 non-null  object
#  1   평점      22246 non-null  int64
#  2   사용자리뷰   22246 non-null  object
#  3   업체답변    19141 non-null  object
#  4   은행명     22246 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 869.1+ KB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9534 entries, 0 to 9533
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   리뷰일     9534 non-null   object
#  1   평점      9534 non-null   int64
#  2   사용자리뷰   9534 non-null   object
#  3   업체답변    8221 non-null   object
#  4   은행명     9534 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 372.5+ KB

# %%
train_df['평점']. value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='평점'>

# %%
train_df[train_df['평점'] ==4]['사용자리뷰'].head(60)
# Out:
# 11                                                   좋아요
# 14                                                    좋음
# 27     Not Found 실행이 안됩니다 하나은행 어플 누르면 Not Found 메세지 뜨...
# 30     이전거보다 메뉴가 많아진건지 내가 사용하는게 걷기가 숨겨져 불편.확인 할때마다 일상...
# 38              보상을 얻기위해 광고를 보는건 상관없는데 광고 좀 가려 받으면 안되나요?
# 69     오늘 토스 재가입 후 저도 모르는 사이 토스페이가입되었네요. 가입 금액(5,900원...
# 75                                     빠르고 정확함 이용을 권장합니다
# 82                                    아직까지 잘 사용하고 있습니다 ?
# 91     지난 달부터 갑자기 홈->앞으로 낼 카드값 부분에 특정 카드사 한곳만 뜹니다ㅠ 분명...
# 97                                                    만족
# 98                                                    좋음
# 106    가상계좌가 브랜드콘 같은걸 살때는 아무 불편함이없는데 온라인으로 결제를할때 제계좌명...
# 107                                  토스아이디를 제발 다시 만들어주세요
# 118                                       금액이조금적어서 아쉬었어요
# 130                 해외(영국)현지번호를 쓰다보니, 인증번호를 받을수가 없습니다. ㅠ
# 145                     항상 먼저 고객상황을 고려해서 정보을 알려주어 감사감사^^
# 151     역대 은행앱 중 가장 만족. 허나 이벤트를 하려고 버튼을 누르면 오류가 생겼다며 안됨.
# 153    소비 관리하는 데 아주 유용하게 쓰고 있습니다. ktx 예매 때문에 코레일을 이용했...
# 156                                                  효율적
# 157                           전산상 확인이 안되는 상품설명이 있어서 아쉽네요
# 165                                                    굿
# 175                                              사용하기 좋음
# 191    업데이트 하고 나서부터 비밀번호, 지문인식 등등 한 후 그 다음 화면으로 안넘어가고...
# 205                                                    굳
# 206                                                  좋아요
# 208    전.조흥은행때최최초로싸인.서명을한사람인겄같습니다. 신용등급으로~ 지금은 보이스피싱피...
# 222                                                    굿
# 223    알람이 안떠서 직접 가서 알람 뜨도록 설정 을 했는데 돈만 가져가고 알람 안뜨네요 ...
# 232                                           직관적이고 쉬워요!
# 235    하루에 가장 많이 사용하는 어플입니다. 근데 라이브쇼핑에서 60초 기다리고 최대 5...
# 247                                               빨라서좋네요
# 255                                               Gooooo
# 259                                게좌숨기기 기능 굿~!! 쉽고 편해요.
# 260                                            대체로 만족합니다
# 267                                                  좋아요
# 296                                            앱이 너무 버벅댐
# 303                                넘나 편하지만 교통카드 충전이 불편해요
# 304    kb국민인증서 유효기간이 340일 넘게 남았는데 계속 연장하겠냐고 탭이뜨네요.. 적...
# 315                      수수료 1300원이나 내야함 (700원정도면 상관없어요)
# 329                                            간편하여 좋습니다
# 348              이것저것 뒤로가는 단계에서 삑나서 귀찮게하는게있긴한데 이정도면 편리해요
# 360                               토스증권 아이패드도 쓸 수 있게 해주세요
# 361    정말 다 좋은데 만보기가 작동을 안해서 가족 중 나만 돈을 못벌고 있음. 알림 허용...
# 384    알기쉽고 따라하기 쉽게 구성되어 있네요,한가지 아쉬운점은 간편비밀번호 입력에 일부제...
# 392                  토스피드에 만원내고 사진 올리면 포인트 수익은 따로 없는건가요?
# 399                                          카드 포안트가 안떠요
# 423                          한가지가 다마칠땍까지는 비밀번호를넣지안앟음좋것어요
# 429                                             안전하고 편리함
# 438                                                 좋아요.
# 443    번호표 발행에 (개인대출,예금,입출금 각 각) 세부 항목별로 인원수 대로 나오게 만...
# 445    예.적금 안내와 기타 상담시 답변도 빠르고 친절합니다 이번엔 N일 적금으로 모은 작...
# 460    잘 사용했는데 호가창에서 체결강도랑 보이던게 안보이니까 너무 불편해요.. 설정할 수...
# 465    ㅂㄴㅣㅓ든2 aaa×²aㅁㅂㅁㅈㅇㅋㄷㅃㄷㅓㅗ6ㅗㅓㄷ6ㄴㅍㄴㅇㄴㅇ릅린ㅍ1ㅜㅗ 000 ...
# 470                                                    굿
# 472              내역합치기 기능 어떻게 쓰나요? 내역 길게 눌러도 삭제 버튼만 뜹니다.
# 482                                                아주좋아요
# 527                                                   깔끔
# 603                                                 좋습니다
# 625                                                  좋아요
# 627                                              사용하기편해요
# Name: 사용자리뷰, dtype: object

# %%
train_df[train_df['평점'] ==3]['사용자리뷰'].head(60)
# Out:
# 6                           고양이키우기 쿠폰 유효기간 6일. 넘 한거 아닌가요?
# 18      배터리가 빨리 줄어요..서비스센터 가면 토스앱이 배터리 사용이 많다고 하네요.. 방...
# 32                                입출금목록에서 터치해서메모입력하던게안되네요
# 39                             앱 켤때 70%는 다시 켜야됨. 캐시 남아있다고
# 89      제일 큰 문제중 하나는 혜택으로 알림설정을 유도하면서 알림이 제대로 동작 안합니다....
# 132     포인트통의 포인트를 포인트리로 전환하려는데 보내기가 안되네요 오류 개선 좀 부탁드려...
# 176     은행.신한카드 잘 쓰고 있는데 이거 왜? 출시? 수퍼 Opt 재발행하고,은행쓸려 했...
# 177                                   토스 요즘 쫌 짜증난다 맨날 버그야
# 184      데이터로 하나원큐 들어가려는데 너무 오래 걸립니다... 옛날에는 안그랬는데 버그인가요?
# 197                 할부금 완납한거는 왜 반영이 안돼서 계속 할부금액으로 계속 잡히나요
# 209     무슨 점검을 밥 먹듯이 하세요.. 할꺼면 새벽 2시 이후로 해주세요 타이밍 진짜.....
# 253     쇼핑, 주식 메뉴가 삼성 덱스에선 안나옵니다. 다른앱은 이런게 없는데 토스만 그렇군...
# 266                                  만족합니다. 간단하고 빠르고~~~~~
# 305     토스를 사용하고 싶어도 비번을 틀려서 못 사용중 ㅠㅠㅠ 이거 어떻하나요? 저 번호도...
# 352     홈화면에서 노란색 이체 버튼 눌렀을때 최근계좌에 입금금액이랑 입금날짜가 같이 떴었는...
# 357     10월4일 부터 푸시알림(?)이 이상네요. 며칠 전 앱 업데이를 많이 한 것 같은데...
# 362     다 좋은데 요즘 고양이??키우기 100%채운 후 새 고양이로 넘어갈때 화면 정지되고...
# 389     토스 요즘 배터리 너무 많이 잡아 먹는데 저만 그런건가요? 폰 최적화하면 토스만 매...
# 391     토스 만보기 나이 만12세로 낮춰주세요ㅜㅜㅠ 토스 사용연량이 만12센데 왜 만보기는...
# 401                          잘쓰고 있는데 점점앱이 무거워지고 느려지는게 느껴짐
# 413     매일걷기 연동이 되다 안되다 바뀌고 나서 이상 하네요 다른 걷기 앱은 똑같이 걸음수...
# 414                                 왜 자꾸 포인트받는 양을 줄이는지 ㅋㅋ
# 432     왜 뒤로가기 버튼이 실행이 안되죠? 핸드폰 뒤로가기도 토스에 있는 뒤로가기도 안먹히는데요
# 450     토스뱅크 접속은 되는데 다른메뉴로 넘어가지 않습니다. 미라클 모닝 이벤트, 증권 등...
# 456              알림앱은 왜 삭제하셨는지요... 다시 만들어 주세요! 글고 앱이 느립니다
# 511     잘 쓰고는 있는데 일주일 방문미션으로 광고보면서 실제로 그 광고제품을 구매한적도 있...
# 534     업데이트가 종료된 폰이기에 커스텀롬을 사용하는데. 해킹위험 감지라며 더 이상 사용이...
# 550     일주일 걷기 미션이 없어져서 아쉽네요. 그나마 고정포인트라서 좋았는데.. 걷기 미션...
# 562     토스 프라임 적립 금액이 1원 미만이라서 적립이 안 된다는데 이제 배민은 지원 안 ...
# 611                                      지문인식 로그인 왜 사라짐??
# 618                   잘쓰고있는데 귀찮게 자꾸 뭐 입력하라마라좀 그만했으면 좋겠습니다
# 665     사용하기 편하고 좋습니다. 다만 건강탭에 발병률 부분은 이해가 안가네요 관련 수치도...
# 669                                           진원 ㅈㅈㄷㅈㅈㅍ2ㅈ
# 672     위비뱅크 진짜 편했는데 종료된거에 대해 아직도 이해가 안되고 자동로그인이라도 있었음...
# 686                            갑자기 카테고리가 왜 없어진건가요???;;;;,
# 693                       토스 잘쓰고 있는데 하루가 지났는데 왜 돈이 안 꺼내저여
# 723     간편 로그인하기 설정좀 한번만 뜨게하면 안되나 들어갈때마다 안하기 누르기 짜증남. ...
# 741     앱 사용중 홈키를 누르거나 다른 앱 실행시 백그라운드에서 실행중인 어플리케이션 목록...
# 746     보안상이유로 가상기기 에서는 사용 할수없다고 뜨는데 어떻게해야되나요? 가상기기 가 ...
# 767     가위바위보 누구 아이디어냐ㅋㅋ 놀리는거도 아니고ㅋㅋ 0.1초 보다 빠르게 바뀌면 어...
# 780     어제부터 실행이 안되서 오늘 앱 삭제후 새로 설치하고 실행할려고해도 어제와 동일하게...
# 781                                                편리한 구성
# 797                                   ㅌㄹㄹㄷㄷᆢㄹㅡㅡㄹㆍ로ㅡㄹ르ㅡㅡ둗됴
# 798     고양이 키우기 애용하고 있는데 버벅임이 눈에 띄게 많고, 최근 광고가 무료 폰게임 ...
# 804     너무잘사용중인데 최근 업데이트후 너무 느려지네요. 앱이 멈추기도하고 스크롤 반응이 ...
# 824                                    아니 왜 오늘 접속이 안되는건가요
# 848     기존 알림서비스 앱에서는 입출금내역 선택적으로 삭제가 가능했는데, 통합되면서 내역삭...
# 870                                        편리한 가입 및 저축 가입
# 900                                 와!!! 추가이체 겁나게 불편 하네요ㅜ
# 932                                      인터넷 뱅킹이 너무 어려워요.
# 958     광고 소리 없애고 보기만 하는건 안되는건가요? 음악들으면서 토스 앱 켜서 만보기든 ...
# 977     사용하다가 종종 그냥 하얀색 창만 뜨고 떠야할 페이지가 안뜰 때가 있습니다. 이러기...
# 1001    안녕하세요 계좌이체를 하는데 돈 보낸사람 이름으로 뜨는 문제점이 있어 큰 어려움과 ...
# 1027                                           토스가 안깔려요ㅠㅠ
# 1028    앱내 kbpay 결제를 하려고 해도 앱이 설치되어 있는데 구글플레이로 넘어가요. 결...
# 1029    농협 손해보험 연결이 안되네요 처음에 연결되었지만 작년부터 연결이 안되네요 왜 그런...
# 1057    제가 사용한지얼마안된 사람인데 나쁜점이 있습니다 급식표를 보려고하는데 계속 점검중이...
# 1071    Not found 오류 저만 뜨는 건가요..? 접속이 아예 안되는데요 삭제하고 다시...
# 1099                왜 토스 업데이트가 안되죠? 와이파이연결 저장공간 다 되있는데...
# 1125    토스앱 다운로드 받으려면 넘 시간이 걸리는데 왜 그런지 모르겠네요..다른 앱은 빨리...
# Name: 사용자리뷰, dtype: object

# %%
train_df['긍정'] =train_df['평점'].apply(lambda x:1 if x in [4,5] else 0)
train_df
# Out:
#               리뷰일  평점                                              사용자리뷰  \
# 0      2023-12-21   5        엄빠 폰에 설치해드렸는데 두분 다 쓰기 편하다고 하시네요 ㅎㅎ 저도 쓰고있음!
# 1      2025-02-17   1  Cd기 축소 연장하려면 이 어플 깔라는데 왜 30퍼에서 안깔리는지 아니 애초에 슈퍼...
# 2      2024-07-26   5                      서비스가 통합되어 있어서 점점 사용빈도가 높아지네요.
# 3      2024-09-01   1                                          카드 충천이 안됌
# 4      2023-11-13   1                                   알뜰폰 인증이 안돼요.....
# ...           ...  ..                                                ...
# 22241  2025-03-12   3                                   어플 시작오류가 가끔 나네요.
# 22242  2025-01-09   1                            업데이트 후에 계좌이체하는 게 자주 튕겨요
# 22243  2023-07-07   5                                                굳굳굳
# 22244  2024-10-10   5                               오래시간 같이한 나의은행 든든합니다.
# 22245  2023-08-09   1  라이브 광고 전보다 더 안좋네 아무리 주기 싫어도 겨우 3원줄거면서 너무 쪼잔하게 ...
#
#                                                     업체답변 은행명  긍정
# 0                                                    NaN  하나   1
# 1      안녕하세요. 신한은행입니다.\n먼저 SOL사용에 불편을 드려 죄송합니다.\n어플의 ...  신한   0
# 2      고객님 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. KB스타뱅킹...  국민   1
# 3      안녕하세요. 전민구 님, 토스팀입니다. 남겨주신 내용만으로는 겪고계신 불편사항의 자...  토스   0
# 4      안녕하세요 헤이모두들안녕님, 우리은행입니다. 먼저 이용에 불편을 드려 매우 죄송합니...  우리   0
# ...                                                  ...  ..  ..
# 22241  안녕하세요 푸딩 고객님. 우리은행 우리WON뱅킹 이용에 불편을 드려 죄송합니다. 2...  우리   0
# 22242  안녕하세요 일월구일 고객님. 먼저 우리WON뱅킹 이용에 불편을 드려 죄송합니다. 보...  우리   0
# 22243  Seung Woo Kim 고객님, 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로...  국민   1
# 22244  안녕하세요 lee jeong seon (isate) 고객님. 칭찬 진심으로 감사드리...  우리   1
# 22245  안녕하세요. 송재영님, 토스 고객센터입니다. 토스를 이용하시면서 느끼신 소중한 의견...  토스   0
#
# [22246 rows x 6 columns]

# %%
test_df['긍정'] =test_df['평점'].apply(lambda x:1 if x in [4,5] else 0)
test_df
# Out:
#              리뷰일  평점                                              사용자리뷰  \
# 0     2024-02-08   5                                         고경민계장님감사해요
# 1     2023-07-24   5  저축목표피드 새로 생긴거 너무좋은데 분명 카테고리를 저축으로 했는데 왜 인식이 안되...
# 2     2023-09-25   1  아니 이딴걸 편리하게 사용하는앱이라고 쳐만들엇나 이렇게 불편하게만든건 일부러그런거에...
# 3     2024-02-15   3  몇 년째 만족하며 사용중이라 조금식 개선되어거는 모습에 만족하며 사용중입니다. 하지...
# 4     2023-06-19   5                           스타뱅킹을 사용 하고나서부터 편안해서 좋아요
# ...          ...  ..                                                ...
# 9529  2025-04-05   1  만보기 이벤트는 실망스러워요. 후기 말투 다 똑같고 사기 맞죠? 양심이 참... 정...
# 9530  2023-05-17   5                 기능이 많아 다 사용해보진 못 했지만 대체적으로 편한거 같아요
# 9531  2023-07-05   5                                             편리하네요.
# 9532  2024-12-20   5                                          사용하기 편리해요
# 9533  2024-03-06   1  너무 후져서 오랜만에 어플이용하다가 욕했답니다 인증방식이 2010년대에 머물러계심 ...
#
#                                                    업체답변    은행명  긍정
# 0     안녕하세요 최순녀 고객님. 칭찬 진심으로 감사드리며, 더욱 편리하고 안정적인 서비스...     우리   1
# 1     신아​ 님, 안녕하세요? 뱅크샐러드 고객감동팀​입니다. 소중한 시간내어 고객센터에 ...  뱅크샐러드   1
# 2     안녕하세요. 우리은행입니다. 먼저 우리WON뱅킹 이용에 불편을 드려 죄송합니다. 보...     우리   0
# 3     안녕하세요? 뱅크샐러드 고객감동팀입니다. 뱅크샐러드에 KB pay를 연결해 모든 자...  뱅크샐러드   0
# 4     한송림 고객님, 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. 앞...     국민   1
# ...                                                 ...    ...  ..
# 9529  안녕하세요. 송송님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 노력하였으나,...     토스   0
# 9530  이강욱 고객님 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. 고객...     국민   1
# 9531  농사꾼 고객님, 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. 앞...     국민   1
# 9532  고객님 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. KB스타뱅킹...     국민   1
# 9533  안녕하세요 신한은행입니다.\n먼저 SOL사용에 불편을 드려 정말 죄송합니다.\n고객...     신한   0
#
# [9534 rows x 6 columns]

# %%
train_df['은행명'].value_counts()
# Out:
# 은행명
# 국민       8863
# 토스       6201
# 우리       2969
# 하나       1932
# 신한       1764
# 뱅크샐러드     517
# Name: count, dtype: int64

# %% [markdown]
# # 변수를 자동으로 생성하면서 긍정부정데이터 프레임 만들기
# * globals()[변수명]

# %%
bank_en_list = ['hana','shinhan','kb',  'toss','woori','b_salad']

# %%
pos_neg_list = []
for bank,bank_eng in zip(train_df['은행명'].unique(), bank_en_list):
    # 은행별 긍정 부정 리뷰를 필터링
    pos = train_df[(train_df['은행명']==bank) & (train_df['긍정']==1)]
    neg = train_df[(train_df['은행명']==bank) & (train_df['긍정']==0)]
    # 전역변수를 자동 생성해서 저장
    globals()[f"{bank_eng}_pos"] = pos
    globals()[f"{bank_eng}_neg"] = neg
    pos_neg_list.append(f"{bank_eng}_pos")
    pos_neg_list.append(f"{bank_eng}_neg")
    
    # 시각화
    plt.bar(['긍정','부정'], [pos.shape[0],neg.shape[0]], color=['skyblue', 'salmon'])
    plt.title(f"{bank}긍부정 분포")
    plt.ylabel("리뷰수")
    plt.ylim(0, max(pos.shape[0],neg.shape[0])+ 100)
    plt.show()
    print()
    print(pos.shape[0],neg.shape[0])
# Out:
# 1042 890
# 755 1009
# 7553 1310
# 2415 3786
# 1146 1823
# 329 188

# %%
train_df[(train_df['은행명']=='토스') & (train_df['긍정']==1)]
train_df[(train_df['은행명']=='토스') & (train_df['긍정']==0)]
# Out:
#               리뷰일  평점                                              사용자리뷰  \
# 3      2024-09-01   1                                          카드 충천이 안됌
# 5      2025-01-01   1  토스쇼핑 맘카페에서 피해자 올라온것 보니 교묘하게 사기치고 하는 판매자 있는데 관리...
# 6      2025-03-23   3                      고양이키우기 쿠폰 유효기간 6일. 넘 한거 아닌가요?
# 8      2024-01-05   1  제가 토스 계좌에 돈이 좀 남아있는 상황에서 핸드폰이 고장나 핸드폰을 초기화 했는데...
# 10     2025-02-28   1                                     고양이 놀기 광고 더 붙음
# ...           ...  ..                                                ...
# 22210  2023-12-05   1  이젠 하다하다 캐릭터 소장 500원 됐네 100원일땐 오히려 만원정도야 쓸만하네 이...
# 22222  2024-04-21   3  점점 토스가 야박해지네요. 토스포인트 인출할때도 수수료가 비싸고 친구랑 토스켜기도 ...
# 22230  2023-06-15   2  프로그램 오류가 매우 많아서 쓰기 매우 불편하다. 위치 설정 "안한다"고 하면 안내...
# 22237  2023-08-17   1  라이브방송으로 포인트잘모았는데 요즘은 별로 시스템이 점점 포인트를 안주려고하는듯.....
# 22245  2023-08-09   1  라이브 광고 전보다 더 안좋네 아무리 주기 싫어도 겨우 3원줄거면서 너무 쪼잔하게 ...
#
#                                                     업체답변 은행명  긍정
# 3      안녕하세요. 전민구 님, 토스팀입니다. 남겨주신 내용만으로는 겪고계신 불편사항의 자...  토스   0
# 5      안녕하세요. 유뚜뚜님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 노력하였으나...  토스   0
# 6      안녕하세요. 한호야 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 노력하였으...  토스   0
# 8      안녕하세요. 고객님, 토스 고객센터입니다. 남겨주신 내용만으로는 정확한 확인이 어려...  토스   0
# 10     안녕하세요. ㅂㅁ 님, 토스팀입니다. 먼저 서비스 이용에 불편을 드렸다면 대단히 죄...  토스   0
# ...                                                  ...  ..  ..
# 22210  안녕하세요. seoyoon choi님, 토스 고객센터입니다. 만족스러운 서비스를 제...  토스   0
# 22222  안녕하세요. 지승진고객님, 토스 고객센터입니다. 토스를 이용하시면서 느끼신 소중한 ...  토스   0
# 22230  안녕하세요. 김석곤님, 토스 고객센터입니다. 먼저 서비스 이용에 불편을 드렸다면 죄...  토스   0
# 22237  안녕하세요. 겜즐 님. 토스 고객센터입니다. 토스 앱은 다양한 혜택과 서비스를 제공...  토스   0
# 22245  안녕하세요. 송재영님, 토스 고객센터입니다. 토스를 이용하시면서 느끼신 소중한 의견...  토스   0
#
# [3786 rows x 6 columns]

# %%
pos_neg_list
# Out:
# ['hana_pos',
#  'hana_neg',
#  'shinhan_pos',
#  'shinhan_neg',
#  'kb_pos',
#  'kb_neg',
#  'toss_pos',
#  'toss_neg',
#  'woori_pos',
#  'woori_neg',
#  'b_salad_pos',
#  'b_salad_neg']

# %%
for bank in pos_neg_list:
    display(globals()[bank])
# Out:
#               리뷰일  평점                                              사용자리뷰  \
# 0      2023-12-21   5        엄빠 폰에 설치해드렸는데 두분 다 쓰기 편하다고 하시네요 ㅎㅎ 저도 쓰고있음!
# 27     2024-05-07   4  Not Found 실행이 안됩니다 하나은행 어플 누르면 Not Found 메세지 뜨...
# 58     2024-09-05   5    뱅킹. 잘. 이용하고. 있어요. 항상친절. 하게 설명. 해 주셔서. 감사. 수고하세요
# 59     2024-03-15   5                                             잘쓰고잇어용
# 66     2024-11-30   5                                             감사합니다!
# ...           ...  ..                                                ...
# 22120  2024-10-11   5                    입, 출, 현황을 확인할 수 있어 매우 편리하고 좋아요.
# 22165  2023-10-11   5                                        최고입니다 감사합니다
# 22196  2024-12-30   5                                         감사합니다?????
# 22202  2023-07-03   5                                           간편하고 좋네요
# 22214  2023-06-14   5                                                좋아요
#
#                                                     업체답변 은행명  긍정
# 0                                                    NaN  하나   1
# 27     안녕하세요. 하나은행입니다. 우선 이용에 불편을 드려 대단히 죄송합니다. 5/7일 ...  하나   1
# 58     안녕하세요. 하나은행입니다. 하나원큐 앱 서비스를 이용해 주셔서 감사드립니다. 손님...  하나   1
# 59     안녕하세요. 하나은행입니다. 하나원큐 앱 서비스를 이용해 주셔서 감사드립니다. 손님...  하나   1
# 66     안녕하세요. 하나은행입니다. 하나원큐 앱 서비스를 이용해 주셔서 감사드립니다. 손님...  하나   1
# ...                                                  ...  ..  ..
# 22120  안녕하세요. 하나은행입니다. 하나원큐 앱 서비스를 이용해 주셔서 감사드립니다. 손님...  하나   1
# 22165                                                NaN  하나   1
# 22196  안녕하세요. 하나은행입니다. 하나원큐 앱 서비스를 이용해 주셔서 감사드립니다. 손님...  하나   1
# 22202                                                NaN  하나   1
# 22214                                                NaN  하나   1
#
# [1042 rows x 6 columns]
#               리뷰일  평점                                              사용자리뷰  \
# 9      2023-08-22   1                                         앱이 안열려요.ㅠㅠ
# 23     2025-01-13   1  지문 로그인 이었는데 아까 까지만 해도 잘 되다가 갑자기 서명 필수값이 없다고 나오...
# 55     2025-02-23   2                       어플 서비스 원활하지 못하고있습니다 빠른수정바랍니다
# 63     2024-09-20   1               축구예매때문에 통장계설을 해야한고 퉤 직관포기 이러니 관중이 없지
# 101    2024-05-07   1  왜 업데이트하고 나니까 계속 not found 에러 뜨나요? 삭제하고 다시 설치했는...
# ...           ...  ..                                                ...
# 22153  2023-07-04   1                                   축구예매하기 왜이리 복잡함??
# 22197  2024-01-27   1                                    인증을 몇 번을 계속 하내요
# 22199  2023-06-28   1  외화 이체하는데 몇번을 시도해도 마지막 비밀번호 치는 화면에서 멈춰서 제때 이체도 ...
# 22232  2024-01-08   1  (2024년 1월 수정) 급여계좌인데 어플 접속이 안되면 어쩌자는겁니까 오늘부로 급...
# 22238  2023-10-25   1  어제부터 사용하고 있는데 시스템장애라고 회원가입도 못하고 있었네요,,ㅎ 진짜 다른 ...
#
#                                                     업체답변 은행명  긍정
# 9      안녕하세요, 하나은행입니다. 우선 서비스 이용에 불편을 드려 죄송합니다. 앱리뷰 내...  하나   0
# 23     안녕하세요. 하나은행입니다. 우선 이용에 불편을 드려 죄송합니다. 계속적으로 동일한...  하나   0
# 55     안녕하세요. 하나은행입니다. 하나원큐 이용 감사드립니다. 단순 앱리뷰라 손님의 정확...  하나   0
# 63     안녕하세요. 하나은행입니다. 하나은행 계좌가 없으셔도 축구티켓 예매가 가능합니다. ...  하나   0
# 101    안녕하세요. 하나은행입니다. 우선 이용에 불편을 드려 대단히 죄송합니다. 5/7일 ...  하나   0
# ...                                                  ...  ..  ..
# 22153                                                NaN  하나   0
# 22197                                                NaN  하나   0
# 22199                                                NaN  하나   0
# 22232  안녕하세요, 하나은행입니다. 우선 이용에 불편을 드려 죄송합니다. 데이터 환경이 불...  하나   0
# 22238  안녕하세요, 하나은행입니다. 우선 이용에 불편을 드려 죄송합니다. 앱리뷰 내용만으로...  하나   0
#
# [890 rows x 6 columns]
#               리뷰일  평점                                              사용자리뷰  \
# 56     2023-10-17   5                상세설명과 부족한 저에게 기다려주시고 친절하심에 감사합니다 ^^
# 114    2023-10-26   5                                                  굿
# 157    2024-10-24   4                         전산상 확인이 안되는 상품설명이 있어서 아쉽네요
# 174    2024-07-18   5                                                  굳
# 178    2025-03-11   5          안녕하세요^.^신한어플한가지만개선했면해요~복잡합니다~다크모드개선해주세요~~
# ...           ...  ..                                                ...
# 22108  2024-07-29   5                             편하게 쓸수있고 이벤트가 다양해서 좋아요
# 22157  2023-07-27   5  평소에 잘 쓰고있어서 별점은 5개 줬어요. 근데 오늘 업뎃하고나서 앱열면 시작페이지...
# 22209  2023-09-13   5                                               좋아요?
# 22212  2024-03-20   4                                                좋아요
# 22221  2024-02-26   5         신한은행은 시시각각으로 야구라든가 금융정보들을 전송해줘서 넘나 유용합니다^^
#
#                                                     업체답변 은행명  긍정
# 56     안녕하세요. 고객님\n쏠을 잘 이용해주셔서 감사합니다.\n신한은행 쏠은 고객님들이 ...  신한   1
# 114    안녕하세요. 고객님\n쏠을 잘 이용해주셔서 감사합니다.\n신한은행 쏠은 고객님들이 ...  신한   1
# 157    안녕하세요 신한은행입니다.\n먼저 SOL사용에 불편을 드려 죄송합니다.\n다만 남겨...  신한   1
# 174    안녕하세요 고객님 신한SOL뱅크 이용에 감사드립니다.\n신한은행은 고객님들이 더욱 ...  신한   1
# 178    안녕하세요 신한은행입니다.\n먼저 SOL 이용에 불편을 드려 정말 죄송합니다.\n고...  신한   1
# ...                                                  ...  ..  ..
# 22108  안녕하세요. 고객님\n쏠을 잘 이용해주셔서 감사합니다.\n신한은행 쏠은 고객님들이 ...  신한   1
# 22157  안녕하세요 신한은행입니다. 먼저 SOL 사용에 불편을 드려 죄송합니다. 고객님이 남...  신한   1
# 22209  안녕하세요. 고객님\n쏠을 잘 이용해주셔서 감사합니다.\n신한은행 쏠은 고객님들이 ...  신한   1
# 22212  안녕하세요. 고객님\n쏠을 잘 이용해주셔서 감사합니다.\n신한은행 쏠은 고객님들이 ...  신한   1
# 22221  안녕하세요. 고객님\n쏠을 잘 이용해주셔서 감사합니다.\n신한은행 쏠은 고객님들이 ...  신한   1
#
# [755 rows x 6 columns]
#               리뷰일  평점                                              사용자리뷰  \
# 1      2025-02-17   1  Cd기 축소 연장하려면 이 어플 깔라는데 왜 30퍼에서 안깔리는지 아니 애초에 슈퍼...
# 32     2023-12-18   3                            입출금목록에서 터치해서메모입력하던게안되네요
# 36     2024-04-01   1  상품 가입할때 적으라는거 다적고 서류 가져오라는거 다 하고 마지막에 완료 버튼 누르...
# 50     2024-05-03   1         무한로딩 안넘어가요 다음페이지가 급하게 입금할일 있을때마다 답답해 죽겠습니다
# 86     2023-06-28   2     ㅣㅌㅈㅅㅈㅎㅊ9ㅈㅇㅅㅈㅅㅊ ㄴ9ㅉㅎㅈㅅㅈㅎㅈㅅㄴㅆㅈㅎㅈㅎ. 즞ㄷㄷㄴ $ .ㄷㅅㅊ99
# ...           ...  ..                                                ...
# 22066  2023-08-14   1                 지문등록하려는데 왜 인증번호 메세지가 안와요 확인 안하시나요?
# 22070  2023-07-01   1  다 같은 상황을 겪고있는데 왜 아직도 수정을 안해주시나요? 이벤트 참여도 안되고 하...
# 22075  2023-07-20   1  은행어플이 맞는지도 의심스러움..이거 모의어플임? 업뎃 안하고 내계좌봐도 하얀벽돌폰...
# 22110  2024-11-23   1  그놈의 빛번짐 도대체 어떻게 하라는 건지를 모르겠습니다. 비대면 실명인증 하는데 온...
# 22227  2023-06-29   1  업데이트이후 너무 느려짐!! 조회하는데 시간이 너무 오래걸리고 로그인할때 인증서 확...
#
#                                                     업체답변 은행명  긍정
# 1      안녕하세요. 신한은행입니다.\n먼저 SOL사용에 불편을 드려 죄송합니다.\n어플의 ...  신한   0
# 32     안녕하세요 신한은행입니다. 먼저, 신한은행을 이용해 주신 고객님께 감사의 말씀 드리...  신한   0
# 36     안녕하세요 신한은행입니다.\n먼저 이용에 불편을 드려 정말 죄송합니다.\n고객님 상...  신한   0
# 50     안녕하세요 신한은행입니다.\n먼저 SOL사용에 불편을 드려 죄송합니다.\n고객님이 ...  신한   0
# 86                                                   NaN  신한   0
# ...                                                  ...  ..  ..
# 22066  안녕하세요 신한은행입니다.\n먼저 이용에 불편을 드려 정말 죄송합니다.\n인증 문자...  신한   0
# 22070  안녕하세요 신한은행입니다.\n먼저 SOL사용에 불편을 드려 정말 죄송합니다.\n리뷰...  신한   0
# 22075  안녕하세요 신한은행입니다. 먼저 SOL 사용에 불편을 드려 죄송합니다. 고객님이 남...  신한   0
# 22110  안녕하세요 신한은행입니다.\n먼저 SOL 이용에 불편을 드려 죄송합니다.\n신분증진...  신한   0
# 22227  안녕하세요 신한은행입니다. 먼저 앱 이용 시 속도로 인해 불편을 드려서 죄송합니다....  신한   0
#
# [1009 rows x 6 columns]
#               리뷰일  평점                                    사용자리뷰  \
# 2      2024-07-26   5            서비스가 통합되어 있어서 점점 사용빈도가 높아지네요.
# 15     2024-03-08   5                                        굿
# 16     2023-08-01   5                                       좋음
# 17     2023-12-20   5                                 매우 만족합니다
# 19     2023-11-28   5                                   만족합니다.
# ...           ...  ..                                      ...
# 22235  2025-04-01   5                           가입하는데 쉽고 편리합니다
# 22236  2023-07-22   5                                 환전신청 편해요
# 22239  2023-10-16   5  시스템 이용에 관한 설명이 잘 되어 있어 쉽게 일 처리할 수 있었습니다
# 22240  2023-06-09   5                                친절하고 상냥해요
# 22243  2023-07-07   5                                      굳굳굳
#
#                                                     업체답변 은행명  긍정
# 2      고객님 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. KB스타뱅킹...  국민   1
# 15     고객님 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. KB스타뱅킹...  국민   1
# 16     윤종미 고객님, 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. 앞...  국민   1
# 17     고객님 안녕하세요! KB스타뱅킹을 이용해 주시고 바쁘신 와중에 칭찬글 남겨주시어 진...  국민   1
# 19     고객님, 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사합니다. 앞으로도 고...  국민   1
# ...                                                  ...  ..  ..
# 22235  고객님 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. KB스타뱅킹...  국민   1
# 22236  Ji K 고객님, 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. ...  국민   1
# 22239  올리도라 고객님, 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사합니다. 앞...  국민   1
# 22240  Jin seog Kang 고객님 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 ...  국민   1
# 22243  Seung Woo Kim 고객님, 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로...  국민   1
#
# [7553 rows x 6 columns]
#               리뷰일  평점                                              사용자리뷰  \
# 39     2025-03-04   3                         앱 켤때 70%는 다시 켜야됨. 캐시 남아있다고
# 85     2025-03-01   1                          알림 받기 싫다고! 알림설정 안하면 사용못하네
# 87     2023-08-25   1                                                  굳
# 88     2023-09-01   1            느리고 접속안됨 인증서 만들어도 인벨리드 뜨면서 오류 그냥 어쩌라는건지
# 90     2024-11-20   1  매일걷기 하려는데 구글에서 액세스 차단돼서 못하고 있어요 이거 개발사 문제라는데 해...
# ...           ...  ..                                                ...
# 22188  2025-02-21   3                         알림을 확인했는데도 알림표시가 없어지지 않습니다
# 22203  2024-11-26   1  걸음수 연동하려고 하면 차단된 앱이라고 하면서 구글 계정의 민감한 정보에 엑세스 하...
# 22213  2024-07-31   1                                 잘되다가앱이안열리네요어떵게해안될지
# 22220  2023-09-05   1  입출금알림을 받으려면 혜택알림 동의가 기본적으로 되어야하는게 너무 싫으네요! 이 부...
# 22224  2025-04-02   1                       업데이트후 20000보에 걸음수26보 측정되네요 ㅎ
#
#                                                     업체답변 은행명  긍정
# 39     고객님, 안녕하세요. KB스타뱅킹 이용에 불편을 드려 죄송합니다. 앱 구동이 원활하...  국민   0
# 85     고객님 안녕하세요! KB스타뱅킹 이용에 불편을 드려 죄송합니다. 만일 광고성 알림을...  국민   0
# 87     김영중 고객님, 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사합니다. 앱 ...  국민   0
# 88     민속 고객님, 안녕하세요! KB스타뱅킹 이용에 불편을 드려 대단히 죄송합니다. 앱 ...  국민   0
# 90     고객님 안녕하세요! KB스타뱅킹을 이용에 불편을 드려 대단히 죄송합니다. 현재 구글...  국민   0
# ...                                                  ...  ..  ..
# 22188  고객님, 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사합니다. KB스타뱅킹...  국민   0
# 22203  고객님 안녕하세요! KB스타뱅킹을 이용에 불편을 드려 대단히 죄송합니다. 현재 구글...  국민   0
# 22213  안녕하세요 고객님. KB스타뱅킹 이용에 불편을 드려 죄송합니다. 업데이트 이후 앱구...  국민   0
# 22220  mj n 고객님, 안녕하세요! 이용에 불편을 드려 죄송합니다. KB스타뱅킹 알림서비...  국민   0
# 22224  고객님, 안녕하세요. KB매일걷기 서비스 이용 시 걸음수 연동이 원활하지 않은 현상...  국민   0
#
# [1310 rows x 6 columns]
#               리뷰일  평점                                              사용자리뷰  \
# 11     2023-10-11   4                                                좋아요
# 29     2023-11-16   5                                                 조아
# 33     2024-10-08   5  초등학생이 쓰기도 너무 좋고 계좌도 되고 이벤트나 돈 넣는거,주는거 너무 편해서 좋...
# 38     2025-04-04   4           보상을 얻기위해 광고를 보는건 상관없는데 광고 좀 가려 받으면 안되나요?
# 49     2023-09-07   5                                        잘쓰고 있고 편해요.
# ...           ...  ..                                                ...
# 22190  2024-08-03   5                                   티메프 사태로 토스에게 감동!
# 22204  2023-11-29   4  너무 잘쓰고있어요.한가지 궁금한게 있는데 토스유스카드 발급을 받았는데요. 교통카드로...
# 22208  2024-09-07   5                                 응 은행어플 안써 토스가 최고야ㅇ
# 22225  2023-10-08   5  저 해냄 저금통에 돈 꺼내기와 돈 채우기가 안보여요. 만들었는데 안보여서 송금하기에...
# 22233  2024-05-18   4  요즘3일간 토스에들어가지 않았더니 갑자기 인증창이 뜨면서 토스가 다시인증하라네요 이...
#
#                                                     업체답변 은행명  긍정
# 11                                                   NaN  토스   1
# 29                                                   NaN  토스   1
# 33                                                   NaN  토스   1
# 38     안녕하세요. 성은하님, 토스팀입니다. 사용에 불편을 드려 죄송합니다. 다만, 남겨주...  토스   1
# 49                                                   NaN  토스   1
# ...                                                  ...  ..  ..
# 22190                                                NaN  토스   1
# 22204  안녕하세요. 성이름님, 토스 고객센터입니다. 토스 유스카드의 경우, 결제 기능과 교...  토스   1
# 22208                                                NaN  토스   1
# 22225  안녕하세요. 금성제님, 토스 고객센터입니다. 먼저 이용에 불편을 드려 죄송합니다. ...  토스   1
# 22233  안녕하세요. 고주원님, 토스 고객센터입니다. 남겨주신 내용만으로는 겪고계신 불편사항...  토스   1
#
# [2415 rows x 6 columns]
#               리뷰일  평점                                              사용자리뷰  \
# 3      2024-09-01   1                                          카드 충천이 안됌
# 5      2025-01-01   1  토스쇼핑 맘카페에서 피해자 올라온것 보니 교묘하게 사기치고 하는 판매자 있는데 관리...
# 6      2025-03-23   3                      고양이키우기 쿠폰 유효기간 6일. 넘 한거 아닌가요?
# 8      2024-01-05   1  제가 토스 계좌에 돈이 좀 남아있는 상황에서 핸드폰이 고장나 핸드폰을 초기화 했는데...
# 10     2025-02-28   1                                     고양이 놀기 광고 더 붙음
# ...           ...  ..                                                ...
# 22210  2023-12-05   1  이젠 하다하다 캐릭터 소장 500원 됐네 100원일땐 오히려 만원정도야 쓸만하네 이...
# 22222  2024-04-21   3  점점 토스가 야박해지네요. 토스포인트 인출할때도 수수료가 비싸고 친구랑 토스켜기도 ...
# 22230  2023-06-15   2  프로그램 오류가 매우 많아서 쓰기 매우 불편하다. 위치 설정 "안한다"고 하면 안내...
# 22237  2023-08-17   1  라이브방송으로 포인트잘모았는데 요즘은 별로 시스템이 점점 포인트를 안주려고하는듯.....
# 22245  2023-08-09   1  라이브 광고 전보다 더 안좋네 아무리 주기 싫어도 겨우 3원줄거면서 너무 쪼잔하게 ...
#
#                                                     업체답변 은행명  긍정
# 3      안녕하세요. 전민구 님, 토스팀입니다. 남겨주신 내용만으로는 겪고계신 불편사항의 자...  토스   0
# 5      안녕하세요. 유뚜뚜님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 노력하였으나...  토스   0
# 6      안녕하세요. 한호야 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 노력하였으...  토스   0
# 8      안녕하세요. 고객님, 토스 고객센터입니다. 남겨주신 내용만으로는 정확한 확인이 어려...  토스   0
# 10     안녕하세요. ㅂㅁ 님, 토스팀입니다. 먼저 서비스 이용에 불편을 드렸다면 대단히 죄...  토스   0
# ...                                                  ...  ..  ..
# 22210  안녕하세요. seoyoon choi님, 토스 고객센터입니다. 만족스러운 서비스를 제...  토스   0
# 22222  안녕하세요. 지승진고객님, 토스 고객센터입니다. 토스를 이용하시면서 느끼신 소중한 ...  토스   0
# 22230  안녕하세요. 김석곤님, 토스 고객센터입니다. 먼저 서비스 이용에 불편을 드렸다면 죄...  토스   0
# 22237  안녕하세요. 겜즐 님. 토스 고객센터입니다. 토스 앱은 다양한 혜택과 서비스를 제공...  토스   0
# 22245  안녕하세요. 송재영님, 토스 고객센터입니다. 토스를 이용하시면서 느끼신 소중한 의견...  토스   0
#
# [3786 rows x 6 columns]
#               리뷰일  평점                 사용자리뷰  \
# 7      2024-04-15   5       알아듣게 잘 이용 가입했어요
# 12     2024-05-30   5                 편리합니다
# 14     2023-11-21   4                    좋음
# 22     2024-05-30   5                  좋아요!
# 41     2025-03-17   5   너무편리하게 가입하고 이율도 높아요
# ...           ...  ..                   ...
# 22139  2023-07-14   5                     굿
# 22146  2024-10-27   5             방문없이 잘했네요
# 22172  2024-11-06   5     우리앱 넘 간편하고 쓰기 좋아요
# 22173  2024-12-10   5                편리해졌네요
# 22244  2024-10-10   5  오래시간 같이한 나의은행 든든합니다.
#
#                                                     업체답변 은행명  긍정
# 7      안녕하세요 Jinhee Joo 고객님, 우리은행 우리WON뱅킹을 이용해주셔서 감사합...  우리   1
# 12     안녕하세요 마마초록 고객님. 칭찬 진심으로 감사드리며, 더욱 편리하고 안정적인 서비...  우리   1
# 14     안녕하세요. 권유진 고객님, 우리은행입니다. 칭찬 진심으로 감사드리며, 더욱 편리하...  우리   1
# 22     안녕하세요 김만중 고객님. 칭찬 진심으로 감사드리며, 더욱 편리하고 안정적인 서비스...  우리   1
# 41     안녕하세요 KH Lee 고객님. 칭찬 진심으로 감사드리며, 더욱 편리하고 안정적인 ...  우리   1
# ...                                                  ...  ..  ..
# 22139  안녕하세요. 우리은행입니다. 칭찬 진심으로 감사드리며, 더욱 편리하고 안정적인 서비...  우리   1
# 22146                                                NaN  우리   1
# 22172  안녕하세요 심지영 고객님. 칭찬 진심으로 감사드리며, 더욱 편리하고 안정적인 서비스...  우리   1
# 22173  안녕하세요 junho kang 고객님. 칭찬 진심으로 감사드리며, 더욱 편리하고 안...  우리   1
# 22244  안녕하세요 lee jeong seon (isate) 고객님. 칭찬 진심으로 감사드리...  우리   1
#
# [1146 rows x 6 columns]
#               리뷰일  평점                                              사용자리뷰  \
# 4      2023-11-13   1                                   알뜰폰 인증이 안돼요.....
# 31     2024-02-16   1  비대면회원가입 카메라 인식 개못함. 어디 동네 지나가던 개가 인증해도 이것보단 빨리...
# 44     2023-10-29   1  앱이 어느 순간부터 아예 안열려요... 화면이 먹통.... 주 계좌가 우리은행인데 ...
# 46     2024-04-11   1  유심과 e심을 사용중인데 메인번호인 e심을 인식못해 유심번호로 인증이되고 이체시 오...
# 54     2025-03-12   1                           거래지연 안내 뜨면서 접속이 안되네요....
# ...           ...  ..                                                ...
# 22180  2024-12-15   1  위비트래블 마이메뉴에 두고 한번에 접근해서 쓰고있었는데 업데이트후 사라짐 하... ...
# 22189  2023-11-14   1  5번째 새로 깔고있어요. 몇번 쓰다가 첫화면에서 로딩걸려서 다음 화면이 전혀 안들어...
# 22200  2023-09-24   3  총잔액만 금액 off기능 있은면 좋겠어요 총액이 굵은 글씨로 노출되니 주변사람 신경...
# 22241  2025-03-12   3                                   어플 시작오류가 가끔 나네요.
# 22242  2025-01-09   1                            업데이트 후에 계좌이체하는 게 자주 튕겨요
#
#                                                     업체답변 은행명  긍정
# 4      안녕하세요 헤이모두들안녕님, 우리은행입니다. 먼저 이용에 불편을 드려 매우 죄송합니...  우리   0
# 31     안녕하세요 고객님. 먼저 우리WON뱅킹 이용에 불편을 드려 죄송합니다. 안면인식에 ...  우리   0
# 44     안녕하세요, 우리은행입니다. 이용에 불편을 드려 매우 죄송합니다. 남겨주신 내용만으...  우리   0
# 46     안녕하세요. 김종환 고객님, 우리은행입니다. 우리WON뱅킹 이용에 불편을 드려 죄송...  우리   0
# 54     안녕하세요 딸바보 고객님. 우리은행 우리WON뱅킹 이용에 불편을 드려 죄송합니다. ...  우리   0
# ...                                                  ...  ..  ..
# 22180  안녕하세요 남자는배 고객님, 우리은행 입니다. 우리WON뱅킹의 변화가 고객님의 일상...  우리   0
# 22189  안녕하세요. 우리은행입니다. 먼저 우리WON뱅킹 이용에 불편을 드려 죄송합니다. 보...  우리   0
# 22200  안녕하세요. 우리은행입니다. 먼저 우리WON뱅킹 이용에 불편을 드려 죄송합니다. 보...  우리   0
# 22241  안녕하세요 푸딩 고객님. 우리은행 우리WON뱅킹 이용에 불편을 드려 죄송합니다. 2...  우리   0
# 22242  안녕하세요 일월구일 고객님. 먼저 우리WON뱅킹 이용에 불편을 드려 죄송합니다. 보...  우리   0
#
# [1823 rows x 6 columns]
#               리뷰일  평점                                              사용자리뷰  \
# 141    2024-03-03   5      가계부로는 정말 편리해요. 한가지 문의가 있어요. 가족 카드는 등록할 수 없나요?
# 154    2024-01-29   5  너무 좋아요 그런데 가계부 달력을 볼때 일주일을 월~일 로 볼수있으면 좋겠어요 지금...
# 308    2023-06-04   5  가계부 달력으로 볼 수 있는 기능이 정말 좋은기능이라고 생각하는데 위젯으로 홈화면에...
# 316    2024-07-03   5  수입내역에는 아이콘 변경 하는 기능이 없나요? 지출 내역은 아이콘 변경이 되는데 수...
# 371    2023-10-20   5                                             정말 베리굿
# ...           ...  ..                                                ...
# 21694  2024-05-18   4                            미성년자는 왜 법적으로 못하게 막는 거지?
# 21736  2023-07-16   4                                          ㆍㄴㄷ ?듯 ㅡ느
# 22015  2023-04-07   5  [자산관리 영역의 삶의 질은 뱅샐 전과 후로 나뉨] 1. 자산 현황 한눈에 파악 2...
# 22063  2024-01-19   5                                                  굿
# 22150  2024-03-18   5  퇴직연금 (회사가입분)은 왜 인식을 못하는건가요? 예전엔 되었던거같은데 삼성증권 퇴...
#
#                                                     업체답변    은행명  긍정
# 141    안녕하세요? 뱅크샐러드 고객감동팀입니다. 현재 뱅크샐러드에서는 마이데이터를 통한 기...  뱅크샐러드   1
# 154    안녕하세요? 뱅크샐러드 고객감동팀입니다. 가계부의 달력이 일요일 시작으로 고정되어 ...  뱅크샐러드   1
# 308    김김김 님, 안녕하세요. 뱅크샐러드 고객감동팀입니다. 뱅크샐러드를 이용해 주시고, ...  뱅크샐러드   1
# 316    안녕하세요? 뱅크샐러드 고객감동팀입니다. 뱅크샐러드를 이용해 주시고, 리뷰 남겨 주...  뱅크샐러드   1
# 371    만점강사​ 님, 안녕하세요? 뱅크샐러드 고객감동팀​입니다. 뱅크샐러드를 이용해 주시...  뱅크샐러드   1
# ...                                                  ...    ...  ..
# 21694  안녕하세요? 뱅크샐러드 고객감동팀입니다. 뱅크샐러드를 이용해 주시고 리뷰 남겨 주셔...  뱅크샐러드   1
# 21736  강두호​ 님, 안녕하세요? 뱅크샐러드 고객감동팀​입니다. 뱅크샐러드를 이용해 주시고...  뱅크샐러드   1
# 22015  안녕하세요? 뱅크샐러드입니다. 먼저, 뱅크샐러드를 이용해주시고 소중한 리뷰 남겨주셔...  뱅크샐러드   1
# 22063  안녕하세요? 뱅크샐러드 고객감동팀입니다. 뱅크샐러드를 만족스럽게 이용하고 계신 것 ...  뱅크샐러드   1
# 22150  안녕하세요? 뱅크샐러드 고객감동팀입니다. 뱅크샐러드에 퇴직연금을 연결해 모든 자산을...  뱅크샐러드   1
#
# [329 rows x 6 columns]
#               리뷰일  평점                                              사용자리뷰  \
# 188    2023-08-04   1                     쓸데없는기능이많아 로딩이오래걸리고 막상 가계부로서는별로
# 221    2023-04-05   1                                    하루에 몇 명을 뽑는 걸까?
# 422    2023-12-30   1  스팟성 적금과 지출을 매번 구분해서 지정해야 하는게 번거롭습니다. 이를 지정하지 않...
# 442    2023-11-13   2  앱 삭제한지 꽤 되었는데 오늘 갑자기 신용조회기록이 발생했다고 카톡이 왔어요 이게 ...
# 544    2023-05-11   1            일부 카드(삼성카드 등)사 연동이 안돼서 수기로 작성해야 하거나 누락됨
# ...           ...  ..                                                ...
# 21711  2024-08-23   1  가입할때 계좌번호 복붙이 한 10년전 개발한 어플처럼 하이픈 이론고 안빠지고 붙여넣...
# 22062  2024-09-08   1                      이번 업데이트 이후 앱 잔오류가 많아서 쓸때마다 빡침
# 22092  2025-04-04   1  뱅셀머니 송금계돠 연결 오류가 계속되네요. 인증까지 마친 후 본인계좌 예금주 확인한...
# 22151  2023-12-26   3  이번달 중순 부터 가계부 지출분석이 열리지 않아요 고객센터에 글도 2번이나 남겼는데...
# 22182  2025-01-14   3  연금 연결이 안돼요 쌓인 연금 확인하기 눌러도 자산 연결 페이지만 떠요 어떻게 해야...
#
#                                                     업체답변    은행명  긍정
# 188    안녕하세요? 뱅크샐러드 고객감동팀​입니다. 뱅크샐러드를 이용해 주시고 리뷰 남겨 주...  뱅크샐러드   0
# 221    최종원​ 님, 안녕하세요? 뱅크샐러드 고객감동팀​입니다. 뱅크샐러드를 이용해 주시고...  뱅크샐러드   0
# 422    안녕하세요? 뱅크샐러드 고객감동팀입니다. 먼저, 뱅크샐러드를 이용해주시고 이렇게 리...  뱅크샐러드   0
# 442    Flying Caramel​ 님, 안녕하세요? 뱅크샐러드 고객감동팀​입니다. 뱅크샐...  뱅크샐러드   0
# 544    Minsuk Kang 님, 안녕하세요. 뱅크샐러드 고객감동팀입니다. 뱅크샐러드를 이...  뱅크샐러드   0
# ...                                                  ...    ...  ..
# 21711  안녕하세요? 뱅크샐러드 고객감동팀입니다. 먼저, 뱅크샐러드를 이용해주시고 이렇게 리...  뱅크샐러드   0
# 22062  안녕하세요? 뱅크샐러드 고객감동팀입니다. 먼저, 뱅크샐러드를 이용해주시고 이렇게 리...  뱅크샐러드   0
# 22092  안녕하세요? 뱅크샐러드 고객감동팀입니다. 뱅크샐러드를 이용해 주시고, 리뷰 남겨 주...  뱅크샐러드   0
# 22151  안녕하세요? 뱅크샐러드 고객감동팀입니다. 뱅크샐러드를 이용해 주시고, 리뷰 남겨 주...  뱅크샐러드   0
# 22182  안녕하세요, 뱅크샐러드 고객감동팀입니다. 뱅크샐러드를 이용해주시고 연락 주셔서 감사...  뱅크샐러드   0
#
# [188 rows x 6 columns]

# %%
import re
def text_clean(x):
    pattern = r'[가-힣0-9a-zA-Z]+'
    matches = re.findall(pattern, x)
    matches = " ".join(matches)
    return matches

# %%
for bank in pos_neg_list:
    globals()[bank]['사용자리뷰']= globals()[bank]['사용자리뷰'].apply(text_clean)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16472\3926909026.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   globals()[bank]['사용자리뷰']= globals()[bank]['사용자리뷰'].apply(text_clean)

# %%
hana_pos['사용자리뷰']
# Out:
# 0                  엄빠 폰에 설치해드렸는데 두분 다 쓰기 편하다고 하시네요 저도 쓰고있음
# 27       Not Found 실행이 안됩니다 하나은행 어플 누르면 Not Found 메세지 뜨...
# 58                 뱅킹 잘 이용하고 있어요 항상친절 하게 설명 해 주셔서 감사 수고하세요
# 59                                                  잘쓰고잇어용
# 66                                                   감사합니다
#                                ...
# 22120                         입 출 현황을 확인할 수 있어 매우 편리하고 좋아요
# 22165                                          최고입니다 감사합니다
# 22196                                                감사합니다
# 22202                                             간편하고 좋네요
# 22214                                                  좋아요
# Name: 사용자리뷰, Length: 1042, dtype: object

# %% [markdown]
# # 은행별 긍부정 리뷰 워드클라우드 만들기

# %%
# ! pip install wordcloud

# %%
from wordcloud import WordCloud
from konlpy.tag import Mecab
mecab = Mecab()

# %%
pos_neg_list
# Out:
# ['hana_pos',
#  'hana_neg',
#  'shinhan_pos',
#  'shinhan_neg',
#  'kb_pos',
#  'kb_neg',
#  'toss_pos',
#  'toss_neg',
#  'woori_pos',
#  'woori_neg',
#  'b_salad_pos',
#  'b_salad_neg']

# %%
# 사용자리뷰 컬럼을 Series에서 list 변경해서 담고
# .tolist()쓰면 어레이를 리스트로
# 다시 join으로 1개의 문자열로 변환
text_data = hana_pos['사용자리뷰'].astype(str).tolist()
full_text = " ".join(text_data)
full_text

# 불용어 세트 생성
stopwords = set(['은행', '어플', '뱅킹'])

#명사 추출
nouns = mecab.nouns(full_text)
filtered = [word for word in nouns if len(word)> 1 and word not in stopwords]

# 빈도수 집계

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from gensim.models import CoherenceModel, Word2Vec
from gensim import corpora
from konlpy.tag import Mecab
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import numpy as np

mecab = Mecab()

# 형태소 기반 명사 토큰화 함수
def tokenize_texts(texts):
    return [[word for word in mecab.nouns(doc) if len(word) > 1] for doc in texts]

# 최적 토픽 수 탐색 함수
def find_optimal_topics(tokenized_texts, start=2, end=8):
    dictionary = corpora.Dictionary(tokenized_texts)
    corpus = [dictionary.doc2bow(text) for text in tokenized_texts]

    vectorizer = CountVectorizer(tokenizer=lambda x: x, lowercase=False)
    doc_term_matrix = vectorizer.fit_transform(tokenized_texts)

    best_score = -1
    best_n = start

    for n_topics in range(start, end + 1):
        try:
            lda_model = LatentDirichletAllocation(n_components=n_topics, random_state=42)
            lda_model.fit(doc_term_matrix)

            topics = []
            for topic in lda_model.components_:
                top_words = [vectorizer.get_feature_names_out()[i] for i in topic.argsort()[:-11:-1]]
                topics.append(top_words)

            cm = CoherenceModel(topics=topics, texts=tokenized_texts, dictionary=dictionary, coherence='c_v')
            score = cm.get_coherence()
            print(f"  → 토픽 수: {n_topics}, Coherence Score: {score:.4f}")
            if score > best_score:
                best_score = score
                best_n = n_topics
        except:
            continue

    return best_n

# 실제 실행 코드
for var in pos_neg_list:
    df = globals()[var]
    if len(df) < 20:
        print(f"{var} 리뷰 수 부족 - 스킵")
        continue

    texts = df['사용자리뷰'].dropna().tolist()
    print(f"\n[{var}] 최적 토픽 수 계산 중...")

    tokenized_texts = tokenize_texts(texts)
    print(tokenized_texts)
    best_k = find_optimal_topics(tokenized_texts)

    vectorizer = CountVectorizer(tokenizer=lambda x: x, lowercase=False, max_df=0.9, min_df=10)

    try:
        review_vec = vectorizer.fit_transform(tokenized_texts)
        lda_model = LatentDirichletAllocation(n_components=best_k, random_state=42)
        lda_model.fit(review_vec)
        words = vectorizer.get_feature_names_out()

        all_topic_words = set()
        print(f"\n[{var}] 토픽별 상위 단어 (K={best_k})\n" + "-" * 40)
        for i, topic in enumerate(lda_model.components_):
            top = [words[idx] for idx in topic.argsort()[-10:]]
            print(f"Topic #{i}: {top}")
            all_topic_words.update(top)

        # 전체 리뷰로 Word2Vec 학습
        all_reviews = train_df['사용자리뷰'].dropna().tolist()
        all_tokenized = tokenize_texts(all_reviews)
        w2v_model = Word2Vec(sentences=all_tokenized, vector_size=100, window=5, min_count=5, workers=4, sg=1)

        # 토픽 단어 중 Word2Vec에 있는 것만 시각화
        valid_words = [word for word in all_topic_words if word in w2v_model.wv]
        vectors = np.array([w2v_model.wv[word] for word in valid_words])

        if len(valid_words) >= 2:
            tsne = TSNE(n_components=2, random_state=0, perplexity=5, n_iter=5000)
            reduced_vecs = tsne.fit_transform(vectors)

            plt.figure(figsize=(10, 6))
            for i, word in enumerate(valid_words):
                x, y = reduced_vecs[i]
                plt.scatter(x, y)
                plt.text(x + 0.01, y + 0.01, word, fontsize=12)
            plt.title(f"{var} 토픽 단어의 Word2Vec 유사도 기반 시각화 (t-SNE)")
            plt.grid(True)
            plt.show()
        else:
            print("Word2Vec 모델에 포함된 단어가 너무 적습니다.")

    except ValueError as e:
        print(f"{var} LDA 오류: {e}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from sklearn.feature_extraction.text import CountVectorizer
#       2 from sklearn.decomposition import LatentDirichletAllocation
#       3 from gensim.models import CoherenceModel, Word2Vec
#
# File ~/miniforge3/envs/fintech/lib/python3.9/site-packages/sklearn/__init__.py:73
#      62 # `_distributor_init` allows distributors to run custom init code.
#      63 # For instance, for the Windows wheel, this is used to pre-load the
#      64 # vcomp shared library runtime for OpenMP embedded in the sklearn/.libs
#    (...)
#      67 # later is linked to the OpenMP runtime to make it possible to introspect
#      68 # it and importing it first would fail if the OpenMP dll cannot be found.
#      69 from . import (  # noqa: F401 E402
#      70     __check_build,
#      71     _distributor_init,
#      72 )
# ---> 73 from .base import clone  # noqa: E402
#      74 from .utils._show_versions import show_versions  # noqa: E402
#      76 _submodules = [
#      77     "calibration",
#      78     "cluster",
#    (...)
#     114     "compose",
#     115 ]
#
# File ~/miniforge3/envs/fintech/lib/python3.9/site-packages/sklearn/base.py:19
#      17 from ._config import config_context, get_config
#      18 from .exceptions import InconsistentVersionWarning
# ---> 19 from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#      20 from .utils._metadata_requests import _MetadataRequester, _routing_enabled
#      21 from .utils._param_validation import validate_parameter_constraints
#
# File ~/miniforge3/envs/fintech/lib/python3.9/site-packages/sklearn/utils/__init__.py:15
#      13 from . import _joblib, metadata_routing
#      14 from ._bunch import Bunch
# ---> 15 from ._chunking import gen_batches, gen_even_slices
#      16 from ._estimator_html_repr import estimator_html_repr
#      18 # Make _safe_indexing importable from here for backward compat as this particular
#      19 # helper is considered semi-private and typically very useful for third-party
#      20 # libraries that want to comply with scikit-learn's estimator API. In particular,
#      21 # _safe_indexing was included in our public API documentation despite the leading
#      22 # `_` in its name.
#
# File ~/miniforge3/envs/fintech/lib/python3.9/site-packages/sklearn/utils/_chunking.py:11
#       8 import numpy as np
#      10 from .._config import get_config
# ---> 11 from ._param_validation import Interval, validate_params
#      14 def chunk_generator(gen, chunksize):
#      15     """Chunk generator, ``gen`` into lists of length ``chunksize``. The last
#      16     chunk may have a length less than ``chunksize``."""
#
# File ~/miniforge3/envs/fintech/lib/python3.9/site-packages/sklearn/utils/_param_validation.py:17
#      14 from scipy.sparse import csr_matrix, issparse
#      16 from .._config import config_context, get_config
# ---> 17 from .validation import _is_arraylike_not_scalar
#      20 class InvalidParameterError(ValueError, TypeError):
#      21     """Custom exception to be raised when the parameter of a class/method/function
#      22     does not have a valid type or value.
#      23     """
#
# File ~/miniforge3/envs/fintech/lib/python3.9/site-packages/sklearn/utils/validation.py:21
#      19 from .. import get_config as _get_config
#      20 from ..exceptions import DataConversionWarning, NotFittedError, PositiveSpectrumWarning
# ---> 21 from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#      22 from ..utils.deprecation import _deprecate_force_all_finite
#      23 from ..utils.fixes import ComplexWarning, _preserve_dia_indices_dtype
#
# File ~/miniforge3/envs/fintech/lib/python3.9/site-packages/sklearn/utils/_array_api.py:17
#      14 import scipy.special as special
#      16 from .._config import get_config
# ---> 17 from .fixes import parse_version
#      19 _NUMPY_NAMESPACE_NAMES = {"numpy", "array_api_compat.numpy"}
#      22 def yield_namespaces(include_numpy_namespaces=True):
#
# File ~/miniforge3/envs/fintech/lib/python3.9/site-packages/sklearn/utils/fixes.py:17
#      15 import scipy
#      16 import scipy.sparse.linalg
# ---> 17 import scipy.stats
#      19 try:
#      20     import pandas as pd
#
# File ~/miniforge3/envs/fintech/lib/python3.9/site-packages/scipy/stats/__init__.py:606
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)
#     601
#     602 """  # noqa: E501
#     604 from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     605                                DegenerateDataWarning, FitError)
# --> 606 from ._stats_py import *
#     607 from ._variation import variation
#     608 from .distributions import *
#
# File ~/miniforge3/envs/fintech/lib/python3.9/site-packages/scipy/stats/_stats_py.py:49
#      47 import scipy.special as special
#      48 from scipy import linalg
# ---> 49 from . import distributions
#      50 from . import _mstats_basic as mstats_basic
#      51 from ._stats_mstats_common import (_find_repeats, linregress, theilslopes,
#      52                                    siegelslopes)
#
# File ~/miniforge3/envs/fintech/lib/python3.9/site-packages/scipy/stats/distributions.py:11
#       8 from ._distn_infrastructure import (rv_discrete, rv_continuous, rv_frozen)  # noqa: F401
#      10 from . import _continuous_distns
# ---> 11 from . import _discrete_distns
#      13 from ._continuous_distns import *  # noqa: F403
#      14 from ._levy_stable import levy_stable
#
# File ~/miniforge3/envs/fintech/lib/python3.9/site-packages/scipy/stats/_discrete_distns.py:10
#       8 from scipy.special import entr, logsumexp, betaln, gammaln as gamln, zeta
#       9 from scipy._lib._util import _lazywhere, rng_integers
# ---> 10 from scipy.interpolate import interp1d
#      12 from numpy import floor, ceil, log, exp, sqrt, log1p, expm1, tanh, cosh, sinh
#      14 import numpy as np
#
# File ~/miniforge3/envs/fintech/lib/python3.9/site-packages/scipy/interpolate/__init__.py:167
#       1 """
#       2 ========================================
#       3 Interpolation (:mod:`scipy.interpolate`)
#    (...)
#     165 (should not be used in new code).
#     166 """
# --> 167 from ._interpolate import *
#     168 from ._fitpack_py import *
#     170 # New interface to fitpack library:
#
# File ~/miniforge3/envs/fintech/lib/python3.9/site-packages/scipy/interpolate/_interpolate.py:14
#      11 from scipy._lib._util import copy_if_needed
#      12 from scipy.special import comb
# ---> 14 from . import _fitpack_py
#      15 from . import dfitpack
#      16 from ._polyint import _Interpolator1D
#
# File ~/miniforge3/envs/fintech/lib/python3.9/site-packages/scipy/interpolate/_fitpack_py.py:8
#       5 import numpy as np
#       7 # These are in the API for fitpack even if not used in fitpack.py itself.
# ----> 8 from ._fitpack_impl import bisplrep, bisplev, dblint  # noqa: F401
#       9 from . import _fitpack_impl as _impl
#      10 from ._bsplines import BSpline
#
# File ~/miniforge3/envs/fintech/lib/python3.9/site-packages/scipy/interpolate/_fitpack_impl.py:103
#      52 _iermess = {
#      53     0: ["The spline has a residual sum of squares fp such that "
#      54         "abs(fp-s)/s<=0.001", None],
#    (...)
#      68     'unknown': ["An error occurred", TypeError]
#      69 }
#      71 _iermess2 = {
#      72     0: ["The spline has a residual sum of squares fp such that "
#      73         "abs(fp-s)/s<=0.001", None],
#    (...)
#      99     'unknown': ["An error occurred", TypeError]
#     100 }
#     102 _parcur_cache = {'t': array([], float), 'wrk': array([], float),
# --> 103                  'iwrk': array([], dfitpack_int), 'u': array([], float),
#     104                  'ub': 0, 'ue': 1}
#     107 def splprep(x, w=None, u=None, ub=None, ue=None, k=3, task=0, s=None, t=None,
#     108             full_output=0, nest=None, per=0, quiet=1):
#     109     # see the docstring of `_fitpack_py/splprep`
#     110     if task <= 0:
#
# TypeError:

# %% [markdown]
# # LDA 기반 최적 토픽 추출 Word2vec 기반 t-SNE 시각화

# %%
pip install gensim
# Out:
# Requirement already satisfied: gensim in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from gensim) (7.1.0)
# Requirement already satisfied: wrapt in c:\users\admin\miniforge3\envs\fintech\lib\site-packages (from smart-open>=1.8.1->gensim) (1.17.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from konlpy.tag import Kkma
from konlpy.utils import pprint
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 from konlpy.tag import Kkma
#       2 from konlpy.utils import pprint
#
# ModuleNotFoundError: No module named 'konlpy'

# %%
from gensim.models import Word2Vec
from sklearn.manifold import TSNE

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from gensim.models import CoherenceModel, Word2Vec
from gensim import corpora
from konlpy.tag import Mecab
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import numpy as np

mecab = Mecab()

# 형태소 기반 명사 토큰화 함수
def tokenize_texts(texts):
    return [[word for word in mecab.nouns(doc) if len(word) > 1] for doc in texts]

# 최적 토픽 수 탐색 함수
def find_optimal_topics(tokenized_texts, start=2, end=8):
    dictionary = corpora.Dictionary(tokenized_texts)
    corpus = [dictionary.doc2bow(text) for text in tokenized_texts]

    vectorizer = CountVectorizer(tokenizer=lambda x: x, lowercase=False)
    doc_term_matrix = vectorizer.fit_transform(tokenized_texts)

    best_score = -1
    best_n = start

    for n_topics in range(start, end + 1):
        try:
            lda_model = LatentDirichletAllocation(n_components=n_topics, random_state=42)
            lda_model.fit(doc_term_matrix)

            topics = []
            for topic in lda_model.components_:
                top_words = [vectorizer.get_feature_names_out()[i] for i in topic.argsort()[:-11:-1]]
                topics.append(top_words)

            cm = CoherenceModel(topics=topics, texts=tokenized_texts, dictionary=dictionary, coherence='c_v')
            score = cm.get_coherence()
            print(f"  → 토픽 수: {n_topics}, Coherence Score: {score:.4f}")
            if score > best_score:
                best_score = score
                best_n = n_topics
        except:
            continue

    return best_n

# 실제 실행 코드
for var in pos_neg_list:
    df = globals()[var]
    if len(df) < 20:
        print(f"{var} 리뷰 수 부족 - 스킵")
        continue

    texts = df['사용자리뷰'].dropna().tolist()
    print(f"\n[{var}] 최적 토픽 수 계산 중...")

    tokenized_texts = tokenize_texts(texts)
#     print(tokenized_texts)
    best_k = find_optimal_topics(tokenized_texts)

    vectorizer = CountVectorizer(tokenizer=lambda x: x, lowercase=False, max_df=0.9, min_df=10)

    try:
        review_vec = vectorizer.fit_transform(tokenized_texts)
        lda_model = LatentDirichletAllocation(n_components=best_k, random_state=42)
        lda_model.fit(review_vec)
        words = vectorizer.get_feature_names_out()

        all_topic_words = set()
        print(f"\n[{var}] 토픽별 상위 단어 (K={best_k})\n" + "-" * 40)
        for i, topic in enumerate(lda_model.components_):
            top = [words[idx] for idx in topic.argsort()[-10:]]
            print(f"Topic #{i}: {top}")
            all_topic_words.update(top)

        # 전체 리뷰로 Word2Vec 학습
        all_reviews = train_df['사용자리뷰'].dropna().tolist()
        all_tokenized = tokenize_texts(all_reviews)
        w2v_model = Word2Vec(sentences=all_tokenized, vector_size=100, window=5, min_count=5, workers=4, sg=1)

        # 토픽 단어 중 Word2Vec에 있는 것만 시각화
        valid_words = [word for word in all_topic_words if word in w2v_model.wv]
        vectors = np.array([w2v_model.wv[word] for word in valid_words])

        if len(valid_words) >= 2:
            tsne = TSNE(n_components=2, random_state=0, perplexity=5, n_iter=5000)
            reduced_vecs = tsne.fit_transform(vectors)

            plt.figure(figsize=(10, 6))
            for i, word in enumerate(valid_words):
                x, y = reduced_vecs[i]
                plt.scatter(x, y)
                plt.text(x + 0.01, y + 0.01, word, fontsize=12)
            plt.title(f"{var} 토픽 단어의 Word2Vec 유사도 기반 시각화 (t-SNE)")
            plt.grid(True)
            plt.show()
        else:
            print("Word2Vec 모델에 포함된 단어가 너무 적습니다.")

    except ValueError as e:
        print(f"{var} LDA 오류: {e}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[48], line 5
#       3 from gensim.models import CoherenceModel, Word2Vec
#       4 from gensim import corpora
# ----> 5 from konlpy.tag import Mecab
#       6 from sklearn.manifold import TSNE
#       7 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'konlpy'
