# %%
# Matplotlib은 파이썬에서 그래프를 그릴 때 사용

* https://matplotlib.org/stable/users/getting_started/
* pip install matplotlib, conda install matplotlib
* pip install seaborn
* pip install koreanize-matplotlib

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import koreanize_matplotlib

# %% [markdown]
# # 간단한 그래프 예제

# %%
fig,ax = plt.subplots() # 도화지 준비
ax.plot([1,2,3,4],[1,2,3,4])
plt.show()

# %% [markdown]
# * figure: 전체 그래프가 그려지는 도화지
# * axes: 한 칸에 그려지는 그래프
# * axis: 그래프의 x,y축 눈금

# %%
fig = plt.figure()
plt.show()

# %% [markdown]
# ## x,y 축이 하나씩 있는 그래프 그리기

# %%
fig.ax =

# %% [markdown]
# # 2 x 2 4개 그래프 그리기

# %%
fig,ax = plt.subplots(2,2)
print(ax.shape)
print(ax)
print(ax[:1])
plt.show
# Out:
# (2, 2)
# [[<Axes: > <Axes: >]
#  [<Axes: > <Axes: >]]
# [[<Axes: > <Axes: >]]
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # 2x2 그래프에서 왼쪽 행 결합하기
# * subplot_mosic([left,right], [left,right])

# %%
fig, axes = plt.subplot_mosaic([["left", "right_top"], ['left', 'right_bottom']])
plt.show()

# %%
fig, axes = plt.subplot_mosaic([["top", "top"], ['left', 'right']])
print(axes)
plt.show()
# Out:
# {'top': <Axes: label='top'>, 'left': <Axes: label='left'>, 'right': <Axes: label='right'>}

# %% [markdown]
# # matplotlib의 2가지 코딩 스타일
# ## 00-스타일: maplotlib 공식 추천 스타일
# * 복잡한 그래프를 그릴 때 사용
# * 사용법이 pyplot 스타일보다 복잡함

# %%
x = np.linspace(0,2,100)
x
# Out:
# array([0.        , 0.02020202, 0.04040404, 0.06060606, 0.08080808,
#        0.1010101 , 0.12121212, 0.14141414, 0.16161616, 0.18181818,
#        0.2020202 , 0.22222222, 0.24242424, 0.26262626, 0.28282828,
#        0.3030303 , 0.32323232, 0.34343434, 0.36363636, 0.38383838,
#        0.4040404 , 0.42424242, 0.44444444, 0.46464646, 0.48484848,
#        0.50505051, 0.52525253, 0.54545455, 0.56565657, 0.58585859,
#        0.60606061, 0.62626263, 0.64646465, 0.66666667, 0.68686869,
#        0.70707071, 0.72727273, 0.74747475, 0.76767677, 0.78787879,
#        0.80808081, 0.82828283, 0.84848485, 0.86868687, 0.88888889,
#        0.90909091, 0.92929293, 0.94949495, 0.96969697, 0.98989899,
#        1.01010101, 1.03030303, 1.05050505, 1.07070707, 1.09090909,
#        1.11111111, 1.13131313, 1.15151515, 1.17171717, 1.19191919,
#        1.21212121, 1.23232323, 1.25252525, 1.27272727, 1.29292929,
#        1.31313131, 1.33333333, 1.35353535, 1.37373737, 1.39393939,
# ...

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))
ax.plot(x,x,label='linear')
ax.plot(x, x**2, label="quadratic")
ax.plot(x, x**3,label="cubic")
ax.set_xlabel('x label')
ax.set_ylabel('y label')
ax.set_title('간단그래프')
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(3,2,figsize=(5, 2.7))
ax[0,0].plot(x,x,label='linear')
ax[1,0].plot(x, x**2, label="quadratic")
ax[2,0].plot(x, x**3,label="cubic")
ax[0].set_xlabel('x label')
ax[0].set_ylabel('y label')
ax[0].set_title('간단그래프')
ax[0].legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 5
#       3 ax[1,0].plot(x, x**2, label="quadratic")
#       4 ax[2,0].plot(x, x**3,label="cubic")
# ----> 5 ax[0].set_xlabel('x label')
#       6 ax[0].set_ylabel('y label')
#       7 ax[0].set_title('간단그래프')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'set_xlabel'

# %%
fig, ax = plt.subplots(3,1,figsize=(5, 2.7))
ax[0].plot(x,x,label='linear')
ax[1].plot(x, x**2, label="quadratic")
ax[2].plot(x, x**3,label="cubic")
ax[0].set_xlabel('x label')
ax[0].set_ylabel('y label')
ax[0].set_title('간단그래프')
ax[0].legend()
plt.show()

# %% [markdown]
# ## pyplot 스타일
# * oo-style 보다 사용법 간단.
# * 복잡한 그래프를 그릴 때는 적합하지 않다.

# %%
# plt.ax = plt.subplot oo-style
# ax.plot(x,x,label='linear')
plt.figure(figsize=(5, 2.7))
plt.plot(x,x,label='linear')
plt.plot(x,x**2, label="quadratic")
plt.plot(x,x**3, label="cubic")
plt.xlabel("x축이름")
plt.ylabel("y축이름")
plt.title("pyplot 스타일 그래프")
plt.legend() #범례
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
#  # 선모양 바꾸기 set_linestyle(모양)

# %%
data1,data2,data3,data4 = np.random.randn(4,100)

# %%
data1
# Out:
# array([ 4.04662992e-01,  7.44922368e-01,  1.71145102e-01, -1.49394370e+00,
#        -1.07509464e+00,  7.20868260e-01, -1.07518356e+00,  8.68476196e-01,
#         2.18847844e+00, -1.61480651e+00,  2.03632069e+00,  7.90899716e-01,
#        -1.52355369e+00, -5.20521747e-01, -6.25323468e-01,  1.06904010e+00,
#        -3.36895410e-01, -8.59403897e-01, -5.53084945e-01, -1.08465882e-01,
#         9.01739276e-02,  1.36112753e-01, -7.49695189e-01, -9.56629793e-02,
#        -4.37183871e-02, -7.78492670e-02, -4.96572591e-01, -3.89319691e-01,
#        -8.62828429e-01, -2.95343039e-01,  6.71188068e-02, -6.84715497e-02,
#        -1.80896735e-01,  2.47215222e-03,  1.49772042e+00,  1.22174871e-01,
#        -4.71836411e-01, -8.85350126e-01, -1.59950983e-01, -4.62335801e-01,
#         2.38702363e+00,  7.00356159e-01,  1.16667317e+00,  2.85763180e-01,
#         3.69078916e-02, -2.06824152e-01, -4.91070460e-01,  3.83021314e-01,
# ...

# %% [markdown]
# ## 선모양 : '-','--','-.',':',''

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))
x = np.arange(len(data1))
ax.plot(x,np.cumsum(data1), color='blue', linewidth=3, linestyle="-")
ax.plot(x,np.cumsum(data2), color='orange', linewidth=2, linestyle="-.")
plt.show()

# %% [markdown]
# # 산점도 그래프를 그리고 색 변경하기
# * facecolor(안쪽컬러), engecolor(테두리색)

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))
ax.scatter(data1,data2, s=100, facecolor="C6", edgecolor='g')
plt.show()

# %% [markdown]
# 컬러를 RGB 값으로 주고 싶으면 (0,1,0.5)와 같이 rgb 컬러를 튜플로 적어주면 된다

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))
ax.scatter(data1,data2, s=100, facecolor=(0,0,0), edgecolor='g')
plt.show()

# %% [markdown]
# # 마커의 모양 지정하기
# |마커|설명|
# |---|:---|
# ||

# %%
fig , ax = plt.subplots(figsize=(5,2.7))
ax.plot(data1, 'o', label= "data1")
# ax.plot(data2, 'd', label= "data2")
# ax.plot(data3, 'v', label= "data3")
# ax.plot(data4, 's', label= "data4")
ax.legend()
plt.show()

# %%
fig , ax = plt.subplots(figsize=(5,2.7))
ax.plot(data1, '<', label= "data1")
ax.plot(data2, '>', label= "data2")
ax.plot(data3, 'v', label= "data3")
ax.plot(data4, 's', label= "data4")
ax.legend()
plt.show()

# %% [markdown]
# # x축, y축 이름, 눈금, 그래프 이름

# %%
mu, sigma = 115, 15
x = mu +sigma *np.random.randn(1000)
fig,ax = plt.subplots(figsize=(5,2.7))
n, bins, patches = ax.hist(x,50,density=True, facecolor='C0', alpha=0.75)
ax.set_xlabel("Length [cm]")
ax.set_ylabel("Probability")
ax.set_title('Aardark lengths\n(not really)')
ax.text(75,.025,r'$\nu=115, \ \sigma=15$')
ax.axis([55, 175, 0, 0.03]) #x,y축의 범위
plt.show()

# %%
mu, sigma = 115, 15
x = mu +sigma *np.random.randn(1000)
fig,ax = plt.subplots(figsize=(5,2.7))
n, bins, patches = ax.hist(x,50,density=True, facecolor='C0', alpha=0.75)
ax.set_xlabel("Length [cm]")
ax.set_ylabel("Probability")
ax.set_title('Aardark lengths\n(not really)')
ax.text(75,.025,r'$\nu=115, \ \sigma=15$')
ax.axis([55, 175, 0, 0.03]) #x,y축의 범위
ax.axis('off') # 사진 출력할 때 사용 
plt.show()

# %% [markdown]
# # 눈금자 단위구간

# %%
xdata = np.arange(len(data1))
fig,ax = plt.subplots(2,1,figsize=(5,2.7), layout='constrained')
ax[0].plot(xdata, data1)
ax[0].set_title('Automic ticks')

ax[1].plot(xdata,data1)
ax[1].set_xticks(np.arange(0,100,30), ['zero','30', 'sixty', '90'])
ax[1].set_yticks([-1.5,0,1.5])
ax[1].set_title("Manual ticks")
# Out:
# Text(0.5, 1.0, 'Manual ticks')

# %% [markdown]
# # 카테고리 막대 그래프 그리기

# %%
fig,ax = plt.subplots(figsize=(5,2.7))
categories=['turnips', 'rutabaga', 'cucumber', 'pummkins']
ax.bar(categories, np.random.rand(len(categories)))
plt.show()
